# %%
from draw.easy_map import map_background as map_background
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

fig, ax = plt.subplots(figsize = (10,8),subplot_kw={'projection': ccrs.PlateCarree()})
map_background(ax, grid_line='y', back_color='y', gridline_spaces=30)

# %%
import sys
print(sys.executable) # 현재 파이썬 인터프리터 경로 확인
print(sys.path)       # 현재 모듈 검색 경로 확인
# Out:
# /home1/jek/miniconda3/envs/pangu/bin/python
# ['/home1/jek/miniconda3/envs/pangu/lib/python310.zip', '/home1/jek/miniconda3/envs/pangu/lib/python3.10', '/home1/jek/miniconda3/envs/pangu/lib/python3.10/lib-dynload', '', '/home1/jek/.local/lib/python3.10/site-packages', '/home1/jek/miniconda3/envs/pangu/lib/python3.10/site-packages', '/home1/jek/custom_pkg']

# %%
import sysconfig
print(sysconfig.get_paths()['purelib'])
# Out:
# /home1/jek/miniconda3/envs/pangu/lib/python3.10/site-packages
