# %%
#%%
import torch
import onnxruntime as ort
import os
import numpy as np
import onnx
import time
import itertools

# ===============================
# CONFIG
# ===============================
lat_perturb = False  # ✅ 위도별 표준편차(=axis=3 기반 perturbation) 활성화 옵션
pangu_dir = r'/home1/jek/Pangu-Weather'

lat_indices = np.linspace(90, -90, 721)
lon_indices = np.linspace(-180, 180, 1441)[:-1]

def latlon_extent(lon_min, lon_max, lat_min, lat_max):    
    lon_min, lon_max = lon_min-180, lon_max-180  
    lat_start = np.argmin(np.abs(lat_indices - lat_max)) 
    lat_end = np.argmin(np.abs(lat_indices - lat_min))
    lon_start = np.argmin(np.abs(lon_indices - lon_min))
    lon_end = np.argmin(np.abs(lon_indices - lon_max))
    latlon_ratio = (lon_max-lon_min)/(lat_max-lat_min)
    extent=[lon_min, lon_max, lat_min, lat_max]
    return lat_start, lat_end, lon_start, lon_end, extent, latlon_ratio

lat_start, lat_end, lon_start, lon_end, extent, latlon_ratio = latlon_extent(100,160,5,45)  # ✅ 저장할 위경도 범위

year = ['2022']
month = ['08']
day = ['28']
times = ['00']
ens_list = range(0,100)
perturbation_scale_list =[0.05]
factor_list_list = [['z']]

surface_factor = ['MSLP', 'U10', 'V10', 'T2M']
surface_dict = {'MSLP':0, 'U10':1, 'V10':2, 'T2M':3}
upper_factor = ['z', 'q', 't', 'u', 'v']
upper_dict = {'z':0, 'q':1, 't':2, 'u':3, 'v':4}


# ===============================
# ONNX Sessions
# ===============================
options = ort.SessionOptions()
options.enable_cpu_mem_arena= True
options.enable_mem_pattern = False
options.enable_mem_reuse = False

cuda_provider_options_gpu0 = {'arena_extend_strategy': 'kSameAsRequested', 'device_id': 0}
ort_session_6 = ort.InferenceSession(
    rf'{pangu_dir}/pangu_weather_6.onnx', 
    sess_options=options, 
    providers=[('CUDAExecutionProvider', cuda_provider_options_gpu0)]
)

# ===============================
# MAIN LOOP
# ===============================
start = time.time()

for factor_list in factor_list_list:
    for perturbation_scale in perturbation_scale_list:
        for y, m, d, tm in itertools.product(year, month, day, times):
            time_str = f'{y}/{m}/{d}/{tm}UTC'

            input_data_dir = rf'{pangu_dir}/input_data/{time_str}'
            output_data_dir = rf'/data09/Pangu_TC_ENS/output_data/{time_str}'

            input_upper = np.load(os.path.join(input_data_dir, 'upper.npy')).astype(np.float32)
            input_surface = np.load(os.path.join(input_data_dir, 'surface.npy')).astype(np.float32)

            # ===============================
            # STD DEV 계산
            # ===============================
            # 전체 영역 기반 표준편차
            std_dev_upper = np.std(input_upper, axis=(2, 3), dtype=np.float32) * perturbation_scale  # (C, L)
            std_dev_surface = np.std(input_surface, axis=(1, 2), dtype=np.float32) * perturbation_scale

            factor_str = "".join([f"_{f}" for f in factor_list])
            lp_suffix = "_lp" if lat_perturb else ""
            ens_root_dir = rf'/data09/Pangu_TC_ENS/output_data/{time_str}/{perturbation_scale}ENS{factor_str}_6h{lp_suffix}'

            # ===============================
            # ENSEMBLE LOOP
            # ===============================
            for ens in ens_list:
                output_data_dir = os.path.join(ens_root_dir, str(ens))
                os.makedirs(os.path.join(output_data_dir, 'upper'), exist_ok=True)
                os.makedirs(os.path.join(output_data_dir, 'surface'), exist_ok=True)
                
                perturbed_upper = input_upper.copy()
                perturbed_surface = input_surface.copy()

                seed_val = hash((ens, tuple(factor_list), perturbation_scale)) % (2**32)
                rng = np.random.default_rng(seed_val)

                # ================
                # Perturbation
                # ================
                if ens != 0:
                    for factor in factor_list:
                        if factor in upper_dict:
                            idx = upper_dict[factor]
                            for j in range(13):
                                if lat_perturb:
                                    # 위도별 표준편차 적용
                                    noise = rng.normal(0, 1, size=input_upper[idx, j].shape).astype(np.float32)
                                    scale = std_dev_upper[idx, j][..., None]  # (lat, 1)
                                    perturbation = noise * scale
                                else:
                                    # 전체 평균 표준편차 적용
                                    perturbation = rng.normal(0, std_dev_upper[idx, j], input_upper[idx, j].shape)
                                perturbed_upper[idx, j] = input_upper[idx, j] + perturbation.astype(np.float32)

                        elif factor in surface_dict:
                            idx = surface_dict[factor]
                            perturbation = rng.normal(0, std_dev_surface[idx], input_surface[idx].shape)
                            perturbed_surface[idx] = input_surface[idx] + perturbation.astype(np.float32)

                # ================
                # Save initial
                # ================
                np.save(os.path.join(output_data_dir, f'upper/0h'), perturbed_upper[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                np.save(os.path.join(output_data_dir, f'surface/0h'), perturbed_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])

                start = time.time()

                # ================
                # Forecast loop
                # ================
                for i in range(28):
                    start_i = time.time()
                    predict_interval = 6 * (i + 1)

                    output, output_surface = ort_session_6.run(None, {'input': perturbed_upper, 'input_surface': perturbed_surface})

                    np.save(os.path.join(output_data_dir, f'upper/{predict_interval}h'), output[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                    np.save(os.path.join(output_data_dir, f'surface/{predict_interval}h'), output_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])

                    perturbed_upper, perturbed_surface = output, output_surface
                    end_i = time.time()
                    print(f'{factor_list} {perturbation_scale}_{ens}ENS {i+1}번째 반복 +{predict_interval}h {end_i-start_i:.2f}s')

                end = time.time()
                print(f"{factor_list} {perturbation_scale}_{ens}ENS: {end-start:.1f}s")
# Out:
# ['z'] 0.05_0ENS 1번째 반복 +6h 7.95s
# ['z'] 0.05_0ENS 2번째 반복 +12h 3.48s
# ['z'] 0.05_0ENS 3번째 반복 +18h 9.84s
# ['z'] 0.05_0ENS 4번째 반복 +24h 5.62s
# ['z'] 0.05_0ENS 5번째 반복 +30h 9.74s
# ['z'] 0.05_0ENS 6번째 반복 +36h 6.00s
# ['z'] 0.05_0ENS 7번째 반복 +42h 9.92s
# ['z'] 0.05_0ENS 8번째 반복 +48h 5.86s
# ['z'] 0.05_0ENS 9번째 반복 +54h 9.60s
# ['z'] 0.05_0ENS 10번째 반복 +60h 5.87s
# ['z'] 0.05_0ENS 11번째 반복 +66h 9.64s
# ['z'] 0.05_0ENS 12번째 반복 +72h 5.85s
# ['z'] 0.05_0ENS 13번째 반복 +78h 9.84s
# ['z'] 0.05_0ENS 14번째 반복 +84h 5.86s
# ['z'] 0.05_0ENS 15번째 반복 +90h 10.66s
# ['z'] 0.05_0ENS 16번째 반복 +96h 5.94s
# ['z'] 0.05_0ENS 17번째 반복 +102h 9.64s
# ['z'] 0.05_0ENS 18번째 반복 +108h 5.88s
# ['z'] 0.05_0ENS 19번째 반복 +114h 9.52s
# ['z'] 0.05_0ENS 20번째 반복 +120h 6.28s
# ['z'] 0.05_0ENS 21번째 반복 +126h 9.56s
# ['z'] 0.05_0ENS 22번째 반복 +132h 5.84s
# ['z'] 0.05_0ENS 23번째 반복 +138h 9.70s
# ['z'] 0.05_0ENS 24번째 반복 +144h 5.82s
# ['z'] 0.05_0ENS 25번째 반복 +150h 9.58s
# ['z'] 0.05_0ENS 26번째 반복 +156h 5.77s
# ['z'] 0.05_0ENS 27번째 반복 +162h 9.34s
# ['z'] 0.05_0ENS 28번째 반복 +168h 5.80s
# ['z'] 0.05_0ENS: 214.4s
# ['z'] 0.05_1ENS 1번째 반복 +6h 10.26s
# ['z'] 0.05_1ENS 2번째 반복 +12h 6.38s
# ['z'] 0.05_1ENS 3번째 반복 +18h 7.99s
# ['z'] 0.05_1ENS 4번째 반복 +24h 6.00s
# ['z'] 0.05_1ENS 5번째 반복 +30h 7.03s
# ['z'] 0.05_1ENS 6번째 반복 +36h 6.03s
# ['z'] 0.05_1ENS 7번째 반복 +42h 7.02s
# ['z'] 0.05_1ENS 8번째 반복 +48h 6.00s
# ['z'] 0.05_1ENS 9번째 반복 +54h 7.06s
# ['z'] 0.05_1ENS 10번째 반복 +60h 6.63s
# ['z'] 0.05_1ENS 11번째 반복 +66h 7.89s
# ['z'] 0.05_1ENS 12번째 반복 +72h 6.70s
# ['z'] 0.05_1ENS 13번째 반복 +78h 7.98s
# ['z'] 0.05_1ENS 14번째 반복 +84h 7.28s
# ['z'] 0.05_1ENS 15번째 반복 +90h 8.97s
# ['z'] 0.05_1ENS 16번째 반복 +96h 6.77s
# ['z'] 0.05_1ENS 17번째 반복 +102h 7.17s
# ['z'] 0.05_1ENS 18번째 반복 +108h 6.10s
# ['z'] 0.05_1ENS 19번째 반복 +114h 7.10s
# ['z'] 0.05_1ENS 20번째 반복 +120h 6.58s
# ['z'] 0.05_1ENS 21번째 반복 +126h 7.47s
# ['z'] 0.05_1ENS 22번째 반복 +132h 6.17s
# ['z'] 0.05_1ENS 23번째 반복 +138h 7.63s
# ['z'] 0.05_1ENS 24번째 반복 +144h 7.10s
# ['z'] 0.05_1ENS 25번째 반복 +150h 7.12s
# ['z'] 0.05_1ENS 26번째 반복 +156h 6.15s
# ['z'] 0.05_1ENS 27번째 반복 +162h 7.71s
# ['z'] 0.05_1ENS 28번째 반복 +168h 7.07s
# ['z'] 0.05_1ENS: 199.4s
# ['z'] 0.05_2ENS 1번째 반복 +6h 10.98s
# ['z'] 0.05_2ENS 2번째 반복 +12h 3.11s
# ['z'] 0.05_2ENS 3번째 반복 +18h 11.27s
# ['z'] 0.05_2ENS 4번째 반복 +24h 3.41s
# ['z'] 0.05_2ENS 5번째 반복 +30h 9.74s
# ['z'] 0.05_2ENS 6번째 반복 +36h 2.94s
# ['z'] 0.05_2ENS 7번째 반복 +42h 9.70s
# ['z'] 0.05_2ENS 8번째 반복 +48h 3.31s
# ['z'] 0.05_2ENS 9번째 반복 +54h 10.04s
# ['z'] 0.05_2ENS 10번째 반복 +60h 3.29s
# ['z'] 0.05_2ENS 11번째 반복 +66h 9.66s
# ['z'] 0.05_2ENS 12번째 반복 +72h 3.29s
# ['z'] 0.05_2ENS 13번째 반복 +78h 9.69s
# ['z'] 0.05_2ENS 14번째 반복 +84h 3.28s
# ['z'] 0.05_2ENS 15번째 반복 +90h 9.61s
# ['z'] 0.05_2ENS 16번째 반복 +96h 3.28s
# ['z'] 0.05_2ENS 17번째 반복 +102h 9.69s
# ['z'] 0.05_2ENS 18번째 반복 +108h 3.29s
# ['z'] 0.05_2ENS 19번째 반복 +114h 9.57s
# ['z'] 0.05_2ENS 20번째 반복 +120h 3.29s
# ['z'] 0.05_2ENS 21번째 반복 +126h 9.66s
# ['z'] 0.05_2ENS 22번째 반복 +132h 3.29s
# ['z'] 0.05_2ENS 23번째 반복 +138h 10.22s
# ['z'] 0.05_2ENS 24번째 반복 +144h 3.29s
# ['z'] 0.05_2ENS 25번째 반복 +150h 9.65s
# ['z'] 0.05_2ENS 26번째 반복 +156h 3.28s
# ['z'] 0.05_2ENS 27번째 반복 +162h 9.74s
# ['z'] 0.05_2ENS 28번째 반복 +168h 3.30s
# ['z'] 0.05_2ENS: 184.9s
# ['z'] 0.05_3ENS 1번째 반복 +6h 9.83s
# ['z'] 0.05_3ENS 2번째 반복 +12h 2.94s
# ['z'] 0.05_3ENS 3번째 반복 +18h 9.74s
# ['z'] 0.05_3ENS 4번째 반복 +24h 2.96s
# ['z'] 0.05_3ENS 5번째 반복 +30h 9.70s
# ['z'] 0.05_3ENS 6번째 반복 +36h 2.94s
# ['z'] 0.05_3ENS 7번째 반복 +42h 9.70s
# ['z'] 0.05_3ENS 8번째 반복 +48h 2.95s
# ['z'] 0.05_3ENS 9번째 반복 +54h 9.69s
# ['z'] 0.05_3ENS 10번째 반복 +60h 2.94s
# ['z'] 0.05_3ENS 11번째 반복 +66h 10.26s
# ['z'] 0.05_3ENS 12번째 반복 +72h 2.94s
# ['z'] 0.05_3ENS 13번째 반복 +78h 9.59s
# ['z'] 0.05_3ENS 14번째 반복 +84h 2.94s
# ['z'] 0.05_3ENS 15번째 반복 +90h 9.60s
# ['z'] 0.05_3ENS 16번째 반복 +96h 2.92s
# ['z'] 0.05_3ENS 17번째 반복 +102h 9.69s
# ['z'] 0.05_3ENS 18번째 반복 +108h 2.94s
# ['z'] 0.05_3ENS 19번째 반복 +114h 9.61s
# ['z'] 0.05_3ENS 20번째 반복 +120h 2.94s
# ['z'] 0.05_3ENS 21번째 반복 +126h 9.60s
# ['z'] 0.05_3ENS 22번째 반복 +132h 2.93s
# ['z'] 0.05_3ENS 23번째 반복 +138h 10.41s
# ['z'] 0.05_3ENS 24번째 반복 +144h 2.99s
# ['z'] 0.05_3ENS 25번째 반복 +150h 9.67s
# ['z'] 0.05_3ENS 26번째 반복 +156h 2.94s
# ['z'] 0.05_3ENS 27번째 반복 +162h 9.69s
# ['z'] 0.05_3ENS 28번째 반복 +168h 2.94s
# ['z'] 0.05_3ENS: 178.0s
# ['z'] 0.05_4ENS 1번째 반복 +6h 9.94s
# ['z'] 0.05_4ENS 2번째 반복 +12h 2.71s
# ['z'] 0.05_4ENS 3번째 반복 +18h 10.38s
# ['z'] 0.05_4ENS 4번째 반복 +24h 2.71s
# ['z'] 0.05_4ENS 5번째 반복 +30h 9.86s
# ['z'] 0.05_4ENS 6번째 반복 +36h 2.71s
# ['z'] 0.05_4ENS 7번째 반복 +42h 9.83s
# ['z'] 0.05_4ENS 8번째 반복 +48h 2.71s
# ['z'] 0.05_4ENS 9번째 반복 +54h 9.93s
# ['z'] 0.05_4ENS 10번째 반복 +60h 2.72s
# ['z'] 0.05_4ENS 11번째 반복 +66h 9.94s
# ['z'] 0.05_4ENS 12번째 반복 +72h 2.71s
# ['z'] 0.05_4ENS 13번째 반복 +78h 9.96s
# ['z'] 0.05_4ENS 14번째 반복 +84h 2.72s
# ['z'] 0.05_4ENS 15번째 반복 +90h 9.84s
# ['z'] 0.05_4ENS 16번째 반복 +96h 2.72s
# ['z'] 0.05_4ENS 17번째 반복 +102h 9.88s
# ['z'] 0.05_4ENS 18번째 반복 +108h 2.79s
# ['z'] 0.05_4ENS 19번째 반복 +114h 9.84s
# ['z'] 0.05_4ENS 20번째 반복 +120h 2.71s
# ['z'] 0.05_4ENS 21번째 반복 +126h 9.28s
# ['z'] 0.05_4ENS 22번째 반복 +132h 2.72s
# ['z'] 0.05_4ENS 23번째 반복 +138h 9.17s
# ['z'] 0.05_4ENS 24번째 반복 +144h 2.72s
# ['z'] 0.05_4ENS 25번째 반복 +150h 10.01s
# ['z'] 0.05_4ENS 26번째 반복 +156h 2.72s
# ['z'] 0.05_4ENS 27번째 반복 +162h 9.06s
# ['z'] 0.05_4ENS 28번째 반복 +168h 2.71s
# ['z'] 0.05_4ENS: 175.0s
# ['z'] 0.05_5ENS 1번째 반복 +6h 10.02s
# ['z'] 0.05_5ENS 2번째 반복 +12h 2.35s
# ['z'] 0.05_5ENS 3번째 반복 +18h 9.21s
# ['z'] 0.05_5ENS 4번째 반복 +24h 2.36s
# ['z'] 0.05_5ENS 5번째 반복 +30h 9.75s
# ['z'] 0.05_5ENS 6번째 반복 +36h 2.35s
# ['z'] 0.05_5ENS 7번째 반복 +42h 9.25s
# ['z'] 0.05_5ENS 8번째 반복 +48h 2.35s
# ['z'] 0.05_5ENS 9번째 반복 +54h 9.19s
# ['z'] 0.05_5ENS 10번째 반복 +60h 2.35s
# ['z'] 0.05_5ENS 11번째 반복 +66h 9.22s
# ['z'] 0.05_5ENS 12번째 반복 +72h 2.35s
# ['z'] 0.05_5ENS 13번째 반복 +78h 9.25s
# ['z'] 0.05_5ENS 14번째 반복 +84h 2.35s
# ['z'] 0.05_5ENS 15번째 반복 +90h 9.22s
# ['z'] 0.05_5ENS 16번째 반복 +96h 3.00s
# ['z'] 0.05_5ENS 17번째 반복 +102h 9.19s
# ['z'] 0.05_5ENS 18번째 반복 +108h 2.36s
# ['z'] 0.05_5ENS 19번째 반복 +114h 9.19s
# ['z'] 0.05_5ENS 20번째 반복 +120h 2.35s
# ['z'] 0.05_5ENS 21번째 반복 +126h 9.22s
# ['z'] 0.05_5ENS 22번째 반복 +132h 2.35s
# ['z'] 0.05_5ENS 23번째 반복 +138h 9.17s
# ['z'] 0.05_5ENS 24번째 반복 +144h 2.35s
# ['z'] 0.05_5ENS 25번째 반복 +150h 9.19s
# ['z'] 0.05_5ENS 26번째 반복 +156h 2.35s
# ['z'] 0.05_5ENS 27번째 반복 +162h 9.12s
# ['z'] 0.05_5ENS 28번째 반복 +168h 2.34s
# ['z'] 0.05_5ENS: 163.8s
# ['z'] 0.05_6ENS 1번째 반복 +6h 10.14s
# ['z'] 0.05_6ENS 2번째 반복 +12h 2.34s
# ['z'] 0.05_6ENS 3번째 반복 +18h 9.14s
# ['z'] 0.05_6ENS 4번째 반복 +24h 2.33s
# ['z'] 0.05_6ENS 5번째 반복 +30h 9.08s
# ['z'] 0.05_6ENS 6번째 반복 +36h 2.34s
# ['z'] 0.05_6ENS 7번째 반복 +42h 9.23s
# ['z'] 0.05_6ENS 8번째 반복 +48h 2.33s
# ['z'] 0.05_6ENS 9번째 반복 +54h 9.35s
# ['z'] 0.05_6ENS 10번째 반복 +60h 2.33s
# ['z'] 0.05_6ENS 11번째 반복 +66h 9.12s
# ['z'] 0.05_6ENS 12번째 반복 +72h 2.33s
# ['z'] 0.05_6ENS 13번째 반복 +78h 9.24s
# ['z'] 0.05_6ENS 14번째 반복 +84h 2.33s
# ['z'] 0.05_6ENS 15번째 반복 +90h 9.17s
# ['z'] 0.05_6ENS 16번째 반복 +96h 2.33s
# ['z'] 0.05_6ENS 17번째 반복 +102h 9.67s
# ['z'] 0.05_6ENS 18번째 반복 +108h 2.37s
# ['z'] 0.05_6ENS 19번째 반복 +114h 9.19s
# ['z'] 0.05_6ENS 20번째 반복 +120h 2.33s
# ['z'] 0.05_6ENS 21번째 반복 +126h 9.19s
# ['z'] 0.05_6ENS 22번째 반복 +132h 2.34s
# ['z'] 0.05_6ENS 23번째 반복 +138h 9.17s
# ['z'] 0.05_6ENS 24번째 반복 +144h 2.33s
# ['z'] 0.05_6ENS 25번째 반복 +150h 9.19s
# ['z'] 0.05_6ENS 26번째 반복 +156h 2.33s
# ['z'] 0.05_6ENS 27번째 반복 +162h 9.21s
# ['z'] 0.05_6ENS 28번째 반복 +168h 2.33s
# ['z'] 0.05_6ENS: 162.8s
# ['z'] 0.05_7ENS 1번째 반복 +6h 9.96s
# ['z'] 0.05_7ENS 2번째 반복 +12h 2.33s
# ['z'] 0.05_7ENS 3번째 반복 +18h 9.23s
# ['z'] 0.05_7ENS 4번째 반복 +24h 2.33s
# ['z'] 0.05_7ENS 5번째 반복 +30h 9.20s
# ['z'] 0.05_7ENS 6번째 반복 +36h 2.33s
# ['z'] 0.05_7ENS 7번째 반복 +42h 9.19s
# ['z'] 0.05_7ENS 8번째 반복 +48h 2.33s
# ['z'] 0.05_7ENS 9번째 반복 +54h 9.94s
# ['z'] 0.05_7ENS 10번째 반복 +60h 2.34s
# ['z'] 0.05_7ENS 11번째 반복 +66h 9.27s
# ['z'] 0.05_7ENS 12번째 반복 +72h 2.33s
# ['z'] 0.05_7ENS 13번째 반복 +78h 9.14s
# ['z'] 0.05_7ENS 14번째 반복 +84h 2.33s
# ['z'] 0.05_7ENS 15번째 반복 +90h 9.24s
# ['z'] 0.05_7ENS 16번째 반복 +96h 2.33s
# ['z'] 0.05_7ENS 17번째 반복 +102h 9.22s
# ['z'] 0.05_7ENS 18번째 반복 +108h 2.34s
# ['z'] 0.05_7ENS 19번째 반복 +114h 9.24s
# ['z'] 0.05_7ENS 20번째 반복 +120h 2.34s
# ['z'] 0.05_7ENS 21번째 반복 +126h 9.16s
# ['z'] 0.05_7ENS 22번째 반복 +132h 2.33s
# ['z'] 0.05_7ENS 23번째 반복 +138h 9.26s
# ['z'] 0.05_7ENS 24번째 반복 +144h 2.41s
# ['z'] 0.05_7ENS 25번째 반복 +150h 9.18s
# ['z'] 0.05_7ENS 26번째 반복 +156h 2.34s
# ['z'] 0.05_7ENS 27번째 반복 +162h 9.20s
# ['z'] 0.05_7ENS 28번째 반복 +168h 2.34s
# ['z'] 0.05_7ENS: 163.2s
# ['z'] 0.05_8ENS 1번째 반복 +6h 10.07s
# ['z'] 0.05_8ENS 2번째 반복 +12h 2.33s
# ['z'] 0.05_8ENS 3번째 반복 +18h 9.13s
# ['z'] 0.05_8ENS 4번째 반복 +24h 2.33s
# ['z'] 0.05_8ENS 5번째 반복 +30h 9.17s
# ['z'] 0.05_8ENS 6번째 반복 +36h 2.34s
# ['z'] 0.05_8ENS 7번째 반복 +42h 9.11s
# ['z'] 0.05_8ENS 8번째 반복 +48h 2.38s
# ['z'] 0.05_8ENS 9번째 반복 +54h 9.11s
# ['z'] 0.05_8ENS 10번째 반복 +60h 2.45s
# ['z'] 0.05_8ENS 11번째 반복 +66h 9.86s
# ['z'] 0.05_8ENS 12번째 반복 +72h 2.40s
# ['z'] 0.05_8ENS 13번째 반복 +78h 9.01s
# ['z'] 0.05_8ENS 14번째 반복 +84h 2.40s
# ['z'] 0.05_8ENS 15번째 반복 +90h 7.95s
# ['z'] 0.05_8ENS 16번째 반복 +96h 2.30s
# ['z'] 0.05_8ENS 17번째 반복 +102h 3.95s
# ['z'] 0.05_8ENS 18번째 반복 +108h 2.31s
# ['z'] 0.05_8ENS 19번째 반복 +114h 3.92s
# ['z'] 0.05_8ENS 20번째 반복 +120h 2.30s
# ['z'] 0.05_8ENS 21번째 반복 +126h 3.89s
# ['z'] 0.05_8ENS 22번째 반복 +132h 2.30s
# ['z'] 0.05_8ENS 23번째 반복 +138h 3.90s
# ['z'] 0.05_8ENS 24번째 반복 +144h 3.30s
# ['z'] 0.05_8ENS 25번째 반복 +150h 3.93s
# ['z'] 0.05_8ENS 26번째 반복 +156h 2.29s
# ['z'] 0.05_8ENS 27번째 반복 +162h 3.87s
# ['z'] 0.05_8ENS 28번째 반복 +168h 2.29s
# ['z'] 0.05_8ENS: 130.6s
# ['z'] 0.05_9ENS 1번째 반복 +6h 4.24s
# ['z'] 0.05_9ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_9ENS 3번째 반복 +18h 3.91s
# ['z'] 0.05_9ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_9ENS 5번째 반복 +30h 3.88s
# ['z'] 0.05_9ENS 6번째 반복 +36h 2.29s
# ['z'] 0.05_9ENS 7번째 반복 +42h 8.85s
# ['z'] 0.05_9ENS 8번째 반복 +48h 2.29s
# ['z'] 0.05_9ENS 9번째 반복 +54h 8.83s
# ['z'] 0.05_9ENS 10번째 반복 +60h 2.29s
# ['z'] 0.05_9ENS 11번째 반복 +66h 8.83s
# ['z'] 0.05_9ENS 12번째 반복 +72h 2.29s
# ['z'] 0.05_9ENS 13번째 반복 +78h 8.91s
# ['z'] 0.05_9ENS 14번째 반복 +84h 2.30s
# ['z'] 0.05_9ENS 15번째 반복 +90h 8.90s
# ['z'] 0.05_9ENS 16번째 반복 +96h 2.29s
# ['z'] 0.05_9ENS 17번째 반복 +102h 8.93s
# ['z'] 0.05_9ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_9ENS 19번째 반복 +114h 8.88s
# ['z'] 0.05_9ENS 20번째 반복 +120h 2.30s
# ['z'] 0.05_9ENS 21번째 반복 +126h 8.90s
# ['z'] 0.05_9ENS 22번째 반복 +132h 2.29s
# ['z'] 0.05_9ENS 23번째 반복 +138h 8.96s
# ['z'] 0.05_9ENS 24번째 반복 +144h 2.29s
# ['z'] 0.05_9ENS 25번째 반복 +150h 8.89s
# ['z'] 0.05_9ENS 26번째 반복 +156h 2.30s
# ['z'] 0.05_9ENS 27번째 반복 +162h 9.00s
# ['z'] 0.05_9ENS 28번째 반복 +168h 2.43s
# ['z'] 0.05_9ENS: 142.1s
# ['z'] 0.05_10ENS 1번째 반복 +6h 10.13s
# ['z'] 0.05_10ENS 2번째 반복 +12h 2.32s
# ['z'] 0.05_10ENS 3번째 반복 +18h 9.14s
# ['z'] 0.05_10ENS 4번째 반복 +24h 2.32s
# ['z'] 0.05_10ENS 5번째 반복 +30h 9.20s
# ['z'] 0.05_10ENS 6번째 반복 +36h 2.33s
# ['z'] 0.05_10ENS 7번째 반복 +42h 9.20s
# ['z'] 0.05_10ENS 8번째 반복 +48h 2.38s
# ['z'] 0.05_10ENS 9번째 반복 +54h 7.28s
# ['z'] 0.05_10ENS 10번째 반복 +60h 2.30s
# ['z'] 0.05_10ENS 11번째 반복 +66h 7.38s
# ['z'] 0.05_10ENS 12번째 반복 +72h 2.37s
# ['z'] 0.05_10ENS 13번째 반복 +78h 9.00s
# ['z'] 0.05_10ENS 14번째 반복 +84h 2.37s
# ['z'] 0.05_10ENS 15번째 반복 +90h 8.90s
# ['z'] 0.05_10ENS 16번째 반복 +96h 2.37s
# ['z'] 0.05_10ENS 17번째 반복 +102h 8.88s
# ['z'] 0.05_10ENS 18번째 반복 +108h 2.40s
# ['z'] 0.05_10ENS 19번째 반복 +114h 9.09s
# ['z'] 0.05_10ENS 20번째 반복 +120h 2.42s
# ['z'] 0.05_10ENS 21번째 반복 +126h 8.91s
# ['z'] 0.05_10ENS 22번째 반복 +132h 2.43s
# ['z'] 0.05_10ENS 23번째 반복 +138h 8.96s
# ['z'] 0.05_10ENS 24번째 반복 +144h 2.48s
# ['z'] 0.05_10ENS 25번째 반복 +150h 9.57s
# ['z'] 0.05_10ENS 26번째 반복 +156h 3.45s
# ['z'] 0.05_10ENS 27번째 반복 +162h 2.57s
# ['z'] 0.05_10ENS 28번째 반복 +168h 3.59s
# ['z'] 0.05_10ENS: 153.7s
# ['z'] 0.05_11ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_11ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_11ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_11ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_11ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_11ENS 6번째 반복 +36h 2.89s
# ['z'] 0.05_11ENS 7번째 반복 +42h 4.01s
# ['z'] 0.05_11ENS 8번째 반복 +48h 2.64s
# ['z'] 0.05_11ENS 9번째 반복 +54h 2.67s
# ['z'] 0.05_11ENS 10번째 반복 +60h 2.61s
# ['z'] 0.05_11ENS 11번째 반복 +66h 2.66s
# ['z'] 0.05_11ENS 12번째 반복 +72h 2.68s
# ['z'] 0.05_11ENS 13번째 반복 +78h 2.61s
# ['z'] 0.05_11ENS 14번째 반복 +84h 2.50s
# ['z'] 0.05_11ENS 15번째 반복 +90h 2.59s
# ['z'] 0.05_11ENS 16번째 반복 +96h 2.54s
# ['z'] 0.05_11ENS 17번째 반복 +102h 2.71s
# ['z'] 0.05_11ENS 18번째 반복 +108h 2.68s
# ['z'] 0.05_11ENS 19번째 반복 +114h 2.65s
# ['z'] 0.05_11ENS 20번째 반복 +120h 2.65s
# ['z'] 0.05_11ENS 21번째 반복 +126h 2.68s
# ['z'] 0.05_11ENS 22번째 반복 +132h 2.66s
# ['z'] 0.05_11ENS 23번째 반복 +138h 2.62s
# ['z'] 0.05_11ENS 24번째 반복 +144h 2.65s
# ['z'] 0.05_11ENS 25번째 반복 +150h 2.67s
# ['z'] 0.05_11ENS 26번째 반복 +156h 2.64s
# ['z'] 0.05_11ENS 27번째 반복 +162h 2.34s
# ['z'] 0.05_11ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_11ENS: 73.0s
# ['z'] 0.05_12ENS 1번째 반복 +6h 2.33s
# ['z'] 0.05_12ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_12ENS 3번째 반복 +18h 2.30s
# ['z'] 0.05_12ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_12ENS 5번째 반복 +30h 2.31s
# ['z'] 0.05_12ENS 6번째 반복 +36h 2.63s
# ['z'] 0.05_12ENS 7번째 반복 +42h 2.77s
# ['z'] 0.05_12ENS 8번째 반복 +48h 2.33s
# ['z'] 0.05_12ENS 9번째 반복 +54h 10.29s
# ['z'] 0.05_12ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_12ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_12ENS 12번째 반복 +72h 2.42s
# ['z'] 0.05_12ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_12ENS 14번째 반복 +84h 2.44s
# ['z'] 0.05_12ENS 15번째 반복 +90h 2.80s
# ['z'] 0.05_12ENS 16번째 반복 +96h 2.76s
# ['z'] 0.05_12ENS 17번째 반복 +102h 2.31s
# ['z'] 0.05_12ENS 18번째 반복 +108h 15.25s
# ['z'] 0.05_12ENS 19번째 반복 +114h 3.44s
# ['z'] 0.05_12ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_12ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_12ENS 22번째 반복 +132h 2.26s
# ['z'] 0.05_12ENS 23번째 반복 +138h 2.26s
# ['z'] 0.05_12ENS 24번째 반복 +144h 2.26s
# ['z'] 0.05_12ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_12ENS 26번째 반복 +156h 2.26s
# ['z'] 0.05_12ENS 27번째 반복 +162h 2.29s
# ['z'] 0.05_12ENS 28번째 반복 +168h 2.26s
# ['z'] 0.05_12ENS: 88.2s
# ['z'] 0.05_13ENS 1번째 반복 +6h 2.70s
# ['z'] 0.05_13ENS 2번째 반복 +12h 2.26s
# ['z'] 0.05_13ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_13ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_13ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_13ENS 6번째 반복 +36h 2.26s
# ['z'] 0.05_13ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_13ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_13ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_13ENS 10번째 반복 +60h 2.26s
# ['z'] 0.05_13ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_13ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_13ENS 13번째 반복 +78h 2.29s
# ['z'] 0.05_13ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_13ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_13ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_13ENS 17번째 반복 +102h 2.32s
# ['z'] 0.05_13ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_13ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_13ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_13ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_13ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_13ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_13ENS 24번째 반복 +144h 2.26s
# ['z'] 0.05_13ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_13ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_13ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_13ENS 28번째 반복 +168h 2.26s
# ['z'] 0.05_13ENS: 64.0s
# ['z'] 0.05_14ENS 1번째 반복 +6h 3.31s
# ['z'] 0.05_14ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_14ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_14ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_14ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_14ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_14ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_14ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_14ENS 9번째 반복 +54h 2.29s
# ['z'] 0.05_14ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_14ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_14ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_14ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_14ENS 14번째 반복 +84h 2.26s
# ['z'] 0.05_14ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_14ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_14ENS 17번째 반복 +102h 2.32s
# ['z'] 0.05_14ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_14ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_14ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_14ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_14ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_14ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_14ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_14ENS 25번째 반복 +150h 2.29s
# ['z'] 0.05_14ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_14ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_14ENS 28번째 반복 +168h 2.29s
# ['z'] 0.05_14ENS: 64.8s
# ['z'] 0.05_15ENS 1번째 반복 +6h 2.29s
# ['z'] 0.05_15ENS 2번째 반복 +12h 2.29s
# ['z'] 0.05_15ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_15ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_15ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_15ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_15ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_15ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_15ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_15ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_15ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_15ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_15ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_15ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_15ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_15ENS 16번째 반복 +96h 2.29s
# ['z'] 0.05_15ENS 17번째 반복 +102h 2.29s
# ['z'] 0.05_15ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_15ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_15ENS 20번째 반복 +120h 2.33s
# ['z'] 0.05_15ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_15ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_15ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_15ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_15ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_15ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_15ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_15ENS 28번째 반복 +168h 2.33s
# ['z'] 0.05_15ENS: 63.9s
# ['z'] 0.05_16ENS 1번째 반복 +6h 2.58s
# ['z'] 0.05_16ENS 2번째 반복 +12h 2.29s
# ['z'] 0.05_16ENS 3번째 반복 +18h 2.31s
# ['z'] 0.05_16ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_16ENS 5번째 반복 +30h 2.36s
# ['z'] 0.05_16ENS 6번째 반복 +36h 2.36s
# ['z'] 0.05_16ENS 7번째 반복 +42h 2.29s
# ['z'] 0.05_16ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_16ENS 9번째 반복 +54h 2.38s
# ['z'] 0.05_16ENS 10번째 반복 +60h 2.29s
# ['z'] 0.05_16ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_16ENS 12번째 반복 +72h 2.65s
# ['z'] 0.05_16ENS 13번째 반복 +78h 2.31s
# ['z'] 0.05_16ENS 14번째 반복 +84h 2.35s
# ['z'] 0.05_16ENS 15번째 반복 +90h 2.40s
# ['z'] 0.05_16ENS 16번째 반복 +96h 2.45s
# ['z'] 0.05_16ENS 17번째 반복 +102h 2.29s
# ['z'] 0.05_16ENS 18번째 반복 +108h 2.38s
# ['z'] 0.05_16ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_16ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_16ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_16ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_16ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_16ENS 24번째 반복 +144h 2.52s
# ['z'] 0.05_16ENS 25번째 반복 +150h 2.30s
# ['z'] 0.05_16ENS 26번째 반복 +156h 2.35s
# ['z'] 0.05_16ENS 27번째 반복 +162h 2.32s
# ['z'] 0.05_16ENS 28번째 반복 +168h 2.41s
# ['z'] 0.05_16ENS: 65.8s
# ['z'] 0.05_17ENS 1번째 반복 +6h 2.64s
# ['z'] 0.05_17ENS 2번째 반복 +12h 2.31s
# ['z'] 0.05_17ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_17ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_17ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_17ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_17ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_17ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_17ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_17ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_17ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_17ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_17ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_17ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_17ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_17ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_17ENS 17번째 반복 +102h 2.31s
# ['z'] 0.05_17ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_17ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_17ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_17ENS 21번째 반복 +126h 2.29s
# ['z'] 0.05_17ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_17ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_17ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_17ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_17ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_17ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_17ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_17ENS: 64.2s
# ['z'] 0.05_18ENS 1번째 반복 +6h 2.81s
# ['z'] 0.05_18ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_18ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_18ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_18ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_18ENS 6번째 반복 +36h 2.29s
# ['z'] 0.05_18ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_18ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_18ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_18ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_18ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_18ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_18ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_18ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_18ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_18ENS 16번째 반복 +96h 2.30s
# ['z'] 0.05_18ENS 17번째 반복 +102h 2.31s
# ['z'] 0.05_18ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_18ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_18ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_18ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_18ENS 22번째 반복 +132h 2.31s
# ['z'] 0.05_18ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_18ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_18ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_18ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_18ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_18ENS 28번째 반복 +168h 2.29s
# ['z'] 0.05_18ENS: 64.4s
# ['z'] 0.05_19ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_19ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_19ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_19ENS 4번째 반복 +24h 2.32s
# ['z'] 0.05_19ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_19ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_19ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_19ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_19ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_19ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_19ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_19ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_19ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_19ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_19ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_19ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_19ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_19ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_19ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_19ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_19ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_19ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_19ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_19ENS 24번째 반복 +144h 2.29s
# ['z'] 0.05_19ENS 25번째 반복 +150h 2.29s
# ['z'] 0.05_19ENS 26번째 반복 +156h 2.29s
# ['z'] 0.05_19ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_19ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_19ENS: 63.8s
# ['z'] 0.05_20ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_20ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_20ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_20ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_20ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_20ENS 6번째 반복 +36h 2.30s
# ['z'] 0.05_20ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_20ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_20ENS 9번째 반복 +54h 2.29s
# ['z'] 0.05_20ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_20ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_20ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_20ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_20ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_20ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_20ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_20ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_20ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_20ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_20ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_20ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_20ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_20ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_20ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_20ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_20ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_20ENS 27번째 반복 +162h 2.26s
# ['z'] 0.05_20ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_20ENS: 63.7s
# ['z'] 0.05_21ENS 1번째 반복 +6h 2.29s
# ['z'] 0.05_21ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_21ENS 3번째 반복 +18h 2.29s
# ['z'] 0.05_21ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_21ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_21ENS 6번째 반복 +36h 2.26s
# ['z'] 0.05_21ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_21ENS 8번째 반복 +48h 2.33s
# ['z'] 0.05_21ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_21ENS 10번째 반복 +60h 2.26s
# ['z'] 0.05_21ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_21ENS 12번째 반복 +72h 2.26s
# ['z'] 0.05_21ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_21ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_21ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_21ENS 16번째 반복 +96h 2.26s
# ['z'] 0.05_21ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_21ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_21ENS 19번째 반복 +114h 2.29s
# ['z'] 0.05_21ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_21ENS 21번째 반복 +126h 2.29s
# ['z'] 0.05_21ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_21ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_21ENS 24번째 반복 +144h 2.29s
# ['z'] 0.05_21ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_21ENS 26번째 반복 +156h 2.26s
# ['z'] 0.05_21ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_21ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_21ENS: 63.6s
# ['z'] 0.05_22ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_22ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_22ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_22ENS 4번째 반복 +24h 2.26s
# ['z'] 0.05_22ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_22ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_22ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_22ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_22ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_22ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_22ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_22ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_22ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_22ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_22ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_22ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_22ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_22ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_22ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_22ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_22ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_22ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_22ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_22ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_22ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_22ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_22ENS 27번째 반복 +162h 2.29s
# ['z'] 0.05_22ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_22ENS: 63.6s
# ['z'] 0.05_23ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_23ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_23ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_23ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_23ENS 5번째 반복 +30h 2.29s
# ['z'] 0.05_23ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_23ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_23ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_23ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_23ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_23ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_23ENS 12번째 반복 +72h 2.26s
# ['z'] 0.05_23ENS 13번째 반복 +78h 2.30s
# ['z'] 0.05_23ENS 14번째 반복 +84h 2.29s
# ['z'] 0.05_23ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_23ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_23ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_23ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_23ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_23ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_23ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_23ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_23ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_23ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_23ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_23ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_23ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_23ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_23ENS: 63.7s
# ['z'] 0.05_24ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_24ENS 2번째 반복 +12h 2.29s
# ['z'] 0.05_24ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_24ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_24ENS 5번째 반복 +30h 2.29s
# ['z'] 0.05_24ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_24ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_24ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_24ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_24ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_24ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_24ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_24ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_24ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_24ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_24ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_24ENS 17번째 반복 +102h 2.29s
# ['z'] 0.05_24ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_24ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_24ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_24ENS 21번째 반복 +126h 2.29s
# ['z'] 0.05_24ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_24ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_24ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_24ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_24ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_24ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_24ENS 28번째 반복 +168h 2.30s
# ['z'] 0.05_24ENS: 63.8s
# ['z'] 0.05_25ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_25ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_25ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_25ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_25ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_25ENS 6번째 반복 +36h 2.29s
# ['z'] 0.05_25ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_25ENS 8번째 반복 +48h 2.29s
# ['z'] 0.05_25ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_25ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_25ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_25ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_25ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_25ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_25ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_25ENS 16번째 반복 +96h 2.29s
# ['z'] 0.05_25ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_25ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_25ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_25ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_25ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_25ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_25ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_25ENS 24번째 반복 +144h 2.29s
# ['z'] 0.05_25ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_25ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_25ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_25ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_25ENS: 63.8s
# ['z'] 0.05_26ENS 1번째 반복 +6h 2.29s
# ['z'] 0.05_26ENS 2번째 반복 +12h 2.29s
# ['z'] 0.05_26ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_26ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_26ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_26ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_26ENS 7번째 반복 +42h 2.29s
# ['z'] 0.05_26ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_26ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_26ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_26ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_26ENS 12번째 반복 +72h 2.29s
# ['z'] 0.05_26ENS 13번째 반복 +78h 2.29s
# ['z'] 0.05_26ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_26ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_26ENS 16번째 반복 +96h 2.29s
# ['z'] 0.05_26ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_26ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_26ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_26ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_26ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_26ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_26ENS 23번째 반복 +138h 2.29s
# ['z'] 0.05_26ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_26ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_26ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_26ENS 27번째 반복 +162h 2.29s
# ['z'] 0.05_26ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_26ENS: 63.8s
# ['z'] 0.05_27ENS 1번째 반복 +6h 2.31s
# ['z'] 0.05_27ENS 2번째 반복 +12h 2.29s
# ['z'] 0.05_27ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_27ENS 4번째 반복 +24h 2.56s
# ['z'] 0.05_27ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_27ENS 6번째 반복 +36h 2.29s
# ['z'] 0.05_27ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_27ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_27ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_27ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_27ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_27ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_27ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_27ENS 14번째 반복 +84h 2.31s
# ['z'] 0.05_27ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_27ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_27ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_27ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_27ENS 19번째 반복 +114h 2.29s
# ['z'] 0.05_27ENS 20번째 반복 +120h 2.29s
# ['z'] 0.05_27ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_27ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_27ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_27ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_27ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_27ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_27ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_27ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_27ENS: 64.1s
# ['z'] 0.05_28ENS 1번째 반복 +6h 2.30s
# ['z'] 0.05_28ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_28ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_28ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_28ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_28ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_28ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_28ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_28ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_28ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_28ENS 11번째 반복 +66h 2.30s
# ['z'] 0.05_28ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_28ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_28ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_28ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_28ENS 16번째 반복 +96h 2.29s
# ['z'] 0.05_28ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_28ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_28ENS 19번째 반복 +114h 2.29s
# ['z'] 0.05_28ENS 20번째 반복 +120h 2.29s
# ['z'] 0.05_28ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_28ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_28ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_28ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_28ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_28ENS 26번째 반복 +156h 2.29s
# ['z'] 0.05_28ENS 27번째 반복 +162h 2.31s
# ['z'] 0.05_28ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_28ENS: 63.9s
# ['z'] 0.05_29ENS 1번째 반복 +6h 2.30s
# ['z'] 0.05_29ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_29ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_29ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_29ENS 5번째 반복 +30h 2.29s
# ['z'] 0.05_29ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_29ENS 7번째 반복 +42h 2.30s
# ['z'] 0.05_29ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_29ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_29ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_29ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_29ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_29ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_29ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_29ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_29ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_29ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_29ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_29ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_29ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_29ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_29ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_29ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_29ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_29ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_29ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_29ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_29ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_29ENS: 63.7s
# ['z'] 0.05_30ENS 1번째 반복 +6h 2.33s
# ['z'] 0.05_30ENS 2번째 반복 +12h 2.30s
# ['z'] 0.05_30ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_30ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_30ENS 5번째 반복 +30h 2.29s
# ['z'] 0.05_30ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_30ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_30ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_30ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_30ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_30ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_30ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_30ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_30ENS 14번째 반복 +84h 2.29s
# ['z'] 0.05_30ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_30ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_30ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_30ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_30ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_30ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_30ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_30ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_30ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_30ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_30ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_30ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_30ENS 27번째 반복 +162h 2.29s
# ['z'] 0.05_30ENS 28번째 반복 +168h 2.30s
# ['z'] 0.05_30ENS: 63.9s
# ['z'] 0.05_31ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_31ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_31ENS 3번째 반복 +18h 2.29s
# ['z'] 0.05_31ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_31ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_31ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_31ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_31ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_31ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_31ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_31ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_31ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_31ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_31ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_31ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_31ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_31ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_31ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_31ENS 19번째 반복 +114h 2.30s
# ['z'] 0.05_31ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_31ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_31ENS 22번째 반복 +132h 2.29s
# ['z'] 0.05_31ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_31ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_31ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_31ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_31ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_31ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_31ENS: 63.8s
# ['z'] 0.05_32ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_32ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_32ENS 3번째 반복 +18h 2.29s
# ['z'] 0.05_32ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_32ENS 5번째 반복 +30h 2.29s
# ['z'] 0.05_32ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_32ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_32ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_32ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_32ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_32ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_32ENS 12번째 반복 +72h 2.31s
# ['z'] 0.05_32ENS 13번째 반복 +78h 2.30s
# ['z'] 0.05_32ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_32ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_32ENS 16번째 반복 +96h 2.29s
# ['z'] 0.05_32ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_32ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_32ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_32ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_32ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_32ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_32ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_32ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_32ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_32ENS 26번째 반복 +156h 2.29s
# ['z'] 0.05_32ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_32ENS 28번째 반복 +168h 2.30s
# ['z'] 0.05_32ENS: 63.9s
# ['z'] 0.05_33ENS 1번째 반복 +6h 2.44s
# ['z'] 0.05_33ENS 2번째 반복 +12h 2.30s
# ['z'] 0.05_33ENS 3번째 반복 +18h 2.30s
# ['z'] 0.05_33ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_33ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_33ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_33ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_33ENS 8번째 반복 +48h 2.29s
# ['z'] 0.05_33ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_33ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_33ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_33ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_33ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_33ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_33ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_33ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_33ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_33ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_33ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_33ENS 20번째 반복 +120h 2.29s
# ['z'] 0.05_33ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_33ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_33ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_33ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_33ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_33ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_33ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_33ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_33ENS: 64.0s
# ['z'] 0.05_34ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_34ENS 2번째 반복 +12h 2.32s
# ['z'] 0.05_34ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_34ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_34ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_34ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_34ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_34ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_34ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_34ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_34ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_34ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_34ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_34ENS 14번째 반복 +84h 2.29s
# ['z'] 0.05_34ENS 15번째 반복 +90h 2.29s
# ['z'] 0.05_34ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_34ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_34ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_34ENS 19번째 반복 +114h 2.32s
# ['z'] 0.05_34ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_34ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_34ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_34ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_34ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_34ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_34ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_34ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_34ENS 28번째 반복 +168h 2.30s
# ['z'] 0.05_34ENS: 63.9s
# ['z'] 0.05_35ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_35ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_35ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_35ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_35ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_35ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_35ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_35ENS 8번째 반복 +48h 2.29s
# ['z'] 0.05_35ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_35ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_35ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_35ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_35ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_35ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_35ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_35ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_35ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_35ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_35ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_35ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_35ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_35ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_35ENS 23번째 반복 +138h 2.30s
# ['z'] 0.05_35ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_35ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_35ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_35ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_35ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_35ENS: 63.8s
# ['z'] 0.05_36ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_36ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_36ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_36ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_36ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_36ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_36ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_36ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_36ENS 9번째 반복 +54h 2.30s
# ['z'] 0.05_36ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_36ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_36ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_36ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_36ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_36ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_36ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_36ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_36ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_36ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_36ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_36ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_36ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_36ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_36ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_36ENS 25번째 반복 +150h 2.28s
# ['z'] 0.05_36ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_36ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_36ENS 28번째 반복 +168h 2.30s
# ['z'] 0.05_36ENS: 63.8s
# ['z'] 0.05_37ENS 1번째 반복 +6h 2.29s
# ['z'] 0.05_37ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_37ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_37ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_37ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_37ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_37ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_37ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_37ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_37ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_37ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_37ENS 12번째 반복 +72h 2.29s
# ['z'] 0.05_37ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_37ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_37ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_37ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_37ENS 17번째 반복 +102h 2.29s
# ['z'] 0.05_37ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_37ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_37ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_37ENS 21번째 반복 +126h 2.32s
# ['z'] 0.05_37ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_37ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_37ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_37ENS 25번째 반복 +150h 2.29s
# ['z'] 0.05_37ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_37ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_37ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_37ENS: 63.8s
# ['z'] 0.05_38ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_38ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_38ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_38ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_38ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_38ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_38ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_38ENS 8번째 반복 +48h 2.28s
# ['z'] 0.05_38ENS 9번째 반복 +54h 2.29s
# ['z'] 0.05_38ENS 10번째 반복 +60h 2.29s
# ['z'] 0.05_38ENS 11번째 반복 +66h 2.28s
# ['z'] 0.05_38ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_38ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_38ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_38ENS 15번째 반복 +90h 2.28s
# ['z'] 0.05_38ENS 16번째 반복 +96h 2.30s
# ['z'] 0.05_38ENS 17번째 반복 +102h 2.33s
# ['z'] 0.05_38ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_38ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_38ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_38ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_38ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_38ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_38ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_38ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_38ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_38ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_38ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_38ENS: 63.9s
# ['z'] 0.05_39ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_39ENS 2번째 반복 +12h 2.29s
# ['z'] 0.05_39ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_39ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_39ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_39ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_39ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_39ENS 8번째 반복 +48h 2.29s
# ['z'] 0.05_39ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_39ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_39ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_39ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_39ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_39ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_39ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_39ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_39ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_39ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_39ENS 19번째 반복 +114h 2.30s
# ['z'] 0.05_39ENS 20번째 반복 +120h 2.29s
# ['z'] 0.05_39ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_39ENS 22번째 반복 +132h 2.29s
# ['z'] 0.05_39ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_39ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_39ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_39ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_39ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_39ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_39ENS: 63.8s
# ['z'] 0.05_40ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_40ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_40ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_40ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_40ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_40ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_40ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_40ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_40ENS 9번째 반복 +54h 2.28s
# ['z'] 0.05_40ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_40ENS 11번째 반복 +66h 2.29s
# ['z'] 0.05_40ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_40ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_40ENS 14번째 반복 +84h 2.29s
# ['z'] 0.05_40ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_40ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_40ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_40ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_40ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_40ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_40ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_40ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_40ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_40ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_40ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_40ENS 26번째 반복 +156h 2.28s
# ['z'] 0.05_40ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_40ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_40ENS: 63.7s
# ['z'] 0.05_41ENS 1번째 반복 +6h 2.31s
# ['z'] 0.05_41ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_41ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_41ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_41ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_41ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_41ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_41ENS 8번째 반복 +48h 2.29s
# ['z'] 0.05_41ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_41ENS 10번째 반복 +60h 2.30s
# ['z'] 0.05_41ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_41ENS 12번째 반복 +72h 2.28s
# ['z'] 0.05_41ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_41ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_41ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_41ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_41ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_41ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_41ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_41ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_41ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_41ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_41ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_41ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_41ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_41ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_41ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_41ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_41ENS: 63.8s
# ['z'] 0.05_42ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_42ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_42ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_42ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_42ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_42ENS 6번째 반복 +36h 3.92s
# ['z'] 0.05_42ENS 7번째 반복 +42h 8.82s
# ['z'] 0.05_42ENS 8번째 반복 +48h 5.18s
# ['z'] 0.05_42ENS 9번째 반복 +54h 6.68s
# ['z'] 0.05_42ENS 10번째 반복 +60h 5.46s
# ['z'] 0.05_42ENS 11번째 반복 +66h 6.57s
# ['z'] 0.05_42ENS 12번째 반복 +72h 4.12s
# ['z'] 0.05_42ENS 13번째 반복 +78h 3.72s
# ['z'] 0.05_42ENS 14번째 반복 +84h 3.99s
# ['z'] 0.05_42ENS 15번째 반복 +90h 8.61s
# ['z'] 0.05_42ENS 16번째 반복 +96h 3.74s
# ['z'] 0.05_42ENS 17번째 반복 +102h 4.13s
# ['z'] 0.05_42ENS 18번째 반복 +108h 5.76s
# ['z'] 0.05_42ENS 19번째 반복 +114h 5.65s
# ['z'] 0.05_42ENS 20번째 반복 +120h 6.40s
# ['z'] 0.05_42ENS 21번째 반복 +126h 8.74s
# ['z'] 0.05_42ENS 22번째 반복 +132h 8.68s
# ['z'] 0.05_42ENS 23번째 반복 +138h 8.77s
# ['z'] 0.05_42ENS 24번째 반복 +144h 4.55s
# ['z'] 0.05_42ENS 25번째 반복 +150h 8.49s
# ['z'] 0.05_42ENS 26번째 반복 +156h 5.03s
# ['z'] 0.05_42ENS 27번째 반복 +162h 5.88s
# ['z'] 0.05_42ENS 28번째 반복 +168h 8.64s
# ['z'] 0.05_42ENS: 152.9s
# ['z'] 0.05_43ENS 1번째 반복 +6h 8.98s
# ['z'] 0.05_43ENS 2번째 반복 +12h 6.56s
# ['z'] 0.05_43ENS 3번째 반복 +18h 9.00s
# ['z'] 0.05_43ENS 4번째 반복 +24h 6.45s
# ['z'] 0.05_43ENS 5번째 반복 +30h 5.61s
# ['z'] 0.05_43ENS 6번째 반복 +36h 5.42s
# ['z'] 0.05_43ENS 7번째 반복 +42h 8.24s
# ['z'] 0.05_43ENS 8번째 반복 +48h 8.24s
# ['z'] 0.05_43ENS 9번째 반복 +54h 4.50s
# ['z'] 0.05_43ENS 10번째 반복 +60h 4.78s
# ['z'] 0.05_43ENS 11번째 반복 +66h 9.17s
# ['z'] 0.05_43ENS 12번째 반복 +72h 9.33s
# ['z'] 0.05_43ENS 13번째 반복 +78h 9.64s
# ['z'] 0.05_43ENS 14번째 반복 +84h 6.58s
# ['z'] 0.05_43ENS 15번째 반복 +90h 9.03s
# ['z'] 0.05_43ENS 16번째 반복 +96h 10.53s
# ['z'] 0.05_43ENS 17번째 반복 +102h 4.13s
# ['z'] 0.05_43ENS 18번째 반복 +108h 3.98s
# ['z'] 0.05_43ENS 19번째 반복 +114h 4.02s
# ['z'] 0.05_43ENS 20번째 반복 +120h 3.89s
# ['z'] 0.05_43ENS 21번째 반복 +126h 4.01s
# ['z'] 0.05_43ENS 22번째 반복 +132h 3.98s
# ['z'] 0.05_43ENS 23번째 반복 +138h 4.11s
# ['z'] 0.05_43ENS 24번째 반복 +144h 4.06s
# ['z'] 0.05_43ENS 25번째 반복 +150h 4.13s
# ['z'] 0.05_43ENS 26번째 반복 +156h 10.53s
# ['z'] 0.05_43ENS 27번째 반복 +162h 11.66s
# ['z'] 0.05_43ENS 28번째 반복 +168h 12.12s
# ['z'] 0.05_43ENS: 192.7s
# ['z'] 0.05_44ENS 1번째 반복 +6h 11.76s
# ['z'] 0.05_44ENS 2번째 반복 +12h 5.21s
# ['z'] 0.05_44ENS 3번째 반복 +18h 4.54s
# ['z'] 0.05_44ENS 4번째 반복 +24h 3.88s
# ['z'] 0.05_44ENS 5번째 반복 +30h 8.20s
# ['z'] 0.05_44ENS 6번째 반복 +36h 8.86s
# ['z'] 0.05_44ENS 7번째 반복 +42h 11.72s
# ['z'] 0.05_44ENS 8번째 반복 +48h 8.88s
# ['z'] 0.05_44ENS 9번째 반복 +54h 12.28s
# ['z'] 0.05_44ENS 10번째 반복 +60h 8.73s
# ['z'] 0.05_44ENS 11번째 반복 +66h 11.67s
# ['z'] 0.05_44ENS 12번째 반복 +72h 8.82s
# ['z'] 0.05_44ENS 13번째 반복 +78h 11.64s
# ['z'] 0.05_44ENS 14번째 반복 +84h 8.98s
# ['z'] 0.05_44ENS 15번째 반복 +90h 4.64s
# ['z'] 0.05_44ENS 16번째 반복 +96h 3.70s
# ['z'] 0.05_44ENS 17번째 반복 +102h 4.23s
# ['z'] 0.05_44ENS 18번째 반복 +108h 9.11s
# ['z'] 0.05_44ENS 19번째 반복 +114h 11.56s
# ['z'] 0.05_44ENS 20번째 반복 +120h 8.99s
# ['z'] 0.05_44ENS 21번째 반복 +126h 10.93s
# ['z'] 0.05_44ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_44ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_44ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_44ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_44ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_44ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_44ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_44ENS: 194.2s
# ['z'] 0.05_45ENS 1번째 반복 +6h 2.31s
# ['z'] 0.05_45ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_45ENS 3번째 반복 +18h 2.29s
# ['z'] 0.05_45ENS 4번째 반복 +24h 2.28s
# ['z'] 0.05_45ENS 5번째 반복 +30h 2.28s
# ['z'] 0.05_45ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_45ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_45ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_45ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_45ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_45ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_45ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_45ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_45ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_45ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_45ENS 16번째 반복 +96h 2.32s
# ['z'] 0.05_45ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_45ENS 18번째 반복 +108h 2.30s
# ['z'] 0.05_45ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_45ENS 20번째 반복 +120h 2.29s
# ['z'] 0.05_45ENS 21번째 반복 +126h 2.29s
# ['z'] 0.05_45ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_45ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_45ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_45ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_45ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_45ENS 27번째 반복 +162h 2.28s
# ['z'] 0.05_45ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_45ENS: 63.9s
# ['z'] 0.05_46ENS 1번째 반복 +6h 2.28s
# ['z'] 0.05_46ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_46ENS 3번째 반복 +18h 2.29s
# ['z'] 0.05_46ENS 4번째 반복 +24h 2.29s
# ['z'] 0.05_46ENS 5번째 반복 +30h 2.29s
# ['z'] 0.05_46ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_46ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_46ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_46ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_46ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_46ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_46ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_46ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_46ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_46ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_46ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_46ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_46ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_46ENS 19번째 반복 +114h 2.27s
# ...
# ['z'] 0.05_84ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_84ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_84ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_84ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_84ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_84ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_84ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_84ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_84ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_84ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_84ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_84ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_84ENS: 63.6s
# ['z'] 0.05_85ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_85ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_85ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_85ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_85ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_85ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_85ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_85ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_85ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_85ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_85ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_85ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_85ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_85ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_85ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_85ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_85ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_85ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_85ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_85ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_85ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_85ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_85ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_85ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_85ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_85ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_85ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_85ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_85ENS: 63.6s
# ['z'] 0.05_86ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_86ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_86ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_86ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_86ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_86ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_86ENS 7번째 반복 +42h 2.29s
# ['z'] 0.05_86ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_86ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_86ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_86ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_86ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_86ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_86ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_86ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_86ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_86ENS 17번째 반복 +102h 2.31s
# ['z'] 0.05_86ENS 18번째 반복 +108h 2.29s
# ['z'] 0.05_86ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_86ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_86ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_86ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_86ENS 23번째 반복 +138h 2.28s
# ['z'] 0.05_86ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_86ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_86ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_86ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_86ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_86ENS: 63.7s
# ['z'] 0.05_87ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_87ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_87ENS 3번째 반복 +18h 2.44s
# ['z'] 0.05_87ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_87ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_87ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_87ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_87ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_87ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_87ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_87ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_87ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_87ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_87ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_87ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_87ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_87ENS 17번째 반복 +102h 2.30s
# ['z'] 0.05_87ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_87ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_87ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_87ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_87ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_87ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_87ENS 24번째 반복 +144h 2.28s
# ['z'] 0.05_87ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_87ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_87ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_87ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_87ENS: 63.8s
# ['z'] 0.05_88ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_88ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_88ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_88ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_88ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_88ENS 6번째 반복 +36h 2.29s
# ['z'] 0.05_88ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_88ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_88ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_88ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_88ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_88ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_88ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_88ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_88ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_88ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_88ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_88ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_88ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_88ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_88ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_88ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_88ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_88ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_88ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_88ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_88ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_88ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_88ENS: 63.7s
# ['z'] 0.05_89ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_89ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_89ENS 3번째 반복 +18h 2.28s
# ['z'] 0.05_89ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_89ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_89ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_89ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_89ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_89ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_89ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_89ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_89ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_89ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_89ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_89ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_89ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_89ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_89ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_89ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_89ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_89ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_89ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_89ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_89ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_89ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_89ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_89ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_89ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_89ENS: 63.7s
# ['z'] 0.05_90ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_90ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_90ENS 3번째 반복 +18h 2.30s
# ['z'] 0.05_90ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_90ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_90ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_90ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_90ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_90ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_90ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_90ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_90ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_90ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_90ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_90ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_90ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_90ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_90ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_90ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_90ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_90ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_90ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_90ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_90ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_90ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_90ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_90ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_90ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_90ENS: 63.6s
# ['z'] 0.05_91ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_91ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_91ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_91ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_91ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_91ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_91ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_91ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_91ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_91ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_91ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_91ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_91ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_91ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_91ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_91ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_91ENS 17번째 반복 +102h 2.30s
# ['z'] 0.05_91ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_91ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_91ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_91ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_91ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_91ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_91ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_91ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_91ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_91ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_91ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_91ENS: 63.7s
# ['z'] 0.05_92ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_92ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_92ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_92ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_92ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_92ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_92ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_92ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_92ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_92ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_92ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_92ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_92ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_92ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_92ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_92ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_92ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_92ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_92ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_92ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_92ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_92ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_92ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_92ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_92ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_92ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_92ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_92ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_92ENS: 63.6s
# ['z'] 0.05_93ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_93ENS 2번째 반복 +12h 2.28s
# ['z'] 0.05_93ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_93ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_93ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_93ENS 6번째 반복 +36h 2.28s
# ['z'] 0.05_93ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_93ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_93ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_93ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_93ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_93ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_93ENS 13번째 반복 +78h 2.28s
# ['z'] 0.05_93ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_93ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_93ENS 16번째 반복 +96h 2.28s
# ['z'] 0.05_93ENS 17번째 반복 +102h 2.29s
# ['z'] 0.05_93ENS 18번째 반복 +108h 2.28s
# ['z'] 0.05_93ENS 19번째 반복 +114h 2.29s
# ['z'] 0.05_93ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_93ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_93ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_93ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_93ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_93ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_93ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_93ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_93ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_93ENS: 63.7s
# ['z'] 0.05_94ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_94ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_94ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_94ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_94ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_94ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_94ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_94ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_94ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_94ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_94ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_94ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_94ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_94ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_94ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_94ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_94ENS 17번째 반복 +102h 2.30s
# ['z'] 0.05_94ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_94ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_94ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_94ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_94ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_94ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_94ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_94ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_94ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_94ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_94ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_94ENS: 63.6s
# ['z'] 0.05_95ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_95ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_95ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_95ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_95ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_95ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_95ENS 7번째 반복 +42h 2.29s
# ['z'] 0.05_95ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_95ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_95ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_95ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_95ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_95ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_95ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_95ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_95ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_95ENS 17번째 반복 +102h 2.31s
# ['z'] 0.05_95ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_95ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_95ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_95ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_95ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_95ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_95ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_95ENS 25번째 반복 +150h 2.29s
# ['z'] 0.05_95ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_95ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_95ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_95ENS: 63.7s
# ['z'] 0.05_96ENS 1번째 반복 +6h 2.27s
# ['z'] 0.05_96ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_96ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_96ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_96ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_96ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_96ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_96ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_96ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_96ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_96ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_96ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_96ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_96ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_96ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_96ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_96ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_96ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_96ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_96ENS 20번째 반복 +120h 2.28s
# ['z'] 0.05_96ENS 21번째 반복 +126h 2.28s
# ['z'] 0.05_96ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_96ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_96ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_96ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_96ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_96ENS 27번째 반복 +162h 5.43s
# ['z'] 0.05_96ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_96ENS: 66.8s
# ['z'] 0.05_97ENS 1번째 반복 +6h 4.21s
# ['z'] 0.05_97ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_97ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_97ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_97ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_97ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_97ENS 7번째 반복 +42h 2.28s
# ['z'] 0.05_97ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_97ENS 9번째 반복 +54h 2.32s
# ['z'] 0.05_97ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_97ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_97ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_97ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_97ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_97ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_97ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_97ENS 17번째 반복 +102h 2.28s
# ['z'] 0.05_97ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_97ENS 19번째 반복 +114h 2.28s
# ['z'] 0.05_97ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_97ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_97ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_97ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_97ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_97ENS 25번째 반복 +150h 2.74s
# ['z'] 0.05_97ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_97ENS 27번째 반복 +162h 2.29s
# ['z'] 0.05_97ENS 28번째 반복 +168h 2.28s
# ['z'] 0.05_97ENS: 66.1s
# ['z'] 0.05_98ENS 1번째 반복 +6h 2.44s
# ['z'] 0.05_98ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_98ENS 3번째 반복 +18h 2.29s
# ['z'] 0.05_98ENS 4번째 반복 +24h 2.34s
# ['z'] 0.05_98ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_98ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_98ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_98ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_98ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_98ENS 10번째 반복 +60h 2.28s
# ['z'] 0.05_98ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_98ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_98ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_98ENS 14번째 반복 +84h 2.27s
# ['z'] 0.05_98ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_98ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_98ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_98ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_98ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_98ENS 20번째 반복 +120h 3.14s
# ['z'] 0.05_98ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_98ENS 22번째 반복 +132h 2.27s
# ['z'] 0.05_98ENS 23번째 반복 +138h 2.27s
# ['z'] 0.05_98ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_98ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_98ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_98ENS 27번째 반복 +162h 2.29s
# ['z'] 0.05_98ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_98ENS: 64.8s
# ['z'] 0.05_99ENS 1번째 반복 +6h 3.97s
# ['z'] 0.05_99ENS 2번째 반복 +12h 2.27s
# ['z'] 0.05_99ENS 3번째 반복 +18h 2.27s
# ['z'] 0.05_99ENS 4번째 반복 +24h 2.27s
# ['z'] 0.05_99ENS 5번째 반복 +30h 2.27s
# ['z'] 0.05_99ENS 6번째 반복 +36h 2.27s
# ['z'] 0.05_99ENS 7번째 반복 +42h 2.27s
# ['z'] 0.05_99ENS 8번째 반복 +48h 2.27s
# ['z'] 0.05_99ENS 9번째 반복 +54h 2.27s
# ['z'] 0.05_99ENS 10번째 반복 +60h 2.27s
# ['z'] 0.05_99ENS 11번째 반복 +66h 2.27s
# ['z'] 0.05_99ENS 12번째 반복 +72h 2.27s
# ['z'] 0.05_99ENS 13번째 반복 +78h 2.27s
# ['z'] 0.05_99ENS 14번째 반복 +84h 2.28s
# ['z'] 0.05_99ENS 15번째 반복 +90h 2.27s
# ['z'] 0.05_99ENS 16번째 반복 +96h 2.27s
# ['z'] 0.05_99ENS 17번째 반복 +102h 2.27s
# ['z'] 0.05_99ENS 18번째 반복 +108h 2.27s
# ['z'] 0.05_99ENS 19번째 반복 +114h 2.27s
# ['z'] 0.05_99ENS 20번째 반복 +120h 2.27s
# ['z'] 0.05_99ENS 21번째 반복 +126h 2.27s
# ['z'] 0.05_99ENS 22번째 반복 +132h 2.28s
# ['z'] 0.05_99ENS 23번째 반복 +138h 2.29s
# ['z'] 0.05_99ENS 24번째 반복 +144h 2.27s
# ['z'] 0.05_99ENS 25번째 반복 +150h 2.27s
# ['z'] 0.05_99ENS 26번째 반복 +156h 2.27s
# ['z'] 0.05_99ENS 27번째 반복 +162h 2.27s
# ['z'] 0.05_99ENS 28번째 반복 +168h 2.27s
# ['z'] 0.05_99ENS: 65.3s
