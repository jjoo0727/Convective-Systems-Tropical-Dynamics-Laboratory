# %%
#%%
import torch
import onnxruntime as ort
import os
import numpy as np
import onnx
import time
import itertools

lat_indices = np.linspace(90, -90, 721)
lon_indices = np.linspace(-180, 180, 1441)[:-1]

def latlon_extent(lon_min, lon_max, lat_min, lat_max):    
    lon_min, lon_max = lon_min-180, lon_max-180  
     
    # 위경도 범위를 데이터의 행과 열 인덱스로 변환
    lat_start = np.argmin(np.abs(lat_indices - lat_max)) 
    lat_end = np.argmin(np.abs(lat_indices - lat_min))
    lon_start = np.argmin(np.abs(lon_indices - lon_min))
    lon_end = np.argmin(np.abs(lon_indices - lon_max))
    latlon_ratio = (lon_max-lon_min)/(lat_max-lat_min)
    extent=[lon_min, lon_max, lat_min, lat_max]
    return lat_start, lat_end, lon_start, lon_end, extent, latlon_ratio

lat_start, lat_end, lon_start, lon_end, extent, latlon_ratio = latlon_extent(250,310,5,45)  


year = ['2012']
month = ['06']
day = ['23']
times = ['00']
# ens_num = 100
ens_list = range(2050,4000)
perturbation_scale_list =[0.1]
factor_list_list = [['z']] 
# surface_factors.sort()
# upper_factors.sort()
# surface_str = "".join([f"_{factor}" for factor in surface_factors])  # 각 요소 앞에 _ 추가
# upper_str = "".join([f"_{factor}" for factor in upper_factors])  # 각 요소 앞에 _ 추가
pangu_dir = r'/home1/jek/Pangu-Weather'

surface_factor = ['MSLP', 'U10', 'V10', 'T2M']
surface_dict = {'MSLP':0, 'U10':1, 'V10':2, 'T2M':3}
upper_factor = ['z', 'q', 't', 'u', 'v']
upper_dict = {'z':0, 'q':1, 't':2, 'u':3, 'v':4}


# Set the behavior of onnxruntime
options = ort.SessionOptions()
options.enable_cpu_mem_arena= True
options.enable_mem_pattern = False
options.enable_mem_reuse = False

# Increase the number for faster inference and more memory consumption
# options.intra_op_num_threads = 1

# Set the behavior of cuda provider for the first GPU
cuda_provider_options_gpu0 = {'arena_extend_strategy': 'kSameAsRequested', 'device_id': 0}

# Set the behavior of cuda provider for the second GPU
cuda_provider_options_gpu1 = {'arena_extend_strategy': 'kSameAsRequested', 'device_id': 1}

# Initialize onnxruntime session for Pangu-Weather Models on different GPUs
ort_session_6 = ort.InferenceSession(rf'{pangu_dir}/pangu_weather_6.onnx', sess_options=options, providers=[('CUDAExecutionProvider', cuda_provider_options_gpu1)])
ort_session_24 = ort.InferenceSession(rf'{pangu_dir}/pangu_weather_24.onnx', sess_options=options, providers=[('CUDAExecutionProvider', cuda_provider_options_gpu1)])


start = time.time()

for factor_list in factor_list_list:
    for perturbation_scale in perturbation_scale_list:
        for y, m, d, tm in itertools.product(year, month, day, times):
            time_str = f'{y}/{m}/{d}/{tm}UTC'

            input_data_dir = rf'{pangu_dir}/input_data/{time_str}'
            output_data_dir = rf'/data03/Pangu_TC_ENS/output_data/{time_str}'

            input_upper = np.load(os.path.join(input_data_dir, 'upper.npy')).astype(np.float32)
            input_surface = np.load(os.path.join(input_data_dir, 'surface.npy')).astype(np.float32)


            
            std_dev_upper = np.std(input_upper, axis=(2, 3), dtype=np.float32)*perturbation_scale
            std_dev_surface = np.std(input_surface, axis=(1, 2), dtype=np.float32)*perturbation_scale


            factor_str = "".join([f"_{f}" for f in factor_list])

            for ens in ens_list:
                output_data_dir = rf'/data03/Pangu_TC_ENS/output_data/{time_str}/{perturbation_scale}ENS{factor_str}/{ens}'
                # output_data_dir = rf'/data03/Pangu_TC_ENS/output_data/{time_str}/{ens}'
                
                if not os.path.exists(os.path.join(output_data_dir, f'upper')):
                    os.makedirs(os.path.join(output_data_dir, f'upper'))
                if not os.path.exists(os.path.join(output_data_dir, f'surface')):
                    os.makedirs(os.path.join(output_data_dir, f'surface'))
                
                
                perturbed_upper = input_upper.copy()
                perturbed_surface = input_surface.copy()
                seed_val = hash((ens, tuple(factor_list), perturbation_scale)) % (2**32)
                rng = np.random.default_rng(seed_val)  # 새로운 난수 생성기
                # Perturbation 생성 및 적용     
                if ens == 0:
                    pass
                    
                # else:
                #     for factor in factor_list:
                #         if factor in upper_dict:
                #             idx = upper_dict[factor]
                #             for j in range(13):
                #                 perturbation = np.random.normal(0, std_dev_upper[idx, j], input_upper[idx, j].shape)
                #                 perturbed_upper[idx, j] = input_upper[idx, j] + perturbation.astype(np.float32)
                        
                #         elif factor in surface_dict:
                #             idx = surface_dict[factor]
                #             perturbation = np.random.normal(0, std_dev_surface[idx], input_surface[idx].shape)
                #             perturbed_surface[idx] = input_upper[idx] + perturbation.astype(np.float32)

                else:
                    for factor in factor_list:
                        if factor in upper_dict:
                            idx = upper_dict[factor]
                            for j in range(13):
                                perturbation = rng.normal(0, std_dev_upper[idx, j], input_upper[idx, j].shape)
                                perturbed_upper[idx, j] = input_upper[idx, j] + perturbation.astype(np.float32)
                        elif factor in surface_dict:
                            idx = surface_dict[factor]
                            perturbation = rng.normal(0, std_dev_surface[idx], input_surface[idx].shape)
                            perturbed_surface[idx] = input_upper[idx] + perturbation.astype(np.float32)

                    
                    # for factor_index, factor_name in enumerate(surface_factor):  # 지표면 변수 반복
                    #     if factor_name in surface_factor:
                    #         perturbation = np.random.normal(0, std_dev_surface[factor_index], input_surface[factor_index].shape)
                    #         perturbed_surface[factor_index] = input_surface[factor_index] + perturbation.astype(np.float32)
                    #     else:
                    #         perturbed_surface[factor_index] = input_surface[factor_index]
                    

                    
                np.save(os.path.join(output_data_dir, f'upper/0h'), perturbed_upper[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                np.save(os.path.join(output_data_dir, f'surface/0h'), perturbed_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])

                perturbed_24, perturbed_surface_24 = perturbed_upper, perturbed_surface

                for i in range(28):
                    start_i = time.time()
                    predict_interval = 6*(i+1)
                    if (i+1) % 4 == 0:
                        output, output_surface = ort_session_24.run(None, {'input':perturbed_24, 'input_surface':perturbed_surface_24})
                        perturbed_24, perturbed_surface_24 = output, output_surface
                        np.save(os.path.join(output_data_dir, f'upper/{predict_interval}h'), output[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                        np.save(os.path.join(output_data_dir, f'surface/{predict_interval}h'), output_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])
                        


                    # 6시간 간격도 저장하고 싶으면 주석 해제
                    else:
                        output, output_surface = ort_session_6.run(None, {'input':perturbed_upper, 'input_surface':perturbed_surface})
                        np.save(os.path.join(output_data_dir, f'upper/{predict_interval}h'), output[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                        np.save(os.path.join(output_data_dir, f'surface/{predict_interval}h'), output_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])

                    perturbed_upper, perturbed_surface = output, output_surface
                    end_i = time.time()
                    print(f'{factor_list} {perturbation_scale}_{ens}ENS {i+1}번째 반복 +{predict_interval}h {end_i-start_i}s')
                

                end = time.time()
                print(f"{factor_list} {perturbation_scale}_{ens}ENS: {end-start}s")
# Out:
# ['z'] 0.1_2050ENS 1번째 반복 +6h 2.4328982830047607s
# ['z'] 0.1_2050ENS 2번째 반복 +12h 2.2610182762145996s
# ['z'] 0.1_2050ENS 3번째 반복 +18h 2.261824369430542s
# ['z'] 0.1_2050ENS 4번째 반복 +24h 2.4383230209350586s
# ['z'] 0.1_2050ENS 5번째 반복 +30h 2.2771072387695312s
# ['z'] 0.1_2050ENS 6번째 반복 +36h 2.261852502822876s
# ['z'] 0.1_2050ENS 7번째 반복 +42h 2.2606492042541504s
# ['z'] 0.1_2050ENS 8번째 반복 +48h 2.262373208999634s
# ['z'] 0.1_2050ENS 9번째 반복 +54h 2.2610645294189453s
# ['z'] 0.1_2050ENS 10번째 반복 +60h 2.2616019248962402s
# ['z'] 0.1_2050ENS 11번째 반복 +66h 2.2621452808380127s
# ['z'] 0.1_2050ENS 12번째 반복 +72h 2.262263774871826s
# ['z'] 0.1_2050ENS 13번째 반복 +78h 2.2758758068084717s
# ['z'] 0.1_2050ENS 14번째 반복 +84h 2.2628283500671387s
# ['z'] 0.1_2050ENS 15번째 반복 +90h 2.261746406555176s
# ['z'] 0.1_2050ENS 16번째 반복 +96h 2.261871337890625s
# ['z'] 0.1_2050ENS 17번째 반복 +102h 2.2626149654388428s
# ['z'] 0.1_2050ENS 18번째 반복 +108h 2.26381254196167s
# ['z'] 0.1_2050ENS 19번째 반복 +114h 2.262053966522217s
# ['z'] 0.1_2050ENS 20번째 반복 +120h 2.265017032623291s
# ['z'] 0.1_2050ENS 21번째 반복 +126h 2.2627272605895996s
# ['z'] 0.1_2050ENS 22번째 반복 +132h 2.2635817527770996s
# ['z'] 0.1_2050ENS 23번째 반복 +138h 2.2627899646759033s
# ['z'] 0.1_2050ENS 24번째 반복 +144h 2.2629764080047607s
# ['z'] 0.1_2050ENS 25번째 반복 +150h 2.2610607147216797s
# ['z'] 0.1_2050ENS 26번째 반복 +156h 2.2641890048980713s
# ['z'] 0.1_2050ENS 27번째 반복 +162h 2.262302875518799s
# ['z'] 0.1_2050ENS 28번째 반복 +168h 2.2639877796173096s
# ['z'] 0.1_2050ENS: 64.33659434318542s
# ['z'] 0.1_2051ENS 1번째 반복 +6h 2.2642226219177246s
# ['z'] 0.1_2051ENS 2번째 반복 +12h 2.263493299484253s
# ['z'] 0.1_2051ENS 3번째 반복 +18h 2.2623682022094727s
# ['z'] 0.1_2051ENS 4번째 반복 +24h 2.2633705139160156s
# ['z'] 0.1_2051ENS 5번째 반복 +30h 2.26192045211792s
# ['z'] 0.1_2051ENS 6번째 반복 +36h 2.262617349624634s
# ['z'] 0.1_2051ENS 7번째 반복 +42h 2.261714458465576s
# ['z'] 0.1_2051ENS 8번째 반복 +48h 2.2618930339813232s
# ['z'] 0.1_2051ENS 9번째 반복 +54h 2.2613489627838135s
# ['z'] 0.1_2051ENS 10번째 반복 +60h 2.2631609439849854s
# ['z'] 0.1_2051ENS 11번째 반복 +66h 2.263195037841797s
# ['z'] 0.1_2051ENS 12번째 반복 +72h 2.2633111476898193s
# ['z'] 0.1_2051ENS 13번째 반복 +78h 2.262094259262085s
# ['z'] 0.1_2051ENS 14번째 반복 +84h 2.2631545066833496s
# ['z'] 0.1_2051ENS 15번째 반복 +90h 2.262242317199707s
# ['z'] 0.1_2051ENS 16번째 반복 +96h 2.2621819972991943s
# ['z'] 0.1_2051ENS 17번째 반복 +102h 2.2804155349731445s
# ['z'] 0.1_2051ENS 18번째 반복 +108h 2.264230489730835s
# ['z'] 0.1_2051ENS 19번째 반복 +114h 2.2624940872192383s
# ['z'] 0.1_2051ENS 20번째 반복 +120h 2.2633509635925293s
# ['z'] 0.1_2051ENS 21번째 반복 +126h 2.2629990577697754s
# ['z'] 0.1_2051ENS 22번째 반복 +132h 2.3347413539886475s
# ['z'] 0.1_2051ENS 23번째 반복 +138h 2.262439012527466s
# ['z'] 0.1_2051ENS 24번째 반복 +144h 2.2635743618011475s
# ['z'] 0.1_2051ENS 25번째 반복 +150h 2.261310338973999s
# ['z'] 0.1_2051ENS 26번째 반복 +156h 2.2624804973602295s
# ['z'] 0.1_2051ENS 27번째 반복 +162h 2.2628707885742188s
# ['z'] 0.1_2051ENS 28번째 반복 +168h 2.264340400695801s
# ['z'] 0.1_2051ENS: 128.13053011894226s
# ['z'] 0.1_2052ENS 1번째 반복 +6h 2.2650461196899414s
# ['z'] 0.1_2052ENS 2번째 반복 +12h 2.264598846435547s
# ['z'] 0.1_2052ENS 3번째 반복 +18h 2.2635161876678467s
# ['z'] 0.1_2052ENS 4번째 반복 +24h 2.26450514793396s
# ['z'] 0.1_2052ENS 5번째 반복 +30h 2.2627763748168945s
# ['z'] 0.1_2052ENS 6번째 반복 +36h 2.263819456100464s
# ['z'] 0.1_2052ENS 7번째 반복 +42h 2.262141466140747s
# ['z'] 0.1_2052ENS 8번째 반복 +48h 2.2623655796051025s
# ['z'] 0.1_2052ENS 9번째 반복 +54h 2.2623653411865234s
# ['z'] 0.1_2052ENS 10번째 반복 +60h 2.2642195224761963s
# ['z'] 0.1_2052ENS 11번째 반복 +66h 2.2626237869262695s
# ['z'] 0.1_2052ENS 12번째 반복 +72h 2.26416015625s
# ['z'] 0.1_2052ENS 13번째 반복 +78h 2.27089786529541s
# ['z'] 0.1_2052ENS 14번째 반복 +84h 2.264291286468506s
# ['z'] 0.1_2052ENS 15번째 반복 +90h 2.2632577419281006s
# ['z'] 0.1_2052ENS 16번째 반복 +96h 2.262214422225952s
# ['z'] 0.1_2052ENS 17번째 반복 +102h 2.2620816230773926s
# ['z'] 0.1_2052ENS 18번째 반복 +108h 2.2640464305877686s
# ['z'] 0.1_2052ENS 19번째 반복 +114h 2.2630932331085205s
# ['z'] 0.1_2052ENS 20번째 반복 +120h 2.263856887817383s
# ['z'] 0.1_2052ENS 21번째 반복 +126h 2.2623748779296875s
# ['z'] 0.1_2052ENS 22번째 반복 +132h 2.263596773147583s
# ['z'] 0.1_2052ENS 23번째 반복 +138h 2.2637031078338623s
# ['z'] 0.1_2052ENS 24번째 반복 +144h 2.2630228996276855s
# ['z'] 0.1_2052ENS 25번째 반복 +150h 2.261312246322632s
# ['z'] 0.1_2052ENS 26번째 반복 +156h 2.2632217407226562s
# ['z'] 0.1_2052ENS 27번째 반복 +162h 2.262892961502075s
# ['z'] 0.1_2052ENS 28번째 반복 +168h 2.2628653049468994s
# ['z'] 0.1_2052ENS: 191.82810187339783s
# ['z'] 0.1_2053ENS 1번째 반복 +6h 2.2637062072753906s
# ['z'] 0.1_2053ENS 2번째 반복 +12h 2.2622365951538086s
# ['z'] 0.1_2053ENS 3번째 반복 +18h 2.263643980026245s
# ['z'] 0.1_2053ENS 4번째 반복 +24h 2.2640397548675537s
# ['z'] 0.1_2053ENS 5번째 반복 +30h 2.262979030609131s
# ['z'] 0.1_2053ENS 6번째 반복 +36h 2.2639434337615967s
# ['z'] 0.1_2053ENS 7번째 반복 +42h 2.262441635131836s
# ['z'] 0.1_2053ENS 8번째 반복 +48h 2.2626514434814453s
# ['z'] 0.1_2053ENS 9번째 반복 +54h 2.2629942893981934s
# ['z'] 0.1_2053ENS 10번째 반복 +60h 2.2632510662078857s
# ['z'] 0.1_2053ENS 11번째 반복 +66h 2.26257061958313s
# ['z'] 0.1_2053ENS 12번째 반복 +72h 2.263814687728882s
# ['z'] 0.1_2053ENS 13번째 반복 +78h 2.260770320892334s
# ['z'] 0.1_2053ENS 14번째 반복 +84h 2.2634952068328857s
# ['z'] 0.1_2053ENS 15번째 반복 +90h 2.2628440856933594s
# ['z'] 0.1_2053ENS 16번째 반복 +96h 2.259854793548584s
# ['z'] 0.1_2053ENS 17번째 반복 +102h 2.2597620487213135s
# ['z'] 0.1_2053ENS 18번째 반복 +108h 2.260869264602661s
# ['z'] 0.1_2053ENS 19번째 반복 +114h 2.259061813354492s
# ['z'] 0.1_2053ENS 20번째 반복 +120h 2.2603795528411865s
# ['z'] 0.1_2053ENS 21번째 반복 +126h 2.258251428604126s
# ['z'] 0.1_2053ENS 22번째 반복 +132h 2.2600064277648926s
# ['z'] 0.1_2053ENS 23번째 반복 +138h 2.259537935256958s
# ['z'] 0.1_2053ENS 24번째 반복 +144h 2.2593600749969482s
# ['z'] 0.1_2053ENS 25번째 반복 +150h 2.2579939365386963s
# ['z'] 0.1_2053ENS 26번째 반복 +156h 2.2590177059173584s
# ['z'] 0.1_2053ENS 27번째 반복 +162h 2.258049249649048s
# ['z'] 0.1_2053ENS 28번째 반복 +168h 2.25978422164917s
# ['z'] 0.1_2053ENS: 255.49153399467468s
# ['z'] 0.1_2054ENS 1번째 반복 +6h 2.261160135269165s
# ['z'] 0.1_2054ENS 2번째 반복 +12h 2.261526107788086s
# ['z'] 0.1_2054ENS 3번째 반복 +18h 2.2611474990844727s
# ['z'] 0.1_2054ENS 4번째 반복 +24h 2.261963367462158s
# ['z'] 0.1_2054ENS 5번째 반복 +30h 2.258521556854248s
# ['z'] 0.1_2054ENS 6번째 반복 +36h 2.2605044841766357s
# ['z'] 0.1_2054ENS 7번째 반복 +42h 2.2579729557037354s
# ['z'] 0.1_2054ENS 8번째 반복 +48h 2.2589309215545654s
# ['z'] 0.1_2054ENS 9번째 반복 +54h 2.2584757804870605s
# ['z'] 0.1_2054ENS 10번째 반복 +60h 2.259674310684204s
# ['z'] 0.1_2054ENS 11번째 반복 +66h 2.25907039642334s
# ['z'] 0.1_2054ENS 12번째 반복 +72h 2.2610466480255127s
# ['z'] 0.1_2054ENS 13번째 반복 +78h 2.2585465908050537s
# ['z'] 0.1_2054ENS 14번째 반복 +84h 2.2603325843811035s
# ['z'] 0.1_2054ENS 15번째 반복 +90h 2.258976697921753s
# ['z'] 0.1_2054ENS 16번째 반복 +96h 2.2586498260498047s
# ['z'] 0.1_2054ENS 17번째 반복 +102h 2.2588658332824707s
# ['z'] 0.1_2054ENS 18번째 반복 +108h 2.259878635406494s
# ['z'] 0.1_2054ENS 19번째 반복 +114h 2.291677474975586s
# ['z'] 0.1_2054ENS 20번째 반복 +120h 2.26002836227417s
# ['z'] 0.1_2054ENS 21번째 반복 +126h 2.257765293121338s
# ['z'] 0.1_2054ENS 22번째 반복 +132h 2.2607009410858154s
# ['z'] 0.1_2054ENS 23번째 반복 +138h 2.2587225437164307s
# ['z'] 0.1_2054ENS 24번째 반복 +144h 2.2591474056243896s
# ['z'] 0.1_2054ENS 25번째 반복 +150h 2.258784055709839s
# ['z'] 0.1_2054ENS 26번째 반복 +156h 2.258667469024658s
# ['z'] 0.1_2054ENS 27번째 반복 +162h 2.2590198516845703s
# ['z'] 0.1_2054ENS 28번째 반복 +168h 2.260300397872925s
# ['z'] 0.1_2054ENS: 319.1070508956909s
# ['z'] 0.1_2055ENS 1번째 반복 +6h 2.2609877586364746s
# ['z'] 0.1_2055ENS 2번째 반복 +12h 2.259533643722534s
# ['z'] 0.1_2055ENS 3번째 반복 +18h 2.2599704265594482s
# ['z'] 0.1_2055ENS 4번째 반복 +24h 2.2600393295288086s
# ['z'] 0.1_2055ENS 5번째 반복 +30h 2.257505416870117s
# ['z'] 0.1_2055ENS 6번째 반복 +36h 2.259873390197754s
# ['z'] 0.1_2055ENS 7번째 반복 +42h 2.2586357593536377s
# ['z'] 0.1_2055ENS 8번째 반복 +48h 2.25895619392395s
# ['z'] 0.1_2055ENS 9번째 반복 +54h 2.258338689804077s
# ['z'] 0.1_2055ENS 10번째 반복 +60h 2.259999990463257s
# ['z'] 0.1_2055ENS 11번째 반복 +66h 2.2592413425445557s
# ['z'] 0.1_2055ENS 12번째 반복 +72h 2.260007619857788s
# ['z'] 0.1_2055ENS 13번째 반복 +78h 2.2583837509155273s
# ['z'] 0.1_2055ENS 14번째 반복 +84h 2.2601418495178223s
# ['z'] 0.1_2055ENS 15번째 반복 +90h 2.2589104175567627s
# ['z'] 0.1_2055ENS 16번째 반복 +96h 2.2599682807922363s
# ['z'] 0.1_2055ENS 17번째 반복 +102h 2.257441282272339s
# ['z'] 0.1_2055ENS 18번째 반복 +108h 2.259976625442505s
# ['z'] 0.1_2055ENS 19번째 반복 +114h 2.2605338096618652s
# ['z'] 0.1_2055ENS 20번째 반복 +120h 2.2604217529296875s
# ['z'] 0.1_2055ENS 21번째 반복 +126h 2.2576990127563477s
# ['z'] 0.1_2055ENS 22번째 반복 +132h 2.2604947090148926s
# ['z'] 0.1_2055ENS 23번째 반복 +138h 2.2585344314575195s
# ['z'] 0.1_2055ENS 24번째 반복 +144h 2.258810520172119s
# ['z'] 0.1_2055ENS 25번째 반복 +150h 2.2583329677581787s
# ['z'] 0.1_2055ENS 26번째 반복 +156h 2.2593817710876465s
# ['z'] 0.1_2055ENS 27번째 반복 +162h 2.2585365772247314s
# ['z'] 0.1_2055ENS 28번째 반복 +168h 2.260378122329712s
# ['z'] 0.1_2055ENS: 382.7117886543274s
# ['z'] 0.1_2056ENS 1번째 반복 +6h 2.2596724033355713s
# ['z'] 0.1_2056ENS 2번째 반복 +12h 2.2587897777557373s
# ['z'] 0.1_2056ENS 3번째 반복 +18h 2.2597315311431885s
# ['z'] 0.1_2056ENS 4번째 반복 +24h 2.2603139877319336s
# ['z'] 0.1_2056ENS 5번째 반복 +30h 2.2585198879241943s
# ['z'] 0.1_2056ENS 6번째 반복 +36h 2.2642955780029297s
# ['z'] 0.1_2056ENS 7번째 반복 +42h 2.259953737258911s
# ['z'] 0.1_2056ENS 8번째 반복 +48h 2.2586491107940674s
# ['z'] 0.1_2056ENS 9번째 반복 +54h 2.258685350418091s
# ['z'] 0.1_2056ENS 10번째 반복 +60h 2.2606518268585205s
# ['z'] 0.1_2056ENS 11번째 반복 +66h 2.2584214210510254s
# ['z'] 0.1_2056ENS 12번째 반복 +72h 2.2595155239105225s
# ['z'] 0.1_2056ENS 13번째 반복 +78h 2.2589337825775146s
# ['z'] 0.1_2056ENS 14번째 반복 +84h 2.259988784790039s
# ['z'] 0.1_2056ENS 15번째 반복 +90h 2.258650064468384s
# ['z'] 0.1_2056ENS 16번째 반복 +96h 2.259842872619629s
# ['z'] 0.1_2056ENS 17번째 반복 +102h 2.258513927459717s
# ['z'] 0.1_2056ENS 18번째 반복 +108h 2.260003089904785s
# ['z'] 0.1_2056ENS 19번째 반복 +114h 2.25884747505188s
# ['z'] 0.1_2056ENS 20번째 반복 +120h 2.2609827518463135s
# ['z'] 0.1_2056ENS 21번째 반복 +126h 2.259166955947876s
# ['z'] 0.1_2056ENS 22번째 반복 +132h 2.2603793144226074s
# ['z'] 0.1_2056ENS 23번째 반복 +138h 2.259324312210083s
# ['z'] 0.1_2056ENS 24번째 반복 +144h 2.2587180137634277s
# ['z'] 0.1_2056ENS 25번째 반복 +150h 2.257237434387207s
# ['z'] 0.1_2056ENS 26번째 반복 +156h 2.2601394653320312s
# ['z'] 0.1_2056ENS 27번째 반복 +162h 2.258417844772339s
# ['z'] 0.1_2056ENS 28번째 반복 +168h 2.2599706649780273s
# ['z'] 0.1_2056ENS: 446.29366874694824s
# ['z'] 0.1_2057ENS 1번째 반복 +6h 2.260423183441162s
# ['z'] 0.1_2057ENS 2번째 반복 +12h 2.259153127670288s
# ['z'] 0.1_2057ENS 3번째 반복 +18h 2.259725570678711s
# ['z'] 0.1_2057ENS 4번째 반복 +24h 2.259596109390259s
# ['z'] 0.1_2057ENS 5번째 반복 +30h 2.2587084770202637s
# ['z'] 0.1_2057ENS 6번째 반복 +36h 2.2653520107269287s
# ['z'] 0.1_2057ENS 7번째 반복 +42h 2.2583956718444824s
# ['z'] 0.1_2057ENS 8번째 반복 +48h 2.257887840270996s
# ['z'] 0.1_2057ENS 9번째 반복 +54h 2.2581748962402344s
# ['z'] 0.1_2057ENS 10번째 반복 +60h 2.2596700191497803s
# ['z'] 0.1_2057ENS 11번째 반복 +66h 2.2579939365386963s
# ['z'] 0.1_2057ENS 12번째 반복 +72h 2.2603797912597656s
# ['z'] 0.1_2057ENS 13번째 반복 +78h 2.258039951324463s
# ['z'] 0.1_2057ENS 14번째 반복 +84h 2.2594611644744873s
# ['z'] 0.1_2057ENS 15번째 반복 +90h 2.2586700916290283s
# ['z'] 0.1_2057ENS 16번째 반복 +96h 2.2589457035064697s
# ['z'] 0.1_2057ENS 17번째 반복 +102h 2.2583775520324707s
# ['z'] 0.1_2057ENS 18번째 반복 +108h 2.2595083713531494s
# ['z'] 0.1_2057ENS 19번째 반복 +114h 2.2587714195251465s
# ['z'] 0.1_2057ENS 20번째 반복 +120h 2.2607831954956055s
# ['z'] 0.1_2057ENS 21번째 반복 +126h 2.258779764175415s
# ['z'] 0.1_2057ENS 22번째 반복 +132h 2.26015567779541s
# ['z'] 0.1_2057ENS 23번째 반복 +138h 2.258882999420166s
# ['z'] 0.1_2057ENS 24번째 반복 +144h 2.258012294769287s
# ['z'] 0.1_2057ENS 25번째 반복 +150h 2.2579762935638428s
# ['z'] 0.1_2057ENS 26번째 반복 +156h 2.260195732116699s
# ['z'] 0.1_2057ENS 27번째 반복 +162h 2.2584643363952637s
# ['z'] 0.1_2057ENS 28번째 반복 +168h 2.2601475715637207s
# ['z'] 0.1_2057ENS: 509.8978133201599s
# ['z'] 0.1_2058ENS 1번째 반복 +6h 2.260533571243286s
# ['z'] 0.1_2058ENS 2번째 반복 +12h 2.2596306800842285s
# ['z'] 0.1_2058ENS 3번째 반복 +18h 2.2595105171203613s
# ['z'] 0.1_2058ENS 4번째 반복 +24h 2.259249210357666s
# ['z'] 0.1_2058ENS 5번째 반복 +30h 2.257826089859009s
# ['z'] 0.1_2058ENS 6번째 반복 +36h 2.259911298751831s
# ['z'] 0.1_2058ENS 7번째 반복 +42h 2.258521318435669s
# ['z'] 0.1_2058ENS 8번째 반복 +48h 2.2593483924865723s
# ['z'] 0.1_2058ENS 9번째 반복 +54h 2.2578864097595215s
# ['z'] 0.1_2058ENS 10번째 반복 +60h 2.25925874710083s
# ['z'] 0.1_2058ENS 11번째 반복 +66h 2.2592411041259766s
# ['z'] 0.1_2058ENS 12번째 반복 +72h 2.2604031562805176s
# ['z'] 0.1_2058ENS 13번째 반복 +78h 2.2578353881835938s
# ['z'] 0.1_2058ENS 14번째 반복 +84h 2.260769844055176s
# ['z'] 0.1_2058ENS 15번째 반복 +90h 2.259152889251709s
# ['z'] 0.1_2058ENS 16번째 반복 +96h 2.2596547603607178s
# ['z'] 0.1_2058ENS 17번째 반복 +102h 2.2585878372192383s
# ['z'] 0.1_2058ENS 18번째 반복 +108h 2.260111093521118s
# ['z'] 0.1_2058ENS 19번째 반복 +114h 2.2586987018585205s
# ['z'] 0.1_2058ENS 20번째 반복 +120h 2.2599306106567383s
# ['z'] 0.1_2058ENS 21번째 반복 +126h 2.25785756111145s
# ['z'] 0.1_2058ENS 22번째 반복 +132h 2.2600631713867188s
# ['z'] 0.1_2058ENS 23번째 반복 +138h 2.258863925933838s
# ['z'] 0.1_2058ENS 24번째 반복 +144h 2.260201930999756s
# ['z'] 0.1_2058ENS 25번째 반복 +150h 2.2582502365112305s
# ['z'] 0.1_2058ENS 26번째 반복 +156h 2.2596747875213623s
# ['z'] 0.1_2058ENS 27번째 반복 +162h 2.260141372680664s
# ['z'] 0.1_2058ENS 28번째 반복 +168h 2.2601306438446045s
# ['z'] 0.1_2058ENS: 573.4749319553375s
# ['z'] 0.1_2059ENS 1번째 반복 +6h 2.259485960006714s
# ['z'] 0.1_2059ENS 2번째 반복 +12h 2.260262966156006s
# ['z'] 0.1_2059ENS 3번째 반복 +18h 2.259779214859009s
# ['z'] 0.1_2059ENS 4번째 반복 +24h 2.2602670192718506s
# ['z'] 0.1_2059ENS 5번째 반복 +30h 2.259230613708496s
# ['z'] 0.1_2059ENS 6번째 반복 +36h 2.258371353149414s
# ['z'] 0.1_2059ENS 7번째 반복 +42h 2.2594242095947266s
# ['z'] 0.1_2059ENS 8번째 반복 +48h 2.259533643722534s
# ['z'] 0.1_2059ENS 9번째 반복 +54h 2.2586936950683594s
# ['z'] 0.1_2059ENS 10번째 반복 +60h 2.2595643997192383s
# ['z'] 0.1_2059ENS 11번째 반복 +66h 2.2602334022521973s
# ['z'] 0.1_2059ENS 12번째 반복 +72h 2.260409116744995s
# ['z'] 0.1_2059ENS 13번째 반복 +78h 2.2585666179656982s
# ['z'] 0.1_2059ENS 14번째 반복 +84h 2.259918689727783s
# ['z'] 0.1_2059ENS 15번째 반복 +90h 2.2584264278411865s
# ['z'] 0.1_2059ENS 16번째 반복 +96h 2.2589735984802246s
# ['z'] 0.1_2059ENS 17번째 반복 +102h 2.2584762573242188s
# ['z'] 0.1_2059ENS 18번째 반복 +108h 2.2609236240386963s
# ['z'] 0.1_2059ENS 19번째 반복 +114h 2.2588493824005127s
# ['z'] 0.1_2059ENS 20번째 반복 +120h 2.259896755218506s
# ['z'] 0.1_2059ENS 21번째 반복 +126h 2.2575523853302s
# ['z'] 0.1_2059ENS 22번째 반복 +132h 2.260169506072998s
# ['z'] 0.1_2059ENS 23번째 반복 +138h 2.258131980895996s
# ['z'] 0.1_2059ENS 24번째 반복 +144h 2.2589235305786133s
# ['z'] 0.1_2059ENS 25번째 반복 +150h 2.25795578956604s
# ['z'] 0.1_2059ENS 26번째 반복 +156h 2.2591798305511475s
# ['z'] 0.1_2059ENS 27번째 반복 +162h 2.2586755752563477s
# ['z'] 0.1_2059ENS 28번째 반복 +168h 2.259882688522339s
# ['z'] 0.1_2059ENS: 637.0785369873047s
# ['z'] 0.1_2060ENS 1번째 반복 +6h 2.2591593265533447s
# ['z'] 0.1_2060ENS 2번째 반복 +12h 2.2601730823516846s
# ['z'] 0.1_2060ENS 3번째 반복 +18h 2.2599329948425293s
# ['z'] 0.1_2060ENS 4번째 반복 +24h 2.2604763507843018s
# ['z'] 0.1_2060ENS 5번째 반복 +30h 2.2588751316070557s
# ['z'] 0.1_2060ENS 6번째 반복 +36h 2.2598557472229004s
# ['z'] 0.1_2060ENS 7번째 반복 +42h 2.2587742805480957s
# ['z'] 0.1_2060ENS 8번째 반복 +48h 2.259413957595825s
# ['z'] 0.1_2060ENS 9번째 반복 +54h 2.2585582733154297s
# ['z'] 0.1_2060ENS 10번째 반복 +60h 2.2597248554229736s
# ['z'] 0.1_2060ENS 11번째 반복 +66h 2.2591142654418945s
# ['z'] 0.1_2060ENS 12번째 반복 +72h 2.260697364807129s
# ['z'] 0.1_2060ENS 13번째 반복 +78h 2.259148359298706s
# ['z'] 0.1_2060ENS 14번째 반복 +84h 2.2602641582489014s
# ['z'] 0.1_2060ENS 15번째 반복 +90h 2.2585957050323486s
# ['z'] 0.1_2060ENS 16번째 반복 +96h 2.2594025135040283s
# ['z'] 0.1_2060ENS 17번째 반복 +102h 2.2588884830474854s
# ['z'] 0.1_2060ENS 18번째 반복 +108h 2.260554075241089s
# ['z'] 0.1_2060ENS 19번째 반복 +114h 2.258368968963623s
# ['z'] 0.1_2060ENS 20번째 반복 +120h 2.25986385345459s
# ['z'] 0.1_2060ENS 21번째 반복 +126h 2.259432315826416s
# ['z'] 0.1_2060ENS 22번째 반복 +132h 2.259060859680176s
# ['z'] 0.1_2060ENS 23번째 반복 +138h 2.2590034008026123s
# ['z'] 0.1_2060ENS 24번째 반복 +144h 2.258605718612671s
# ['z'] 0.1_2060ENS 25번째 반복 +150h 2.2578952312469482s
# ['z'] 0.1_2060ENS 26번째 반복 +156h 2.2599542140960693s
# ['z'] 0.1_2060ENS 27번째 반복 +162h 2.2590622901916504s
# ['z'] 0.1_2060ENS 28번째 반복 +168h 2.261049270629883s
# ['z'] 0.1_2060ENS: 700.6576526165009s
# ['z'] 0.1_2061ENS 1번째 반복 +6h 2.259544849395752s
# ['z'] 0.1_2061ENS 2번째 반복 +12h 2.2587645053863525s
# ['z'] 0.1_2061ENS 3번째 반복 +18h 2.2594473361968994s
# ['z'] 0.1_2061ENS 4번째 반복 +24h 2.260075092315674s
# ['z'] 0.1_2061ENS 5번째 반복 +30h 2.2582991123199463s
# ['z'] 0.1_2061ENS 6번째 반복 +36h 2.26035213470459s
# ['z'] 0.1_2061ENS 7번째 반복 +42h 2.2580957412719727s
# ['z'] 0.1_2061ENS 8번째 반복 +48h 2.2578988075256348s
# ['z'] 0.1_2061ENS 9번째 반복 +54h 2.258903980255127s
# ['z'] 0.1_2061ENS 10번째 반복 +60h 2.259650230407715s
# ['z'] 0.1_2061ENS 11번째 반복 +66h 2.258718252182007s
# ['z'] 0.1_2061ENS 12번째 반복 +72h 2.2604002952575684s
# ['z'] 0.1_2061ENS 13번째 반복 +78h 2.25803804397583s
# ['z'] 0.1_2061ENS 14번째 반복 +84h 2.259936809539795s
# ['z'] 0.1_2061ENS 15번째 반복 +90h 2.2593343257904053s
# ['z'] 0.1_2061ENS 16번째 반복 +96h 2.258584499359131s
# ['z'] 0.1_2061ENS 17번째 반복 +102h 2.258338212966919s
# ['z'] 0.1_2061ENS 18번째 반복 +108h 2.2751739025115967s
# ['z'] 0.1_2061ENS 19번째 반복 +114h 2.259225606918335s
# ['z'] 0.1_2061ENS 20번째 반복 +120h 2.2603759765625s
# ['z'] 0.1_2061ENS 21번째 반복 +126h 2.2586910724639893s
# ['z'] 0.1_2061ENS 22번째 반복 +132h 2.260798692703247s
# ['z'] 0.1_2061ENS 23번째 반복 +138h 2.2581942081451416s
# ['z'] 0.1_2061ENS 24번째 반복 +144h 2.259101629257202s
# ['z'] 0.1_2061ENS 25번째 반복 +150h 2.259113311767578s
# ['z'] 0.1_2061ENS 26번째 반복 +156h 2.2600595951080322s
# ['z'] 0.1_2061ENS 27번째 반복 +162h 2.258467197418213s
# ['z'] 0.1_2061ENS 28번째 반복 +168h 2.2603816986083984s
# ['z'] 0.1_2061ENS: 764.2751967906952s
# ['z'] 0.1_2062ENS 1번째 반복 +6h 2.2600176334381104s
# ['z'] 0.1_2062ENS 2번째 반복 +12h 2.2586493492126465s
# ['z'] 0.1_2062ENS 3번째 반복 +18h 2.2596309185028076s
# ['z'] 0.1_2062ENS 4번째 반복 +24h 2.259996175765991s
# ['z'] 0.1_2062ENS 5번째 반복 +30h 2.2586538791656494s
# ['z'] 0.1_2062ENS 6번째 반복 +36h 2.25964093208313s
# ['z'] 0.1_2062ENS 7번째 반복 +42h 2.259881019592285s
# ['z'] 0.1_2062ENS 8번째 반복 +48h 2.2592310905456543s
# ['z'] 0.1_2062ENS 9번째 반복 +54h 2.2582061290740967s
# ['z'] 0.1_2062ENS 10번째 반복 +60h 2.2595436573028564s
# ['z'] 0.1_2062ENS 11번째 반복 +66h 2.2588090896606445s
# ['z'] 0.1_2062ENS 12번째 반복 +72h 2.260718822479248s
# ['z'] 0.1_2062ENS 13번째 반복 +78h 2.258739709854126s
# ['z'] 0.1_2062ENS 14번째 반복 +84h 2.2602758407592773s
# ['z'] 0.1_2062ENS 15번째 반복 +90h 2.259197950363159s
# ['z'] 0.1_2062ENS 16번째 반복 +96h 2.259650707244873s
# ['z'] 0.1_2062ENS 17번째 반복 +102h 2.2582008838653564s
# ['z'] 0.1_2062ENS 18번째 반복 +108h 2.2589304447174072s
# ['z'] 0.1_2062ENS 19번째 반복 +114h 2.2592544555664062s
# ['z'] 0.1_2062ENS 20번째 반복 +120h 2.260255813598633s
# ['z'] 0.1_2062ENS 21번째 반복 +126h 2.258737325668335s
# ['z'] 0.1_2062ENS 22번째 반복 +132h 2.2601993083953857s
# ['z'] 0.1_2062ENS 23번째 반복 +138h 2.2593650817871094s
# ['z'] 0.1_2062ENS 24번째 반복 +144h 2.259186029434204s
# ['z'] 0.1_2062ENS 25번째 반복 +150h 2.259143590927124s
# ['z'] 0.1_2062ENS 26번째 반복 +156h 2.2598352432250977s
# ['z'] 0.1_2062ENS 27번째 반복 +162h 2.2591023445129395s
# ['z'] 0.1_2062ENS 28번째 반복 +168h 2.260653257369995s
# ['z'] 0.1_2062ENS: 827.8549108505249s
# ['z'] 0.1_2063ENS 1번째 반복 +6h 2.260237216949463s
# ['z'] 0.1_2063ENS 2번째 반복 +12h 2.259556531906128s
# ['z'] 0.1_2063ENS 3번째 반복 +18h 2.2607998847961426s
# ['z'] 0.1_2063ENS 4번째 반복 +24h 2.2603600025177s
# ['z'] 0.1_2063ENS 5번째 반복 +30h 2.2579734325408936s
# ['z'] 0.1_2063ENS 6번째 반복 +36h 2.2591493129730225s
# ['z'] 0.1_2063ENS 7번째 반복 +42h 2.2590243816375732s
# ['z'] 0.1_2063ENS 8번째 반복 +48h 2.2591567039489746s
# ['z'] 0.1_2063ENS 9번째 반복 +54h 2.2585597038269043s
# ['z'] 0.1_2063ENS 10번째 반복 +60h 2.2602391242980957s
# ['z'] 0.1_2063ENS 11번째 반복 +66h 2.257861375808716s
# ['z'] 0.1_2063ENS 12번째 반복 +72h 2.2597241401672363s
# ['z'] 0.1_2063ENS 13번째 반복 +78h 2.2581355571746826s
# ['z'] 0.1_2063ENS 14번째 반복 +84h 2.2604587078094482s
# ['z'] 0.1_2063ENS 15번째 반복 +90h 2.258829116821289s
# ['z'] 0.1_2063ENS 16번째 반복 +96h 2.2588915824890137s
# ['z'] 0.1_2063ENS 17번째 반복 +102h 2.2576377391815186s
# ['z'] 0.1_2063ENS 18번째 반복 +108h 2.259915351867676s
# ['z'] 0.1_2063ENS 19번째 반복 +114h 2.2584245204925537s
# ['z'] 0.1_2063ENS 20번째 반복 +120h 2.2605316638946533s
# ['z'] 0.1_2063ENS 21번째 반복 +126h 2.2582969665527344s
# ['z'] 0.1_2063ENS 22번째 반복 +132h 2.265359401702881s
# ['z'] 0.1_2063ENS 23번째 반복 +138h 2.258448839187622s
# ['z'] 0.1_2063ENS 24번째 반복 +144h 2.258328914642334s
# ['z'] 0.1_2063ENS 25번째 반복 +150h 2.2573280334472656s
# ['z'] 0.1_2063ENS 26번째 반복 +156h 2.2605135440826416s
# ['z'] 0.1_2063ENS 27번째 반복 +162h 2.258650302886963s
# ['z'] 0.1_2063ENS 28번째 반복 +168h 2.259756088256836s
# ['z'] 0.1_2063ENS: 891.4601962566376s
# ['z'] 0.1_2064ENS 1번째 반복 +6h 2.26031494140625s
# ['z'] 0.1_2064ENS 2번째 반복 +12h 2.2594692707061768s
# ['z'] 0.1_2064ENS 3번째 반복 +18h 2.2603700160980225s
# ['z'] 0.1_2064ENS 4번째 반복 +24h 2.2616283893585205s
# ['z'] 0.1_2064ENS 5번째 반복 +30h 2.257270336151123s
# ['z'] 0.1_2064ENS 6번째 반복 +36h 2.2595319747924805s
# ['z'] 0.1_2064ENS 7번째 반복 +42h 2.259138822555542s
# ['z'] 0.1_2064ENS 8번째 반복 +48h 2.2594027519226074s
# ['z'] 0.1_2064ENS 9번째 반복 +54h 2.2577834129333496s
# ['z'] 0.1_2064ENS 10번째 반복 +60h 2.2598235607147217s
# ['z'] 0.1_2064ENS 11번째 반복 +66h 2.2588231563568115s
# ['z'] 0.1_2064ENS 12번째 반복 +72h 2.26716947555542s
# ['z'] 0.1_2064ENS 13번째 반복 +78h 2.2588188648223877s
# ['z'] 0.1_2064ENS 14번째 반복 +84h 2.259901523590088s
# ['z'] 0.1_2064ENS 15번째 반복 +90h 2.2581067085266113s
# ['z'] 0.1_2064ENS 16번째 반복 +96h 2.2581591606140137s
# ['z'] 0.1_2064ENS 17번째 반복 +102h 2.2585325241088867s
# ['z'] 0.1_2064ENS 18번째 반복 +108h 2.2815635204315186s
# ['z'] 0.1_2064ENS 19번째 반복 +114h 2.2588322162628174s
# ['z'] 0.1_2064ENS 20번째 반복 +120h 2.2591233253479004s
# ['z'] 0.1_2064ENS 21번째 반복 +126h 2.2583975791931152s
# ['z'] 0.1_2064ENS 22번째 반복 +132h 2.2603366374969482s
# ['z'] 0.1_2064ENS 23번째 반복 +138h 2.2589592933654785s
# ['z'] 0.1_2064ENS 24번째 반복 +144h 2.2578628063201904s
# ['z'] 0.1_2064ENS 25번째 반복 +150h 2.2580857276916504s
# ['z'] 0.1_2064ENS 26번째 반복 +156h 2.2592434883117676s
# ['z'] 0.1_2064ENS 27번째 반복 +162h 2.258190870285034s
# ['z'] 0.1_2064ENS 28번째 반복 +168h 2.2598798274993896s
# ['z'] 0.1_2064ENS: 955.0605313777924s
# ['z'] 0.1_2065ENS 1번째 반복 +6h 2.2598049640655518s
# ['z'] 0.1_2065ENS 2번째 반복 +12h 2.259650945663452s
# ['z'] 0.1_2065ENS 3번째 반복 +18h 2.2589709758758545s
# ['z'] 0.1_2065ENS 4번째 반복 +24h 2.2602226734161377s
# ['z'] 0.1_2065ENS 5번째 반복 +30h 2.257228136062622s
# ['z'] 0.1_2065ENS 6번째 반복 +36h 2.2597498893737793s
# ['z'] 0.1_2065ENS 7번째 반복 +42h 2.25813627243042s
# ['z'] 0.1_2065ENS 8번째 반복 +48h 2.2586398124694824s
# ['z'] 0.1_2065ENS 9번째 반복 +54h 2.2577948570251465s
# ['z'] 0.1_2065ENS 10번째 반복 +60h 2.259639263153076s
# ['z'] 0.1_2065ENS 11번째 반복 +66h 2.261141538619995s
# ['z'] 0.1_2065ENS 12번째 반복 +72h 2.259709596633911s
# ['z'] 0.1_2065ENS 13번째 반복 +78h 2.2575743198394775s
# ['z'] 0.1_2065ENS 14번째 반복 +84h 2.2598960399627686s
# ['z'] 0.1_2065ENS 15번째 반복 +90h 2.2582242488861084s
# ['z'] 0.1_2065ENS 16번째 반복 +96h 2.258713722229004s
# ['z'] 0.1_2065ENS 17번째 반복 +102h 2.258098602294922s
# ['z'] 0.1_2065ENS 18번째 반복 +108h 2.2589664459228516s
# ['z'] 0.1_2065ENS 19번째 반복 +114h 2.257796287536621s
# ['z'] 0.1_2065ENS 20번째 반복 +120h 2.2604026794433594s
# ['z'] 0.1_2065ENS 21번째 반복 +126h 2.2588956356048584s
# ['z'] 0.1_2065ENS 22번째 반복 +132h 2.2596521377563477s
# ['z'] 0.1_2065ENS 23번째 반복 +138h 2.2594239711761475s
# ['z'] 0.1_2065ENS 24번째 반복 +144h 2.257863759994507s
# ['z'] 0.1_2065ENS 25번째 반복 +150h 2.2586803436279297s
# ['z'] 0.1_2065ENS 26번째 반복 +156h 2.2597203254699707s
# ['z'] 0.1_2065ENS 27번째 반복 +162h 2.25883412361145s
# ['z'] 0.1_2065ENS 28번째 반복 +168h 2.260162591934204s
# ['z'] 0.1_2065ENS: 1018.6570584774017s
# ['z'] 0.1_2066ENS 1번째 반복 +6h 2.260578155517578s
# ['z'] 0.1_2066ENS 2번째 반복 +12h 2.2592031955718994s
# ['z'] 0.1_2066ENS 3번째 반복 +18h 2.259889841079712s
# ['z'] 0.1_2066ENS 4번째 반복 +24h 2.259835958480835s
# ['z'] 0.1_2066ENS 5번째 반복 +30h 2.2583374977111816s
# ['z'] 0.1_2066ENS 6번째 반복 +36h 2.260035991668701s
# ['z'] 0.1_2066ENS 7번째 반복 +42h 2.2587928771972656s
# ['z'] 0.1_2066ENS 8번째 반복 +48h 2.272247314453125s
# ['z'] 0.1_2066ENS 9번째 반복 +54h 2.257803201675415s
# ['z'] 0.1_2066ENS 10번째 반복 +60h 2.258662223815918s
# ['z'] 0.1_2066ENS 11번째 반복 +66h 2.2592086791992188s
# ['z'] 0.1_2066ENS 12번째 반복 +72h 2.2595503330230713s
# ['z'] 0.1_2066ENS 13번째 반복 +78h 2.2576334476470947s
# ['z'] 0.1_2066ENS 14번째 반복 +84h 2.260438919067383s
# ['z'] 0.1_2066ENS 15번째 반복 +90h 2.2582807540893555s
# ['z'] 0.1_2066ENS 16번째 반복 +96h 2.257559299468994s
# ['z'] 0.1_2066ENS 17번째 반복 +102h 2.258080244064331s
# ['z'] 0.1_2066ENS 18번째 반복 +108h 2.259638547897339s
# ['z'] 0.1_2066ENS 19번째 반복 +114h 2.2581660747528076s
# ['z'] 0.1_2066ENS 20번째 반복 +120h 2.259369134902954s
# ['z'] 0.1_2066ENS 21번째 반복 +126h 2.2574141025543213s
# ['z'] 0.1_2066ENS 22번째 반복 +132h 2.2596781253814697s
# ['z'] 0.1_2066ENS 23번째 반복 +138h 2.257772207260132s
# ['z'] 0.1_2066ENS 24번째 반복 +144h 2.258568048477173s
# ['z'] 0.1_2066ENS 25번째 반복 +150h 2.257903575897217s
# ['z'] 0.1_2066ENS 26번째 반복 +156h 2.258673667907715s
# ['z'] 0.1_2066ENS 27번째 반복 +162h 2.2592697143554688s
# ['z'] 0.1_2066ENS 28번째 반복 +168h 2.260103702545166s
# ['z'] 0.1_2066ENS: 1082.237068414688s
# ['z'] 0.1_2067ENS 1번째 반복 +6h 2.2600831985473633s
# ['z'] 0.1_2067ENS 2번째 반복 +12h 2.2592248916625977s
# ['z'] 0.1_2067ENS 3번째 반복 +18h 2.2595551013946533s
# ['z'] 0.1_2067ENS 4번째 반복 +24h 2.2600324153900146s
# ['z'] 0.1_2067ENS 5번째 반복 +30h 2.258172035217285s
# ['z'] 0.1_2067ENS 6번째 반복 +36h 2.259477376937866s
# ['z'] 0.1_2067ENS 7번째 반복 +42h 2.258305311203003s
# ['z'] 0.1_2067ENS 8번째 반복 +48h 2.258941411972046s
# ['z'] 0.1_2067ENS 9번째 반복 +54h 2.2575833797454834s
# ['z'] 0.1_2067ENS 10번째 반복 +60h 2.2597708702087402s
# ['z'] 0.1_2067ENS 11번째 반복 +66h 2.2587637901306152s
# ['z'] 0.1_2067ENS 12번째 반복 +72h 2.2597591876983643s
# ['z'] 0.1_2067ENS 13번째 반복 +78h 2.2578766345977783s
# ['z'] 0.1_2067ENS 14번째 반복 +84h 2.259227752685547s
# ['z'] 0.1_2067ENS 15번째 반복 +90h 2.25823974609375s
# ['z'] 0.1_2067ENS 16번째 반복 +96h 2.2582449913024902s
# ['z'] 0.1_2067ENS 17번째 반복 +102h 2.258173942565918s
# ['z'] 0.1_2067ENS 18번째 반복 +108h 2.259032964706421s
# ['z'] 0.1_2067ENS 19번째 반복 +114h 2.2582149505615234s
# ['z'] 0.1_2067ENS 20번째 반복 +120h 2.2592570781707764s
# ['z'] 0.1_2067ENS 21번째 반복 +126h 2.25765061378479s
# ['z'] 0.1_2067ENS 22번째 반복 +132h 2.2597222328186035s
# ['z'] 0.1_2067ENS 23번째 반복 +138h 2.2585110664367676s
# ['z'] 0.1_2067ENS 24번째 반복 +144h 2.2581257820129395s
# ['z'] 0.1_2067ENS 25번째 반복 +150h 2.2580504417419434s
# ['z'] 0.1_2067ENS 26번째 반복 +156h 2.2592833042144775s
# ['z'] 0.1_2067ENS 27번째 반복 +162h 2.258561372756958s
# ['z'] 0.1_2067ENS 28번째 반복 +168h 2.259026527404785s
# ['z'] 0.1_2067ENS: 1145.827122926712s
# ['z'] 0.1_2068ENS 1번째 반복 +6h 2.2604258060455322s
# ['z'] 0.1_2068ENS 2번째 반복 +12h 2.259488582611084s
# ['z'] 0.1_2068ENS 3번째 반복 +18h 2.2589340209960938s
# ['z'] 0.1_2068ENS 4번째 반복 +24h 2.2596383094787598s
# ['z'] 0.1_2068ENS 5번째 반복 +30h 2.2584147453308105s
# ['z'] 0.1_2068ENS 6번째 반복 +36h 2.2592265605926514s
# ['z'] 0.1_2068ENS 7번째 반복 +42h 2.2577152252197266s
# ['z'] 0.1_2068ENS 8번째 반복 +48h 2.2583603858947754s
# ['z'] 0.1_2068ENS 9번째 반복 +54h 2.2582576274871826s
# ['z'] 0.1_2068ENS 10번째 반복 +60h 2.2598116397857666s
# ['z'] 0.1_2068ENS 11번째 반복 +66h 2.2582623958587646s
# ['z'] 0.1_2068ENS 12번째 반복 +72h 2.2593719959259033s
# ['z'] 0.1_2068ENS 13번째 반복 +78h 2.2575998306274414s
# ['z'] 0.1_2068ENS 14번째 반복 +84h 2.26045298576355s
# ['z'] 0.1_2068ENS 15번째 반복 +90h 2.2580089569091797s
# ['z'] 0.1_2068ENS 16번째 반복 +96h 2.258105993270874s
# ['z'] 0.1_2068ENS 17번째 반복 +102h 2.2580556869506836s
# ['z'] 0.1_2068ENS 18번째 반복 +108h 2.2597692012786865s
# ['z'] 0.1_2068ENS 19번째 반복 +114h 2.258979082107544s
# ['z'] 0.1_2068ENS 20번째 반복 +120h 2.2599833011627197s
# ['z'] 0.1_2068ENS 21번째 반복 +126h 2.258760690689087s
# ['z'] 0.1_2068ENS 22번째 반복 +132h 2.2598509788513184s
# ['z'] 0.1_2068ENS 23번째 반복 +138h 2.25785493850708s
# ['z'] 0.1_2068ENS 24번째 반복 +144h 2.259221315383911s
# ['z'] 0.1_2068ENS 25번째 반복 +150h 2.2576584815979004s
# ['z'] 0.1_2068ENS 26번째 반복 +156h 2.259042739868164s
# ['z'] 0.1_2068ENS 27번째 반복 +162h 2.2589948177337646s
# ['z'] 0.1_2068ENS 28번째 반복 +168h 2.260169744491577s
# ['z'] 0.1_2068ENS: 1209.3927838802338s
# ['z'] 0.1_2069ENS 1번째 반복 +6h 2.259876012802124s
# ['z'] 0.1_2069ENS 2번째 반복 +12h 2.2598185539245605s
# ['z'] 0.1_2069ENS 3번째 반복 +18h 2.261085271835327s
# ['z'] 0.1_2069ENS 4번째 반복 +24h 2.2601234912872314s
# ['z'] 0.1_2069ENS 5번째 반복 +30h 2.2580807209014893s
# ['z'] 0.1_2069ENS 6번째 반복 +36h 2.260038375854492s
# ['z'] 0.1_2069ENS 7번째 반복 +42h 2.257652521133423s
# ['z'] 0.1_2069ENS 8번째 반복 +48h 2.259072780609131s
# ['z'] 0.1_2069ENS 9번째 반복 +54h 2.2579643726348877s
# ['z'] 0.1_2069ENS 10번째 반복 +60h 2.2589046955108643s
# ['z'] 0.1_2069ENS 11번째 반복 +66h 2.2591965198516846s
# ['z'] 0.1_2069ENS 12번째 반복 +72h 2.260359287261963s
# ['z'] 0.1_2069ENS 13번째 반복 +78h 2.259093999862671s
# ['z'] 0.1_2069ENS 14번째 반복 +84h 2.2596373558044434s
# ['z'] 0.1_2069ENS 15번째 반복 +90h 2.258810520172119s
# ['z'] 0.1_2069ENS 16번째 반복 +96h 2.258479118347168s
# ['z'] 0.1_2069ENS 17번째 반복 +102h 2.257826328277588s
# ['z'] 0.1_2069ENS 18번째 반복 +108h 2.2595744132995605s
# ['z'] 0.1_2069ENS 19번째 반복 +114h 2.2587695121765137s
# ['z'] 0.1_2069ENS 20번째 반복 +120h 2.260342836380005s
# ['z'] 0.1_2069ENS 21번째 반복 +126h 2.2576916217803955s
# ['z'] 0.1_2069ENS 22번째 반복 +132h 2.2603600025177s
# ['z'] 0.1_2069ENS 23번째 반복 +138h 2.258464813232422s
# ['z'] 0.1_2069ENS 24번째 반복 +144h 2.2586238384246826s
# ['z'] 0.1_2069ENS 25번째 반복 +150h 2.2578516006469727s
# ['z'] 0.1_2069ENS 26번째 반복 +156h 2.259880304336548s
# ['z'] 0.1_2069ENS 27번째 반복 +162h 2.25870680809021s
# ['z'] 0.1_2069ENS 28번째 반복 +168h 2.2600371837615967s
# ['z'] 0.1_2069ENS: 1272.9924380779266s
# ['z'] 0.1_2070ENS 1번째 반복 +6h 2.260235071182251s
# ['z'] 0.1_2070ENS 2번째 반복 +12h 2.25887131690979s
# ['z'] 0.1_2070ENS 3번째 반복 +18h 2.259310245513916s
# ['z'] 0.1_2070ENS 4번째 반복 +24h 2.259552001953125s
# ['z'] 0.1_2070ENS 5번째 반복 +30h 2.2576889991760254s
# ['z'] 0.1_2070ENS 6번째 반복 +36h 2.259093761444092s
# ['z'] 0.1_2070ENS 7번째 반복 +42h 2.258242130279541s
# ['z'] 0.1_2070ENS 8번째 반복 +48h 2.2577977180480957s
# ['z'] 0.1_2070ENS 9번째 반복 +54h 2.258047342300415s
# ['z'] 0.1_2070ENS 10번째 반복 +60h 2.259366035461426s
# ['z'] 0.1_2070ENS 11번째 반복 +66h 2.258382797241211s
# ['z'] 0.1_2070ENS 12번째 반복 +72h 2.2594857215881348s
# ['z'] 0.1_2070ENS 13번째 반복 +78h 2.258260726928711s
# ['z'] 0.1_2070ENS 14번째 반복 +84h 2.2594974040985107s
# ['z'] 0.1_2070ENS 15번째 반복 +90h 2.2582526206970215s
# ['z'] 0.1_2070ENS 16번째 반복 +96h 2.2589316368103027s
# ['z'] 0.1_2070ENS 17번째 반복 +102h 2.2575364112854004s
# ['z'] 0.1_2070ENS 18번째 반복 +108h 2.2593958377838135s
# ['z'] 0.1_2070ENS 19번째 반복 +114h 2.257824659347534s
# ['z'] 0.1_2070ENS 20번째 반복 +120h 2.2604568004608154s
# ['z'] 0.1_2070ENS 21번째 반복 +126h 2.2583260536193848s
# ['z'] 0.1_2070ENS 22번째 반복 +132h 2.259570360183716s
# ['z'] 0.1_2070ENS 23번째 반복 +138h 2.258340358734131s
# ['z'] 0.1_2070ENS 24번째 반복 +144h 2.258289098739624s
# ['z'] 0.1_2070ENS 25번째 반복 +150h 2.2576560974121094s
# ['z'] 0.1_2070ENS 26번째 반복 +156h 2.2592809200286865s
# ['z'] 0.1_2070ENS 27번째 반복 +162h 2.259031057357788s
# ['z'] 0.1_2070ENS 28번째 반복 +168h 2.259976863861084s
# ['z'] 0.1_2070ENS: 1336.5545856952667s
# ['z'] 0.1_2071ENS 1번째 반복 +6h 2.259882926940918s
# ['z'] 0.1_2071ENS 2번째 반복 +12h 2.2598628997802734s
# ['z'] 0.1_2071ENS 3번째 반복 +18h 2.2606961727142334s
# ['z'] 0.1_2071ENS 4번째 반복 +24h 2.259962558746338s
# ['z'] 0.1_2071ENS 5번째 반복 +30h 2.257706880569458s
# ['z'] 0.1_2071ENS 6번째 반복 +36h 2.2594387531280518s
# ['z'] 0.1_2071ENS 7번째 반복 +42h 2.2589457035064697s
# ['z'] 0.1_2071ENS 8번째 반복 +48h 2.2587015628814697s
# ['z'] 0.1_2071ENS 9번째 반복 +54h 2.258208751678467s
# ['z'] 0.1_2071ENS 10번째 반복 +60h 2.259727954864502s
# ['z'] 0.1_2071ENS 11번째 반복 +66h 2.2584831714630127s
# ['z'] 0.1_2071ENS 12번째 반복 +72h 2.2600741386413574s
# ['z'] 0.1_2071ENS 13번째 반복 +78h 2.2578771114349365s
# ['z'] 0.1_2071ENS 14번째 반복 +84h 2.2595951557159424s
# ['z'] 0.1_2071ENS 15번째 반복 +90h 2.2590394020080566s
# ['z'] 0.1_2071ENS 16번째 반복 +96h 2.2584383487701416s
# ['z'] 0.1_2071ENS 17번째 반복 +102h 2.2582242488861084s
# ['z'] 0.1_2071ENS 18번째 반복 +108h 2.258655548095703s
# ['z'] 0.1_2071ENS 19번째 반복 +114h 2.259467124938965s
# ['z'] 0.1_2071ENS 20번째 반복 +120h 2.2602922916412354s
# ['z'] 0.1_2071ENS 21번째 반복 +126h 2.2585535049438477s
# ['z'] 0.1_2071ENS 22번째 반복 +132h 2.2600717544555664s
# ['z'] 0.1_2071ENS 23번째 반복 +138h 2.258528709411621s
# ['z'] 0.1_2071ENS 24번째 반복 +144h 2.258674144744873s
# ['z'] 0.1_2071ENS 25번째 반복 +150h 2.2581467628479004s
# ['z'] 0.1_2071ENS 26번째 반복 +156h 2.2597882747650146s
# ['z'] 0.1_2071ENS 27번째 반복 +162h 2.258946418762207s
# ['z'] 0.1_2071ENS 28번째 반복 +168h 2.2655768394470215s
# ['z'] 0.1_2071ENS: 1400.1595785617828s
# ['z'] 0.1_2072ENS 1번째 반복 +6h 2.2604897022247314s
# ['z'] 0.1_2072ENS 2번째 반복 +12h 2.260161876678467s
# ['z'] 0.1_2072ENS 3번째 반복 +18h 2.2593393325805664s
# ['z'] 0.1_2072ENS 4번째 반복 +24h 2.2610678672790527s
# ['z'] 0.1_2072ENS 5번째 반복 +30h 2.2583529949188232s
# ['z'] 0.1_2072ENS 6번째 반복 +36h 2.2602615356445312s
# ['z'] 0.1_2072ENS 7번째 반복 +42h 2.2582690715789795s
# ['z'] 0.1_2072ENS 8번째 반복 +48h 2.258918523788452s
# ['z'] 0.1_2072ENS 9번째 반복 +54h 2.258418560028076s
# ['z'] 0.1_2072ENS 10번째 반복 +60h 2.259483814239502s
# ['z'] 0.1_2072ENS 11번째 반복 +66h 2.2590932846069336s
# ['z'] 0.1_2072ENS 12번째 반복 +72h 2.260009288787842s
# ['z'] 0.1_2072ENS 13번째 반복 +78h 2.2586145401000977s
# ['z'] 0.1_2072ENS 14번째 반복 +84h 2.25990891456604s
# ['z'] 0.1_2072ENS 15번째 반복 +90h 2.2586357593536377s
# ['z'] 0.1_2072ENS 16번째 반복 +96h 2.2582764625549316s
# ['z'] 0.1_2072ENS 17번째 반복 +102h 2.260725498199463s
# ['z'] 0.1_2072ENS 18번째 반복 +108h 2.265744686126709s
# ['z'] 0.1_2072ENS 19번째 반복 +114h 2.2583634853363037s
# ['z'] 0.1_2072ENS 20번째 반복 +120h 2.259404182434082s
# ['z'] 0.1_2072ENS 21번째 반복 +126h 2.257547378540039s
# ['z'] 0.1_2072ENS 22번째 반복 +132h 2.259648561477661s
# ['z'] 0.1_2072ENS 23번째 반복 +138h 2.2587854862213135s
# ['z'] 0.1_2072ENS 24번째 반복 +144h 2.2579312324523926s
# ['z'] 0.1_2072ENS 25번째 반복 +150h 2.2579352855682373s
# ['z'] 0.1_2072ENS 26번째 반복 +156h 2.2598695755004883s
# ['z'] 0.1_2072ENS 27번째 반복 +162h 2.2584848403930664s
# ['z'] 0.1_2072ENS 28번째 반복 +168h 2.2651000022888184s
# ['z'] 0.1_2072ENS: 1463.7442681789398s
# ['z'] 0.1_2073ENS 1번째 반복 +6h 2.2601208686828613s
# ['z'] 0.1_2073ENS 2번째 반복 +12h 2.259735107421875s
# ['z'] 0.1_2073ENS 3번째 반복 +18h 2.259509801864624s
# ['z'] 0.1_2073ENS 4번째 반복 +24h 2.259648084640503s
# ['z'] 0.1_2073ENS 5번째 반복 +30h 2.25766921043396s
# ['z'] 0.1_2073ENS 6번째 반복 +36h 2.259437084197998s
# ['z'] 0.1_2073ENS 7번째 반복 +42h 2.258789539337158s
# ['z'] 0.1_2073ENS 8번째 반복 +48h 2.258014678955078s
# ['z'] 0.1_2073ENS 9번째 반복 +54h 2.2579286098480225s
# ['z'] 0.1_2073ENS 10번째 반복 +60h 2.259235382080078s
# ['z'] 0.1_2073ENS 11번째 반복 +66h 2.2584352493286133s
# ['z'] 0.1_2073ENS 12번째 반복 +72h 2.2601115703582764s
# ['z'] 0.1_2073ENS 13번째 반복 +78h 2.257901906967163s
# ['z'] 0.1_2073ENS 14번째 반복 +84h 2.26003098487854s
# ['z'] 0.1_2073ENS 15번째 반복 +90h 2.258265733718872s
# ['z'] 0.1_2073ENS 16번째 반복 +96h 2.2581818103790283s
# ['z'] 0.1_2073ENS 17번째 반복 +102h 2.260376214981079s
# ['z'] 0.1_2073ENS 18번째 반복 +108h 2.2596662044525146s
# ['z'] 0.1_2073ENS 19번째 반복 +114h 2.2577364444732666s
# ['z'] 0.1_2073ENS 20번째 반복 +120h 2.26031231880188s
# ['z'] 0.1_2073ENS 21번째 반복 +126h 2.258575439453125s
# ['z'] 0.1_2073ENS 22번째 반복 +132h 2.2588376998901367s
# ['z'] 0.1_2073ENS 23번째 반복 +138h 2.258476495742798s
# ['z'] 0.1_2073ENS 24번째 반복 +144h 2.2575628757476807s
# ['z'] 0.1_2073ENS 25번째 반복 +150h 2.2584733963012695s
# ['z'] 0.1_2073ENS 26번째 반복 +156h 2.2591733932495117s
# ['z'] 0.1_2073ENS 27번째 반복 +162h 2.2589192390441895s
# ['z'] 0.1_2073ENS 28번째 반복 +168h 2.260326385498047s
# ['z'] 0.1_2073ENS: 1527.3391935825348s
# ['z'] 0.1_2074ENS 1번째 반복 +6h 2.2600340843200684s
# ['z'] 0.1_2074ENS 2번째 반복 +12h 2.25936222076416s
# ['z'] 0.1_2074ENS 3번째 반복 +18h 2.2593066692352295s
# ['z'] 0.1_2074ENS 4번째 반복 +24h 2.259392499923706s
# ['z'] 0.1_2074ENS 5번째 반복 +30h 2.259232521057129s
# ['z'] 0.1_2074ENS 6번째 반복 +36h 2.2590105533599854s
# ['z'] 0.1_2074ENS 7번째 반복 +42h 2.25868821144104s
# ['z'] 0.1_2074ENS 8번째 반복 +48h 2.2585721015930176s
# ['z'] 0.1_2074ENS 9번째 반복 +54h 2.25752592086792s
# ['z'] 0.1_2074ENS 10번째 반복 +60h 2.259636163711548s
# ['z'] 0.1_2074ENS 11번째 반복 +66h 2.258899688720703s
# ['z'] 0.1_2074ENS 12번째 반복 +72h 2.2601749897003174s
# ['z'] 0.1_2074ENS 13번째 반복 +78h 2.258277654647827s
# ['z'] 0.1_2074ENS 14번째 반복 +84h 2.2609264850616455s
# ['z'] 0.1_2074ENS 15번째 반복 +90h 2.259169816970825s
# ['z'] 0.1_2074ENS 16번째 반복 +96h 2.2577250003814697s
# ['z'] 0.1_2074ENS 17번째 반복 +102h 2.259068012237549s
# ['z'] 0.1_2074ENS 18번째 반복 +108h 2.2595038414001465s
# ['z'] 0.1_2074ENS 19번째 반복 +114h 2.2596089839935303s
# ['z'] 0.1_2074ENS 20번째 반복 +120h 2.2606923580169678s
# ['z'] 0.1_2074ENS 21번째 반복 +126h 2.258713960647583s
# ['z'] 0.1_2074ENS 22번째 반복 +132h 2.2595386505126953s
# ['z'] 0.1_2074ENS 23번째 반복 +138h 2.2587497234344482s
# ['z'] 0.1_2074ENS 24번째 반복 +144h 2.259521245956421s
# ['z'] 0.1_2074ENS 25번째 반복 +150h 2.2575278282165527s
# ['z'] 0.1_2074ENS 26번째 반복 +156h 2.259493589401245s
# ['z'] 0.1_2074ENS 27번째 반복 +162h 2.259641647338867s
# ['z'] 0.1_2074ENS 28번째 반복 +168h 2.25981068611145s
# ['z'] 0.1_2074ENS: 1590.9127252101898s
# ['z'] 0.1_2075ENS 1번째 반복 +6h 2.2603728771209717s
# ['z'] 0.1_2075ENS 2번째 반복 +12h 2.2599289417266846s
# ['z'] 0.1_2075ENS 3번째 반복 +18h 2.2599472999572754s
# ['z'] 0.1_2075ENS 4번째 반복 +24h 2.260012149810791s
# ['z'] 0.1_2075ENS 5번째 반복 +30h 2.2586669921875s
# ['z'] 0.1_2075ENS 6번째 반복 +36h 2.2588071823120117s
# ['z'] 0.1_2075ENS 7번째 반복 +42h 2.2588133811950684s
# ['z'] 0.1_2075ENS 8번째 반복 +48h 2.258976459503174s
# ['z'] 0.1_2075ENS 9번째 반복 +54h 2.2581071853637695s
# ['z'] 0.1_2075ENS 10번째 반복 +60h 2.259138584136963s
# ['z'] 0.1_2075ENS 11번째 반복 +66h 2.2586421966552734s
# ['z'] 0.1_2075ENS 12번째 반복 +72h 2.2607767581939697s
# ['z'] 0.1_2075ENS 13번째 반복 +78h 2.2586212158203125s
# ['z'] 0.1_2075ENS 14번째 반복 +84h 2.2587766647338867s
# ['z'] 0.1_2075ENS 15번째 반복 +90h 2.2588653564453125s
# ['z'] 0.1_2075ENS 16번째 반복 +96h 2.258610725402832s
# ['z'] 0.1_2075ENS 17번째 반복 +102h 2.2580974102020264s
# ['z'] 0.1_2075ENS 18번째 반복 +108h 2.260251522064209s
# ['z'] 0.1_2075ENS 19번째 반복 +114h 2.2586848735809326s
# ['z'] 0.1_2075ENS 20번째 반복 +120h 2.2596418857574463s
# ['z'] 0.1_2075ENS 21번째 반복 +126h 2.258779287338257s
# ['z'] 0.1_2075ENS 22번째 반복 +132h 2.260510206222534s
# ['z'] 0.1_2075ENS 23번째 반복 +138h 2.2584238052368164s
# ['z'] 0.1_2075ENS 24번째 반복 +144h 2.258938789367676s
# ['z'] 0.1_2075ENS 25번째 반복 +150h 2.25667405128479s
# ['z'] 0.1_2075ENS 26번째 반복 +156h 2.260443925857544s
# ['z'] 0.1_2075ENS 27번째 반복 +162h 2.258108377456665s
# ['z'] 0.1_2075ENS 28번째 반복 +168h 2.259812355041504s
# ['z'] 0.1_2075ENS: 1654.5113923549652s
# ['z'] 0.1_2076ENS 1번째 반복 +6h 2.259859561920166s
# ['z'] 0.1_2076ENS 2번째 반복 +12h 2.2589457035064697s
# ['z'] 0.1_2076ENS 3번째 반복 +18h 2.259051561355591s
# ['z'] 0.1_2076ENS 4번째 반복 +24h 2.259474992752075s
# ['z'] 0.1_2076ENS 5번째 반복 +30h 2.2576355934143066s
# ['z'] 0.1_2076ENS 6번째 반복 +36h 2.2592389583587646s
# ['z'] 0.1_2076ENS 7번째 반복 +42h 2.2582225799560547s
# ['z'] 0.1_2076ENS 8번째 반복 +48h 2.257798433303833s
# ['z'] 0.1_2076ENS 9번째 반복 +54h 2.2582650184631348s
# ['z'] 0.1_2076ENS 10번째 반복 +60h 2.259523868560791s
# ['z'] 0.1_2076ENS 11번째 반복 +66h 2.2586398124694824s
# ['z'] 0.1_2076ENS 12번째 반복 +72h 2.2615582942962646s
# ['z'] 0.1_2076ENS 13번째 반복 +78h 2.258023500442505s
# ['z'] 0.1_2076ENS 14번째 반복 +84h 2.2595794200897217s
# ['z'] 0.1_2076ENS 15번째 반복 +90h 2.2591540813446045s
# ['z'] 0.1_2076ENS 16번째 반복 +96h 2.2588448524475098s
# ['z'] 0.1_2076ENS 17번째 반복 +102h 2.2573256492614746s
# ['z'] 0.1_2076ENS 18번째 반복 +108h 2.2597994804382324s
# ['z'] 0.1_2076ENS 19번째 반복 +114h 2.2584354877471924s
# ['z'] 0.1_2076ENS 20번째 반복 +120h 2.2597062587738037s
# ['z'] 0.1_2076ENS 21번째 반복 +126h 2.258596420288086s
# ['z'] 0.1_2076ENS 22번째 반복 +132h 2.2594501972198486s
# ['z'] 0.1_2076ENS 23번째 반복 +138h 2.2582037448883057s
# ['z'] 0.1_2076ENS 24번째 반복 +144h 2.261305093765259s
# ['z'] 0.1_2076ENS 25번째 반복 +150h 2.259289503097534s
# ['z'] 0.1_2076ENS 26번째 반복 +156h 2.261700391769409s
# ['z'] 0.1_2076ENS 27번째 반복 +162h 2.259315252304077s
# ['z'] 0.1_2076ENS 28번째 반복 +168h 2.262805461883545s
# ['z'] 0.1_2076ENS: 1718.0866627693176s
# ['z'] 0.1_2077ENS 1번째 반복 +6h 2.259842872619629s
# ['z'] 0.1_2077ENS 2번째 반복 +12h 2.258849859237671s
# ['z'] 0.1_2077ENS 3번째 반복 +18h 2.2592644691467285s
# ['z'] 0.1_2077ENS 4번째 반복 +24h 2.2587766647338867s
# ['z'] 0.1_2077ENS 5번째 반복 +30h 2.25736403465271s
# ['z'] 0.1_2077ENS 6번째 반복 +36h 2.2597644329071045s
# ['z'] 0.1_2077ENS 7번째 반복 +42h 2.2578723430633545s
# ['z'] 0.1_2077ENS 8번째 반복 +48h 2.258661985397339s
# ['z'] 0.1_2077ENS 9번째 반복 +54h 2.258324384689331s
# ['z'] 0.1_2077ENS 10번째 반복 +60h 2.259601354598999s
# ['z'] 0.1_2077ENS 11번째 반복 +66h 2.257826089859009s
# ['z'] 0.1_2077ENS 12번째 반복 +72h 2.2603116035461426s
# ['z'] 0.1_2077ENS 13번째 반복 +78h 2.257844924926758s
# ['z'] 0.1_2077ENS 14번째 반복 +84h 2.2595765590667725s
# ['z'] 0.1_2077ENS 15번째 반복 +90h 2.2579798698425293s
# ['z'] 0.1_2077ENS 16번째 반복 +96h 2.2586100101470947s
# ['z'] 0.1_2077ENS 17번째 반복 +102h 2.2587504386901855s
# ['z'] 0.1_2077ENS 18번째 반복 +108h 2.259469985961914s
# ['z'] 0.1_2077ENS 19번째 반복 +114h 2.258575439453125s
# ['z'] 0.1_2077ENS 20번째 반복 +120h 2.2608542442321777s
# ['z'] 0.1_2077ENS 21번째 반복 +126h 2.26682448387146s
# ['z'] 0.1_2077ENS 22번째 반복 +132h 2.2593510150909424s
# ['z'] 0.1_2077ENS 23번째 반복 +138h 2.2582640647888184s
# ['z'] 0.1_2077ENS 24번째 반복 +144h 2.2582297325134277s
# ['z'] 0.1_2077ENS 25번째 반복 +150h 2.259100914001465s
# ['z'] 0.1_2077ENS 26번째 반복 +156h 2.2591326236724854s
# ['z'] 0.1_2077ENS 27번째 반복 +162h 2.259120225906372s
# ['z'] 0.1_2077ENS 28번째 반복 +168h 2.2599992752075195s
# ['z'] 0.1_2077ENS: 1781.6879830360413s
# ['z'] 0.1_2078ENS 1번째 반복 +6h 2.259910821914673s
# ['z'] 0.1_2078ENS 2번째 반복 +12h 2.259490728378296s
# ['z'] 0.1_2078ENS 3번째 반복 +18h 2.260369062423706s
# ['z'] 0.1_2078ENS 4번째 반복 +24h 2.2603704929351807s
# ['z'] 0.1_2078ENS 5번째 반복 +30h 2.258397102355957s
# ['z'] 0.1_2078ENS 6번째 반복 +36h 2.26133131980896s
# ['z'] 0.1_2078ENS 7번째 반복 +42h 2.2580060958862305s
# ['z'] 0.1_2078ENS 8번째 반복 +48h 2.2588839530944824s
# ['z'] 0.1_2078ENS 9번째 반복 +54h 2.258021116256714s
# ['z'] 0.1_2078ENS 10번째 반복 +60h 2.259302854537964s
# ['z'] 0.1_2078ENS 11번째 반복 +66h 2.2586309909820557s
# ['z'] 0.1_2078ENS 12번째 반복 +72h 2.259859800338745s
# ['z'] 0.1_2078ENS 13번째 반복 +78h 2.2587242126464844s
# ['z'] 0.1_2078ENS 14번째 반복 +84h 2.259556531906128s
# ['z'] 0.1_2078ENS 15번째 반복 +90h 2.259014844894409s
# ['z'] 0.1_2078ENS 16번째 반복 +96h 2.2593748569488525s
# ['z'] 0.1_2078ENS 17번째 반복 +102h 2.257847309112549s
# ['z'] 0.1_2078ENS 18번째 반복 +108h 2.2597572803497314s
# ['z'] 0.1_2078ENS 19번째 반복 +114h 2.2586283683776855s
# ['z'] 0.1_2078ENS 20번째 반복 +120h 2.259995222091675s
# ['z'] 0.1_2078ENS 21번째 반복 +126h 2.2581119537353516s
# ['z'] 0.1_2078ENS 22번째 반복 +132h 2.2599284648895264s
# ['z'] 0.1_2078ENS 23번째 반복 +138h 2.2583460807800293s
# ['z'] 0.1_2078ENS 24번째 반복 +144h 2.258551597595215s
# ['z'] 0.1_2078ENS 25번째 반복 +150h 2.2601191997528076s
# ['z'] 0.1_2078ENS 26번째 반복 +156h 2.26108717918396s
# ['z'] 0.1_2078ENS 27번째 반복 +162h 2.259695053100586s
# ['z'] 0.1_2078ENS 28번째 반복 +168h 2.2616562843322754s
# ['z'] 0.1_2078ENS: 1845.284915447235s
# ['z'] 0.1_2079ENS 1번째 반복 +6h 2.25907301902771s
# ['z'] 0.1_2079ENS 2번째 반복 +12h 2.259676694869995s
# ['z'] 0.1_2079ENS 3번째 반복 +18h 2.2591476440429688s
# ['z'] 0.1_2079ENS 4번째 반복 +24h 2.2592079639434814s
# ['z'] 0.1_2079ENS 5번째 반복 +30h 2.2573299407958984s
# ['z'] 0.1_2079ENS 6번째 반복 +36h 2.259718656539917s
# ['z'] 0.1_2079ENS 7번째 반복 +42h 2.2596166133880615s
# ['z'] 0.1_2079ENS 8번째 반복 +48h 2.2587246894836426s
# ['z'] 0.1_2079ENS 9번째 반복 +54h 2.258460283279419s
# ['z'] 0.1_2079ENS 10번째 반복 +60h 2.258930206298828s
# ['z'] 0.1_2079ENS 11번째 반복 +66h 2.2583587169647217s
# ['z'] 0.1_2079ENS 12번째 반복 +72h 2.259599447250366s
# ['z'] 0.1_2079ENS 13번째 반복 +78h 2.2582945823669434s
# ['z'] 0.1_2079ENS 14번째 반복 +84h 2.2599401473999023s
# ['z'] 0.1_2079ENS 15번째 반복 +90h 2.2584495544433594s
# ['z'] 0.1_2079ENS 16번째 반복 +96h 2.258000373840332s
# ['z'] 0.1_2079ENS 17번째 반복 +102h 2.257476806640625s
# ['z'] 0.1_2079ENS 18번째 반복 +108h 2.2599568367004395s
# ['z'] 0.1_2079ENS 19번째 반복 +114h 2.2595102787017822s
# ['z'] 0.1_2079ENS 20번째 반복 +120h 2.2593483924865723s
# ['z'] 0.1_2079ENS 21번째 반복 +126h 2.258627414703369s
# ['z'] 0.1_2079ENS 22번째 반복 +132h 2.259671449661255s
# ['z'] 0.1_2079ENS 23번째 반복 +138h 2.25923228263855s
# ['z'] 0.1_2079ENS 24번째 반복 +144h 2.258683443069458s
# ['z'] 0.1_2079ENS 25번째 반복 +150h 2.2587194442749023s
# ['z'] 0.1_2079ENS 26번째 반복 +156h 2.259965181350708s
# ['z'] 0.1_2079ENS 27번째 반복 +162h 2.259315013885498s
# ['z'] 0.1_2079ENS 28번째 반복 +168h 2.2608447074890137s
# ['z'] 0.1_2079ENS: 1908.8828434944153s
# ['z'] 0.1_2080ENS 1번째 반복 +6h 2.260754346847534s
# ['z'] 0.1_2080ENS 2번째 반복 +12h 2.259587049484253s
# ['z'] 0.1_2080ENS 3번째 반복 +18h 2.260056257247925s
# ['z'] 0.1_2080ENS 4번째 반복 +24h 2.2620656490325928s
# ['z'] 0.1_2080ENS 5번째 반복 +30h 2.2585835456848145s
# ['z'] 0.1_2080ENS 6번째 반복 +36h 2.259556770324707s
# ['z'] 0.1_2080ENS 7번째 반복 +42h 2.2584285736083984s
# ['z'] 0.1_2080ENS 8번째 반복 +48h 2.2585339546203613s
# ['z'] 0.1_2080ENS 9번째 반복 +54h 2.2579972743988037s
# ['z'] 0.1_2080ENS 10번째 반복 +60h 2.260468006134033s
# ['z'] 0.1_2080ENS 11번째 반복 +66h 2.2591757774353027s
# ['z'] 0.1_2080ENS 12번째 반복 +72h 2.2605087757110596s
# ['z'] 0.1_2080ENS 13번째 반복 +78h 2.25781512260437s
# ['z'] 0.1_2080ENS 14번째 반복 +84h 2.2593023777008057s
# ['z'] 0.1_2080ENS 15번째 반복 +90h 2.2591187953948975s
# ['z'] 0.1_2080ENS 16번째 반복 +96h 2.259084463119507s
# ['z'] 0.1_2080ENS 17번째 반복 +102h 2.259718894958496s
# ['z'] 0.1_2080ENS 18번째 반복 +108h 2.2601749897003174s
# ['z'] 0.1_2080ENS 19번째 반복 +114h 2.25893235206604s
# ['z'] 0.1_2080ENS 20번째 반복 +120h 2.2615344524383545s
# ['z'] 0.1_2080ENS 21번째 반복 +126h 2.2603046894073486s
# ['z'] 0.1_2080ENS 22번째 반복 +132h 2.260833740234375s
# ['z'] 0.1_2080ENS 23번째 반복 +138h 2.260223388671875s
# ['z'] 0.1_2080ENS 24번째 반복 +144h 2.2594497203826904s
# ['z'] 0.1_2080ENS 25번째 반복 +150h 2.258148431777954s
# ['z'] 0.1_2080ENS 26번째 반복 +156h 2.2589786052703857s
# ['z'] 0.1_2080ENS 27번째 반복 +162h 2.25872802734375s
# ['z'] 0.1_2080ENS 28번째 반복 +168h 2.260164737701416s
# ['z'] 0.1_2080ENS: 1972.4666945934296s
# ['z'] 0.1_2081ENS 1번째 반복 +6h 2.2615585327148438s
# ['z'] 0.1_2081ENS 2번째 반복 +12h 2.2611920833587646s
# ['z'] 0.1_2081ENS 3번째 반복 +18h 2.2616443634033203s
# ['z'] 0.1_2081ENS 4번째 반복 +24h 2.2620856761932373s
# ['z'] 0.1_2081ENS 5번째 반복 +30h 2.26082444190979s
# ['z'] 0.1_2081ENS 6번째 반복 +36h 2.2618024349212646s
# ['z'] 0.1_2081ENS 7번째 반복 +42h 2.260425329208374s
# ['z'] 0.1_2081ENS 8번째 반복 +48h 2.260667562484741s
# ['z'] 0.1_2081ENS 9번째 반복 +54h 2.2594900131225586s
# ['z'] 0.1_2081ENS 10번째 반복 +60h 2.2613234519958496s
# ['z'] 0.1_2081ENS 11번째 반복 +66h 2.2599613666534424s
# ['z'] 0.1_2081ENS 12번째 반복 +72h 2.260789155960083s
# ['z'] 0.1_2081ENS 13번째 반복 +78h 2.27616024017334s
# ['z'] 0.1_2081ENS 14번째 반복 +84h 2.2613916397094727s
# ['z'] 0.1_2081ENS 15번째 반복 +90h 2.2598726749420166s
# ['z'] 0.1_2081ENS 16번째 반복 +96h 2.2607839107513428s
# ['z'] 0.1_2081ENS 17번째 반복 +102h 2.260047674179077s
# ['z'] 0.1_2081ENS 18번째 반복 +108h 2.261204719543457s
# ['z'] 0.1_2081ENS 19번째 반복 +114h 2.2609848976135254s
# ['z'] 0.1_2081ENS 20번째 반복 +120h 2.2622029781341553s
# ['z'] 0.1_2081ENS 21번째 반복 +126h 2.2604732513427734s
# ['z'] 0.1_2081ENS 22번째 반복 +132h 2.2617924213409424s
# ['z'] 0.1_2081ENS 23번째 반복 +138h 2.267979145050049s
# ['z'] 0.1_2081ENS 24번째 반복 +144h 2.258324146270752s
# ['z'] 0.1_2081ENS 25번째 반복 +150h 2.2581169605255127s
# ['z'] 0.1_2081ENS 26번째 반복 +156h 2.2588117122650146s
# ['z'] 0.1_2081ENS 27번째 반복 +162h 2.2581803798675537s
# ['z'] 0.1_2081ENS 28번째 반복 +168h 2.2599902153015137s
# ['z'] 0.1_2081ENS: 2036.1275839805603s
# ['z'] 0.1_2082ENS 1번째 반복 +6h 2.261979341506958s
# ['z'] 0.1_2082ENS 2번째 반복 +12h 2.2621755599975586s
# ['z'] 0.1_2082ENS 3번째 반복 +18h 2.2614901065826416s
# ['z'] 0.1_2082ENS 4번째 반복 +24h 2.261859893798828s
# ['z'] 0.1_2082ENS 5번째 반복 +30h 2.2603414058685303s
# ['z'] 0.1_2082ENS 6번째 반복 +36h 2.2614893913269043s
# ['z'] 0.1_2082ENS 7번째 반복 +42h 2.260427713394165s
# ['z'] 0.1_2082ENS 8번째 반복 +48h 2.2603566646575928s
# ['z'] 0.1_2082ENS 9번째 반복 +54h 2.2595112323760986s
# ['z'] 0.1_2082ENS 10번째 반복 +60h 2.261014461517334s
# ['z'] 0.1_2082ENS 11번째 반복 +66h 2.259970188140869s
# ['z'] 0.1_2082ENS 12번째 반복 +72h 2.2613511085510254s
# ['z'] 0.1_2082ENS 13번째 반복 +78h 2.2592432498931885s
# ['z'] 0.1_2082ENS 14번째 반복 +84h 2.2606849670410156s
# ['z'] 0.1_2082ENS 15번째 반복 +90h 2.2587084770202637s
# ['z'] 0.1_2082ENS 16번째 반복 +96h 2.2585904598236084s
# ['z'] 0.1_2082ENS 17번째 반복 +102h 2.2582342624664307s
# ['z'] 0.1_2082ENS 18번째 반복 +108h 2.259709596633911s
# ['z'] 0.1_2082ENS 19번째 반복 +114h 2.258802652359009s
# ['z'] 0.1_2082ENS 20번째 반복 +120h 2.2605748176574707s
# ['z'] 0.1_2082ENS 21번째 반복 +126h 2.2588870525360107s
# ['z'] 0.1_2082ENS 22번째 반복 +132h 2.2603919506073s
# ['z'] 0.1_2082ENS 23번째 반복 +138h 2.2629411220550537s
# ['z'] 0.1_2082ENS 24번째 반복 +144h 2.2586474418640137s
# ['z'] 0.1_2082ENS 25번째 반복 +150h 2.257108211517334s
# ['z'] 0.1_2082ENS 26번째 반복 +156h 2.2589826583862305s
# ['z'] 0.1_2082ENS 27번째 반복 +162h 2.2590858936309814s
# ['z'] 0.1_2082ENS 28번째 반복 +168h 2.25988507270813s
# ['z'] 0.1_2082ENS: 2099.724884033203s
# ...
# ['z'] 0.1_3989ENS 2번째 반복 +12h 2.2613608837127686s
# ['z'] 0.1_3989ENS 3번째 반복 +18h 2.261962890625s
# ['z'] 0.1_3989ENS 4번째 반복 +24h 2.2615060806274414s
# ['z'] 0.1_3989ENS 5번째 반복 +30h 2.259871482849121s
# ['z'] 0.1_3989ENS 6번째 반복 +36h 2.2632415294647217s
# ['z'] 0.1_3989ENS 7번째 반복 +42h 2.261436700820923s
# ['z'] 0.1_3989ENS 8번째 반복 +48h 2.261547803878784s
# ['z'] 0.1_3989ENS 9번째 반복 +54h 2.2599971294403076s
# ['z'] 0.1_3989ENS 10번째 반복 +60h 2.2612249851226807s
# ['z'] 0.1_3989ENS 11번째 반복 +66h 2.260805606842041s
# ['z'] 0.1_3989ENS 12번째 반복 +72h 2.2621166706085205s
# ['z'] 0.1_3989ENS 13번째 반복 +78h 2.260707139968872s
# ['z'] 0.1_3989ENS 14번째 반복 +84h 2.262131452560425s
# ['z'] 0.1_3989ENS 15번째 반복 +90h 2.2601828575134277s
# ['z'] 0.1_3989ENS 16번째 반복 +96h 2.261183500289917s
# ['z'] 0.1_3989ENS 17번째 반복 +102h 2.2608017921447754s
# ['z'] 0.1_3989ENS 18번째 반복 +108h 2.26229190826416s
# ['z'] 0.1_3989ENS 19번째 반복 +114h 2.261960029602051s
# ['z'] 0.1_3989ENS 20번째 반복 +120h 2.2625582218170166s
# ['z'] 0.1_3989ENS 21번째 반복 +126h 2.261763334274292s
# ['z'] 0.1_3989ENS 22번째 반복 +132h 2.300889253616333s
# ['z'] 0.1_3989ENS 23번째 반복 +138h 2.262019395828247s
# ['z'] 0.1_3989ENS 24번째 반복 +144h 2.261033058166504s
# ['z'] 0.1_3989ENS 25번째 반복 +150h 2.2627968788146973s
# ['z'] 0.1_3989ENS 26번째 반복 +156h 2.301185131072998s
# ['z'] 0.1_3989ENS 27번째 반복 +162h 2.2636008262634277s
# ['z'] 0.1_3989ENS 28번째 반복 +168h 2.263507127761841s
# ['z'] 0.1_3989ENS: 126120.397108078s
# ['z'] 0.1_3990ENS 1번째 반복 +6h 2.281791925430298s
# ['z'] 0.1_3990ENS 2번째 반복 +12h 2.2626307010650635s
# ['z'] 0.1_3990ENS 3번째 반복 +18h 2.262707233428955s
# ['z'] 0.1_3990ENS 4번째 반복 +24h 2.2628049850463867s
# ['z'] 0.1_3990ENS 5번째 반복 +30h 2.259934663772583s
# ['z'] 0.1_3990ENS 6번째 반복 +36h 2.262174606323242s
# ['z'] 0.1_3990ENS 7번째 반복 +42h 2.2614145278930664s
# ['z'] 0.1_3990ENS 8번째 반복 +48h 2.261040687561035s
# ['z'] 0.1_3990ENS 9번째 반복 +54h 2.2603237628936768s
# ['z'] 0.1_3990ENS 10번째 반복 +60h 2.2620718479156494s
# ['z'] 0.1_3990ENS 11번째 반복 +66h 2.261915445327759s
# ['z'] 0.1_3990ENS 12번째 반복 +72h 2.26299786567688s
# ['z'] 0.1_3990ENS 13번째 반복 +78h 2.265533447265625s
# ['z'] 0.1_3990ENS 14번째 반복 +84h 2.2659547328948975s
# ['z'] 0.1_3990ENS 15번째 반복 +90h 2.2606725692749023s
# ['z'] 0.1_3990ENS 16번째 반복 +96h 2.2618305683135986s
# ['z'] 0.1_3990ENS 17번째 반복 +102h 2.260974407196045s
# ['z'] 0.1_3990ENS 18번째 반복 +108h 2.2617032527923584s
# ['z'] 0.1_3990ENS 19번째 반복 +114h 2.260801076889038s
# ['z'] 0.1_3990ENS 20번째 반복 +120h 2.2623178958892822s
# ['z'] 0.1_3990ENS 21번째 반복 +126h 2.2601568698883057s
# ['z'] 0.1_3990ENS 22번째 반복 +132h 2.263169527053833s
# ['z'] 0.1_3990ENS 23번째 반복 +138h 2.2610952854156494s
# ['z'] 0.1_3990ENS 24번째 반복 +144h 2.261216402053833s
# ['z'] 0.1_3990ENS 25번째 반복 +150h 2.2605817317962646s
# ['z'] 0.1_3990ENS 26번째 반복 +156h 2.262474298477173s
# ['z'] 0.1_3990ENS 27번째 반복 +162h 2.2624082565307617s
# ['z'] 0.1_3990ENS 28번째 반복 +168h 2.2632791996002197s
# ['z'] 0.1_3990ENS: 126184.07312130928s
# ['z'] 0.1_3991ENS 1번째 반복 +6h 2.2644643783569336s
# ['z'] 0.1_3991ENS 2번째 반복 +12h 2.2621915340423584s
# ['z'] 0.1_3991ENS 3번째 반복 +18h 2.2619433403015137s
# ['z'] 0.1_3991ENS 4번째 반복 +24h 2.263228178024292s
# ['z'] 0.1_3991ENS 5번째 반복 +30h 2.2616937160491943s
# ['z'] 0.1_3991ENS 6번째 반복 +36h 2.2621378898620605s
# ['z'] 0.1_3991ENS 7번째 반복 +42h 2.262653112411499s
# ['z'] 0.1_3991ENS 8번째 반복 +48h 2.2625961303710938s
# ['z'] 0.1_3991ENS 9번째 반복 +54h 2.2636842727661133s
# ['z'] 0.1_3991ENS 10번째 반복 +60h 2.2650303840637207s
# ['z'] 0.1_3991ENS 11번째 반복 +66h 2.273961067199707s
# ['z'] 0.1_3991ENS 12번째 반복 +72h 2.269418954849243s
# ['z'] 0.1_3991ENS 13번째 반복 +78h 2.2639706134796143s
# ['z'] 0.1_3991ENS 14번째 반복 +84h 2.265857219696045s
# ['z'] 0.1_3991ENS 15번째 반복 +90h 2.276230573654175s
# ['z'] 0.1_3991ENS 16번째 반복 +96h 2.2742371559143066s
# ['z'] 0.1_3991ENS 17번째 반복 +102h 2.263946056365967s
# ['z'] 0.1_3991ENS 18번째 반복 +108h 2.266266345977783s
# ['z'] 0.1_3991ENS 19번째 반복 +114h 2.277177572250366s
# ['z'] 0.1_3991ENS 20번째 반복 +120h 2.2750353813171387s
# ['z'] 0.1_3991ENS 21번째 반복 +126h 2.2638487815856934s
# ['z'] 0.1_3991ENS 22번째 반복 +132h 2.2656960487365723s
# ['z'] 0.1_3991ENS 23번째 반복 +138h 2.2806456089019775s
# ['z'] 0.1_3991ENS 24번째 반복 +144h 2.267662763595581s
# ['z'] 0.1_3991ENS 25번째 반복 +150h 2.266310930252075s
# ['z'] 0.1_3991ENS 26번째 반복 +156h 2.2732584476470947s
# ['z'] 0.1_3991ENS 27번째 반복 +162h 2.275735855102539s
# ['z'] 0.1_3991ENS 28번째 반복 +168h 2.2914140224456787s
# ['z'] 0.1_3991ENS: 126247.91352915764s
# ['z'] 0.1_3992ENS 1번째 반복 +6h 2.267787456512451s
# ['z'] 0.1_3992ENS 2번째 반복 +12h 2.2668652534484863s
# ['z'] 0.1_3992ENS 3번째 반복 +18h 2.2752747535705566s
# ['z'] 0.1_3992ENS 4번째 반복 +24h 2.2667174339294434s
# ['z'] 0.1_3992ENS 5번째 반복 +30h 2.263918161392212s
# ['z'] 0.1_3992ENS 6번째 반복 +36h 2.266228437423706s
# ['z'] 0.1_3992ENS 7번째 반복 +42h 2.2823305130004883s
# ['z'] 0.1_3992ENS 8번째 반복 +48h 2.2672336101531982s
# ['z'] 0.1_3992ENS 9번째 반복 +54h 2.264410972595215s
# ['z'] 0.1_3992ENS 10번째 반복 +60h 2.2667815685272217s
# ['z'] 0.1_3992ENS 11번째 반복 +66h 2.2817912101745605s
# ['z'] 0.1_3992ENS 12번째 반복 +72h 2.2690181732177734s
# ['z'] 0.1_3992ENS 13번째 반복 +78h 2.2640576362609863s
# ['z'] 0.1_3992ENS 14번째 반복 +84h 2.266045331954956s
# ['z'] 0.1_3992ENS 15번째 반복 +90h 2.281798839569092s
# ['z'] 0.1_3992ENS 16번째 반복 +96h 2.272451639175415s
# ['z'] 0.1_3992ENS 17번째 반복 +102h 2.2642362117767334s
# ['z'] 0.1_3992ENS 18번째 반복 +108h 2.2650563716888428s
# ['z'] 0.1_3992ENS 19번째 반복 +114h 2.280965566635132s
# ['z'] 0.1_3992ENS 20번째 반복 +120h 2.2691426277160645s
# ['z'] 0.1_3992ENS 21번째 반복 +126h 2.263977289199829s
# ['z'] 0.1_3992ENS 22번째 반복 +132h 2.2651240825653076s
# ['z'] 0.1_3992ENS 23번째 반복 +138h 2.2818641662597656s
# ['z'] 0.1_3992ENS 24번째 반복 +144h 2.2722535133361816s
# ['z'] 0.1_3992ENS 25번째 반복 +150h 2.2657556533813477s
# ['z'] 0.1_3992ENS 26번째 반복 +156h 2.265561580657959s
# ['z'] 0.1_3992ENS 27번째 반복 +162h 2.2766666412353516s
# ['z'] 0.1_3992ENS 28번째 반복 +168h 2.2750725746154785s
# ['z'] 0.1_3992ENS: 126311.8320441246s
# ['z'] 0.1_3993ENS 1번째 반복 +6h 2.2665412425994873s
# ['z'] 0.1_3993ENS 2번째 반복 +12h 2.2650439739227295s
# ['z'] 0.1_3993ENS 3번째 반복 +18h 2.281752109527588s
# ['z'] 0.1_3993ENS 4번째 반복 +24h 2.27498197555542s
# ['z'] 0.1_3993ENS 5번째 반복 +30h 2.2637457847595215s
# ['z'] 0.1_3993ENS 6번째 반복 +36h 2.264707565307617s
# ['z'] 0.1_3993ENS 7번째 반복 +42h 2.274697780609131s
# ['z'] 0.1_3993ENS 8번째 반복 +48h 2.2729315757751465s
# ['z'] 0.1_3993ENS 9번째 반복 +54h 2.2634379863739014s
# ['z'] 0.1_3993ENS 10번째 반복 +60h 2.2645695209503174s
# ['z'] 0.1_3993ENS 11번째 반복 +66h 2.2801523208618164s
# ['z'] 0.1_3993ENS 12번째 반복 +72h 2.2739877700805664s
# ['z'] 0.1_3993ENS 13번째 반복 +78h 2.264721632003784s
# ['z'] 0.1_3993ENS 14번째 반복 +84h 2.265660285949707s
# ['z'] 0.1_3993ENS 15번째 반복 +90h 2.2817814350128174s
# ['z'] 0.1_3993ENS 16번째 반복 +96h 2.2676632404327393s
# ['z'] 0.1_3993ENS 17번째 반복 +102h 2.2648355960845947s
# ['z'] 0.1_3993ENS 18번째 반복 +108h 2.2668111324310303s
# ['z'] 0.1_3993ENS 19번째 반복 +114h 2.2825164794921875s
# ['z'] 0.1_3993ENS 20번째 반복 +120h 2.269989252090454s
# ['z'] 0.1_3993ENS 21번째 반복 +126h 2.264847755432129s
# ['z'] 0.1_3993ENS 22번째 반복 +132h 2.2649295330047607s
# ['z'] 0.1_3993ENS 23번째 반복 +138h 2.280611991882324s
# ['z'] 0.1_3993ENS 24번째 반복 +144h 2.267827033996582s
# ['z'] 0.1_3993ENS 25번째 반복 +150h 2.263701915740967s
# ['z'] 0.1_3993ENS 26번째 반복 +156h 2.2659478187561035s
# ['z'] 0.1_3993ENS 27번째 반복 +162h 2.279630422592163s
# ['z'] 0.1_3993ENS 28번째 반복 +168h 2.2751541137695312s
# ['z'] 0.1_3993ENS: 126375.72507023811s
# ['z'] 0.1_3994ENS 1번째 반복 +6h 2.261740207672119s
# ['z'] 0.1_3994ENS 2번째 반복 +12h 2.262239456176758s
# ['z'] 0.1_3994ENS 3번째 반복 +18h 2.261650323867798s
# ['z'] 0.1_3994ENS 4번째 반복 +24h 2.2630410194396973s
# ['z'] 0.1_3994ENS 5번째 반복 +30h 2.2612557411193848s
# ['z'] 0.1_3994ENS 6번째 반복 +36h 2.2631022930145264s
# ['z'] 0.1_3994ENS 7번째 반복 +42h 2.2610645294189453s
# ['z'] 0.1_3994ENS 8번째 반복 +48h 2.2618954181671143s
# ['z'] 0.1_3994ENS 9번째 반복 +54h 2.2613959312438965s
# ['z'] 0.1_3994ENS 10번째 반복 +60h 2.2626090049743652s
# ['z'] 0.1_3994ENS 11번째 반복 +66h 2.261604070663452s
# ['z'] 0.1_3994ENS 12번째 반복 +72h 2.262838840484619s
# ['z'] 0.1_3994ENS 13번째 반복 +78h 2.2605185508728027s
# ['z'] 0.1_3994ENS 14번째 반복 +84h 2.2615013122558594s
# ['z'] 0.1_3994ENS 15번째 반복 +90h 2.2616488933563232s
# ['z'] 0.1_3994ENS 16번째 반복 +96h 2.2608420848846436s
# ['z'] 0.1_3994ENS 17번째 반복 +102h 2.2603819370269775s
# ['z'] 0.1_3994ENS 18번째 반복 +108h 2.2626211643218994s
# ['z'] 0.1_3994ENS 19번째 반복 +114h 2.2646398544311523s
# ['z'] 0.1_3994ENS 20번째 반복 +120h 2.2682247161865234s
# ['z'] 0.1_3994ENS 21번째 반복 +126h 2.260749340057373s
# ['z'] 0.1_3994ENS 22번째 반복 +132h 2.261370897293091s
# ['z'] 0.1_3994ENS 23번째 반복 +138h 2.2610509395599365s
# ['z'] 0.1_3994ENS 24번째 반복 +144h 2.2612802982330322s
# ['z'] 0.1_3994ENS 25번째 반복 +150h 2.2615973949432373s
# ['z'] 0.1_3994ENS 26번째 반복 +156h 2.2620315551757812s
# ['z'] 0.1_3994ENS 27번째 반복 +162h 2.2626309394836426s
# ['z'] 0.1_3994ENS 28번째 반복 +168h 2.2613306045532227s
# ['z'] 0.1_3994ENS: 126439.39601683617s
# ['z'] 0.1_3995ENS 1번째 반복 +6h 2.2637178897857666s
# ['z'] 0.1_3995ENS 2번째 반복 +12h 2.2623400688171387s
# ['z'] 0.1_3995ENS 3번째 반복 +18h 2.264105796813965s
# ['z'] 0.1_3995ENS 4번째 반복 +24h 2.2649495601654053s
# ['z'] 0.1_3995ENS 5번째 반복 +30h 2.2625131607055664s
# ['z'] 0.1_3995ENS 6번째 반복 +36h 2.2620279788970947s
# ['z'] 0.1_3995ENS 7번째 반복 +42h 2.2620959281921387s
# ['z'] 0.1_3995ENS 8번째 반복 +48h 2.26172137260437s
# ['z'] 0.1_3995ENS 9번째 반복 +54h 2.2615835666656494s
# ['z'] 0.1_3995ENS 10번째 반복 +60h 2.2629806995391846s
# ['z'] 0.1_3995ENS 11번째 반복 +66h 2.262371063232422s
# ['z'] 0.1_3995ENS 12번째 반복 +72h 2.2627265453338623s
# ['z'] 0.1_3995ENS 13번째 반복 +78h 2.261833906173706s
# ['z'] 0.1_3995ENS 14번째 반복 +84h 2.2640233039855957s
# ['z'] 0.1_3995ENS 15번째 반복 +90h 2.2620136737823486s
# ['z'] 0.1_3995ENS 16번째 반복 +96h 2.262376308441162s
# ['z'] 0.1_3995ENS 17번째 반복 +102h 2.261700391769409s
# ['z'] 0.1_3995ENS 18번째 반복 +108h 2.2630741596221924s
# ['z'] 0.1_3995ENS 19번째 반복 +114h 2.433070659637451s
# ['z'] 0.1_3995ENS 20번째 반복 +120h 2.2640068531036377s
# ['z'] 0.1_3995ENS 21번째 반복 +126h 2.2616164684295654s
# ['z'] 0.1_3995ENS 22번째 반복 +132h 2.262530565261841s
# ['z'] 0.1_3995ENS 23번째 반복 +138h 2.2627995014190674s
# ['z'] 0.1_3995ENS 24번째 반복 +144h 2.263725519180298s
# ['z'] 0.1_3995ENS 25번째 반복 +150h 2.26066255569458s
# ['z'] 0.1_3995ENS 26번째 반복 +156h 2.261979341506958s
# ['z'] 0.1_3995ENS 27번째 반복 +162h 2.2613325119018555s
# ['z'] 0.1_3995ENS 28번째 반복 +168h 2.262718439102173s
# ['z'] 0.1_3995ENS: 126503.24068307877s
# ['z'] 0.1_3996ENS 1번째 반복 +6h 2.2625932693481445s
# ['z'] 0.1_3996ENS 2번째 반복 +12h 2.2619593143463135s
# ['z'] 0.1_3996ENS 3번째 반복 +18h 2.2625977993011475s
# ['z'] 0.1_3996ENS 4번째 반복 +24h 2.4086668491363525s
# ['z'] 0.1_3996ENS 5번째 반복 +30h 2.263540506362915s
# ['z'] 0.1_3996ENS 6번째 반복 +36h 2.263385772705078s
# ['z'] 0.1_3996ENS 7번째 반복 +42h 2.297990560531616s
# ['z'] 0.1_3996ENS 8번째 반복 +48h 2.262688159942627s
# ['z'] 0.1_3996ENS 9번째 반복 +54h 2.26069974899292s
# ['z'] 0.1_3996ENS 10번째 반복 +60h 2.2611875534057617s
# ['z'] 0.1_3996ENS 11번째 반복 +66h 2.261584758758545s
# ['z'] 0.1_3996ENS 12번째 반복 +72h 2.263099193572998s
# ['z'] 0.1_3996ENS 13번째 반복 +78h 2.260636806488037s
# ['z'] 0.1_3996ENS 14번째 반복 +84h 2.2616019248962402s
# ['z'] 0.1_3996ENS 15번째 반복 +90h 2.2610974311828613s
# ['z'] 0.1_3996ENS 16번째 반복 +96h 2.260996103286743s
# ['z'] 0.1_3996ENS 17번째 반복 +102h 2.261469841003418s
# ['z'] 0.1_3996ENS 18번째 반복 +108h 2.5774502754211426s
# ['z'] 0.1_3996ENS 19번째 반복 +114h 2.261012077331543s
# ['z'] 0.1_3996ENS 20번째 반복 +120h 2.273125410079956s
# ['z'] 0.1_3996ENS 21번째 반복 +126h 2.2609751224517822s
# ['z'] 0.1_3996ENS 22번째 반복 +132h 2.274874210357666s
# ['z'] 0.1_3996ENS 23번째 반복 +138h 2.2796947956085205s
# ['z'] 0.1_3996ENS 24번째 반복 +144h 2.2630763053894043s
# ['z'] 0.1_3996ENS 25번째 반복 +150h 2.2611477375030518s
# ['z'] 0.1_3996ENS 26번째 반복 +156h 2.2627992630004883s
# ['z'] 0.1_3996ENS 27번째 반복 +162h 2.2633426189422607s
# ['z'] 0.1_3996ENS 28번째 반복 +168h 2.262631893157959s
# ['z'] 0.1_3996ENS: 126567.44661140442s
# ['z'] 0.1_3997ENS 1번째 반복 +6h 2.262141466140747s
# ['z'] 0.1_3997ENS 2번째 반복 +12h 2.2628111839294434s
# ['z'] 0.1_3997ENS 3번째 반복 +18h 2.617933750152588s
# ['z'] 0.1_3997ENS 4번째 반복 +24h 2.262664556503296s
# ['z'] 0.1_3997ENS 5번째 반복 +30h 2.262138843536377s
# ['z'] 0.1_3997ENS 6번째 반복 +36h 2.263514280319214s
# ['z'] 0.1_3997ENS 7번째 반복 +42h 2.2610394954681396s
# ['z'] 0.1_3997ENS 8번째 반복 +48h 2.2883176803588867s
# ['z'] 0.1_3997ENS 9번째 반복 +54h 2.2641663551330566s
# ['z'] 0.1_3997ENS 10번째 반복 +60h 2.262028217315674s
# ['z'] 0.1_3997ENS 11번째 반복 +66h 2.2615182399749756s
# ['z'] 0.1_3997ENS 12번째 반복 +72h 2.2645645141601562s
# ['z'] 0.1_3997ENS 13번째 반복 +78h 2.2605807781219482s
# ['z'] 0.1_3997ENS 14번째 반복 +84h 2.263822317123413s
# ['z'] 0.1_3997ENS 15번째 반복 +90h 2.2625725269317627s
# ['z'] 0.1_3997ENS 16번째 반복 +96h 2.260737419128418s
# ['z'] 0.1_3997ENS 17번째 반복 +102h 2.304086446762085s
# ['z'] 0.1_3997ENS 18번째 반복 +108h 2.2637364864349365s
# ['z'] 0.1_3997ENS 19번째 반복 +114h 2.2628748416900635s
# ['z'] 0.1_3997ENS 20번째 반복 +120h 2.2629542350769043s
# ['z'] 0.1_3997ENS 21번째 반복 +126h 2.2608144283294678s
# ['z'] 0.1_3997ENS 22번째 반복 +132h 2.2635674476623535s
# ['z'] 0.1_3997ENS 23번째 반복 +138h 2.2616899013519287s
# ['z'] 0.1_3997ENS 24번째 반복 +144h 2.2604122161865234s
# ['z'] 0.1_3997ENS 25번째 반복 +150h 2.262110948562622s
# ['z'] 0.1_3997ENS 26번째 반복 +156h 2.2631425857543945s
# ['z'] 0.1_3997ENS 27번째 반복 +162h 2.262510299682617s
# ['z'] 0.1_3997ENS 28번째 반복 +168h 2.4418678283691406s
# ['z'] 0.1_3997ENS: 126631.71584200859s
# ['z'] 0.1_3998ENS 1번째 반복 +6h 2.262525796890259s
# ['z'] 0.1_3998ENS 2번째 반복 +12h 2.26790189743042s
# ['z'] 0.1_3998ENS 3번째 반복 +18h 2.2652201652526855s
# ['z'] 0.1_3998ENS 4번째 반복 +24h 2.2625186443328857s
# ['z'] 0.1_3998ENS 5번째 반복 +30h 2.260392665863037s
# ['z'] 0.1_3998ENS 6번째 반복 +36h 2.2680482864379883s
# ['z'] 0.1_3998ENS 7번째 반복 +42h 2.2617850303649902s
# ['z'] 0.1_3998ENS 8번째 반복 +48h 2.262507438659668s
# ['z'] 0.1_3998ENS 9번째 반복 +54h 2.260867118835449s
# ['z'] 0.1_3998ENS 10번째 반복 +60h 2.5557591915130615s
# ['z'] 0.1_3998ENS 11번째 반복 +66h 2.261986017227173s
# ['z'] 0.1_3998ENS 12번째 반복 +72h 2.2888784408569336s
# ['z'] 0.1_3998ENS 13번째 반복 +78h 2.2615091800689697s
# ['z'] 0.1_3998ENS 14번째 반복 +84h 2.2628209590911865s
# ['z'] 0.1_3998ENS 15번째 반복 +90h 2.2617881298065186s
# ['z'] 0.1_3998ENS 16번째 반복 +96h 2.2612643241882324s
# ['z'] 0.1_3998ENS 17번째 반복 +102h 2.2612569332122803s
# ['z'] 0.1_3998ENS 18번째 반복 +108h 2.2624733448028564s
# ['z'] 0.1_3998ENS 19번째 반복 +114h 2.2639055252075195s
# ['z'] 0.1_3998ENS 20번째 반복 +120h 2.263453483581543s
# ['z'] 0.1_3998ENS 21번째 반복 +126h 2.261470317840576s
# ['z'] 0.1_3998ENS 22번째 반복 +132h 2.675724506378174s
# ['z'] 0.1_3998ENS 23번째 반복 +138h 2.2635183334350586s
# ['z'] 0.1_3998ENS 24번째 반복 +144h 2.2623674869537354s
# ['z'] 0.1_3998ENS 25번째 반복 +150h 2.26227068901062s
# ['z'] 0.1_3998ENS 26번째 반복 +156h 2.2632508277893066s
# ['z'] 0.1_3998ENS 27번째 반복 +162h 2.2653019428253174s
# ['z'] 0.1_3998ENS 28번째 반복 +168h 2.3254315853118896s
# ['z'] 0.1_3998ENS: 126696.19269561768s
# ['z'] 0.1_3999ENS 1번째 반복 +6h 2.263033628463745s
# ['z'] 0.1_3999ENS 2번째 반복 +12h 2.2616586685180664s
# ['z'] 0.1_3999ENS 3번째 반복 +18h 2.262882947921753s
# ['z'] 0.1_3999ENS 4번째 반복 +24h 2.2639801502227783s
# ['z'] 0.1_3999ENS 5번째 반복 +30h 2.2612125873565674s
# ['z'] 0.1_3999ENS 6번째 반복 +36h 2.55092716217041s
# ['z'] 0.1_3999ENS 7번째 반복 +42h 2.2630093097686768s
# ['z'] 0.1_3999ENS 8번째 반복 +48h 2.2606585025787354s
# ['z'] 0.1_3999ENS 9번째 반복 +54h 2.262705087661743s
# ['z'] 0.1_3999ENS 10번째 반복 +60h 2.264328956604004s
# ['z'] 0.1_3999ENS 11번째 반복 +66h 2.2617361545562744s
# ['z'] 0.1_3999ENS 12번째 반복 +72h 2.2630484104156494s
# ['z'] 0.1_3999ENS 13번째 반복 +78h 2.261662244796753s
# ['z'] 0.1_3999ENS 14번째 반복 +84h 2.2629127502441406s
# ['z'] 0.1_3999ENS 15번째 반복 +90h 2.2982802391052246s
# ['z'] 0.1_3999ENS 16번째 반복 +96h 2.260915517807007s
# ['z'] 0.1_3999ENS 17번째 반복 +102h 2.2608673572540283s
# ['z'] 0.1_3999ENS 18번째 반복 +108h 2.262317419052124s
# ['z'] 0.1_3999ENS 19번째 반복 +114h 2.2610743045806885s
# ['z'] 0.1_3999ENS 20번째 반복 +120h 2.2624032497406006s
# ['z'] 0.1_3999ENS 21번째 반복 +126h 2.2597265243530273s
# ['z'] 0.1_3999ENS 22번째 반복 +132h 2.2625935077667236s
# ['z'] 0.1_3999ENS 23번째 반복 +138h 2.2615747451782227s
# ['z'] 0.1_3999ENS 24번째 반복 +144h 2.261725425720215s
# ['z'] 0.1_3999ENS 25번째 반복 +150h 2.2617623805999756s
# ['z'] 0.1_3999ENS 26번째 반복 +156h 2.3729281425476074s
# ['z'] 0.1_3999ENS 27번째 반복 +162h 2.2626099586486816s
# ['z'] 0.1_3999ENS 28번째 반복 +168h 2.4630916118621826s
# ['z'] 0.1_3999ENS: 126760.49102950096s
