# %%
#%%
import torch
import onnxruntime as ort
import os
import numpy as np
import onnx
import time
import itertools

# ===============================
# CONFIG
# ===============================
lat_perturb = True  # ✅ 위도별 표준편차(=axis=3 기반 perturbation) 활성화 옵션
pangu_dir = r'/home1/jek/Pangu-Weather'

lat_indices = np.linspace(90, -90, 721)
lon_indices = np.linspace(-180, 180, 1441)[:-1]

def latlon_extent(lon_min, lon_max, lat_min, lat_max):    
    lon_min, lon_max = lon_min-180, lon_max-180  
    lat_start = np.argmin(np.abs(lat_indices - lat_max)) 
    lat_end = np.argmin(np.abs(lat_indices - lat_min))
    lon_start = np.argmin(np.abs(lon_indices - lon_min))
    lon_end = np.argmin(np.abs(lon_indices - lon_max))
    latlon_ratio = (lon_max-lon_min)/(lat_max-lat_min)
    extent=[lon_min, lon_max, lat_min, lat_max]
    return lat_start, lat_end, lon_start, lon_end, extent, latlon_ratio

lat_start, lat_end, lon_start, lon_end, extent, latlon_ratio = latlon_extent(100,160,5,45)  # ✅ 저장할 위경도 범위

year = ['2022']
month = ['08']
day = ['27']
times = ['00']
ens_list = range(100,2000)
perturbation_scale_list =[0.2]
factor_list_list = [['z']]

surface_factor = ['MSLP', 'U10', 'V10', 'T2M']
surface_dict = {'MSLP':0, 'U10':1, 'V10':2, 'T2M':3}
upper_factor = ['z', 'q', 't', 'u', 'v']
upper_dict = {'z':0, 'q':1, 't':2, 'u':3, 'v':4}


# ===============================
# ONNX Sessions
# ===============================
options = ort.SessionOptions()
options.enable_cpu_mem_arena= True
options.enable_mem_pattern = False
options.enable_mem_reuse = False

cuda_provider_options_gpu0 = {'arena_extend_strategy': 'kSameAsRequested', 'device_id': 1}
ort_session_6 = ort.InferenceSession(
    rf'{pangu_dir}/pangu_weather_6.onnx', 
    sess_options=options, 
    providers=[('CUDAExecutionProvider', cuda_provider_options_gpu0)]
)
ort_session_24 = ort.InferenceSession(
    rf'{pangu_dir}/pangu_weather_24.onnx', 
    sess_options=options, 
    providers=[('CUDAExecutionProvider', cuda_provider_options_gpu0)]
)

# ===============================
# MAIN LOOP
# ===============================
start = time.time()

for factor_list in factor_list_list:
    for perturbation_scale in perturbation_scale_list:
        for y, m, d, tm in itertools.product(year, month, day, times):
            time_str = f'{y}/{m}/{d}/{tm}UTC'

            input_data_dir = rf'{pangu_dir}/input_data/{time_str}'
            output_data_dir = rf'/data03/Pangu_TC_ENS/output_data/{time_str}'

            input_upper = np.load(os.path.join(input_data_dir, 'upper.npy')).astype(np.float32)
            input_surface = np.load(os.path.join(input_data_dir, 'surface.npy')).astype(np.float32)

            # ===============================
            # STD DEV 계산
            # ===============================
            if lat_perturb:
                # 위도별 표준편차(lat-dependent)
                std_dev_upper = np.std(input_upper, axis=3, dtype=np.float32) * perturbation_scale  # (C, L, lat)
            else:
                # 전체 영역 기반 표준편차
                std_dev_upper = np.std(input_upper, axis=(2, 3), dtype=np.float32) * perturbation_scale  # (C, L)
            std_dev_surface = np.std(input_surface, axis=(1, 2), dtype=np.float32) * perturbation_scale

            factor_str = "".join([f"_{f}" for f in factor_list])
            lp_suffix = "_lp" if lat_perturb else ""
            ens_root_dir = rf'/data03/Pangu_TC_ENS/output_data/{time_str}/{perturbation_scale}ENS{factor_str}{lp_suffix}'

            # ===============================
            # ENSEMBLE LOOP
            # ===============================
            for ens in ens_list:
                output_data_dir = os.path.join(ens_root_dir, str(ens))
                os.makedirs(os.path.join(output_data_dir, 'upper'), exist_ok=True)
                os.makedirs(os.path.join(output_data_dir, 'surface'), exist_ok=True)
                
                perturbed_upper = input_upper.copy()
                perturbed_surface = input_surface.copy()

                seed_val = hash((ens, tuple(factor_list), perturbation_scale)) % (2**32)
                rng = np.random.default_rng(seed_val)

                # ================
                # Perturbation
                # ================
                if ens != 0:
                    for factor in factor_list:
                        if factor in upper_dict:
                            idx = upper_dict[factor]
                            for j in range(13):
                                if lat_perturb:
                                    # 위도별 표준편차 적용
                                    noise = rng.normal(0, 1, size=input_upper[idx, j].shape).astype(np.float32)
                                    scale = std_dev_upper[idx, j][..., None]  # (lat, 1)
                                    perturbation = noise * scale
                                else:
                                    # 전체 평균 표준편차 적용
                                    perturbation = rng.normal(0, std_dev_upper[idx, j], input_upper[idx, j].shape)
                                perturbed_upper[idx, j] = input_upper[idx, j] + perturbation.astype(np.float32)

                        elif factor in surface_dict:
                            idx = surface_dict[factor]
                            perturbation = rng.normal(0, std_dev_surface[idx], input_surface[idx].shape)
                            perturbed_surface[idx] = input_surface[idx] + perturbation.astype(np.float32)

                # ================
                # Save initial
                # ================
                np.save(os.path.join(output_data_dir, f'upper/0h'), perturbed_upper[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                np.save(os.path.join(output_data_dir, f'surface/0h'), perturbed_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])

                perturbed_24, perturbed_surface_24 = perturbed_upper, perturbed_surface

                # ================
                # Forecast loop
                # ================
                for i in range(28):
                    start_i = time.time()
                    predict_interval = 6 * (i + 1)

                    if (i + 1) % 4 == 0:
                        output, output_surface = ort_session_24.run(None, {'input': perturbed_24, 'input_surface': perturbed_surface_24})
                        perturbed_24, perturbed_surface_24 = output, output_surface
                    else:
                        output, output_surface = ort_session_6.run(None, {'input': perturbed_upper, 'input_surface': perturbed_surface})

                    np.save(os.path.join(output_data_dir, f'upper/{predict_interval}h'), output[:,:,lat_start: lat_end+1, lon_start:lon_end+1])
                    np.save(os.path.join(output_data_dir, f'surface/{predict_interval}h'), output_surface[:,lat_start: lat_end+1, lon_start:lon_end+1])

                    perturbed_upper, perturbed_surface = output, output_surface
                    end_i = time.time()
                    print(f'{factor_list} {perturbation_scale}_{ens}ENS{lp_suffix} {i+1}번째 반복 +{predict_interval}h {end_i-start_i:.2f}s')

                end = time.time()
                print(f"{factor_list} {perturbation_scale}_{ens}ENS{lp_suffix}: {end-start:.1f}s")
# Out:
# ['z'] 0.2_100ENS_lp 1번째 반복 +6h 2.50s
# ['z'] 0.2_100ENS_lp 2번째 반복 +12h 2.27s
# ['z'] 0.2_100ENS_lp 3번째 반복 +18h 2.26s
# ['z'] 0.2_100ENS_lp 4번째 반복 +24h 3.66s
# ['z'] 0.2_100ENS_lp 5번째 반복 +30h 2.26s
# ['z'] 0.2_100ENS_lp 6번째 반복 +36h 2.28s
# ['z'] 0.2_100ENS_lp 7번째 반복 +42h 2.25s
# ['z'] 0.2_100ENS_lp 8번째 반복 +48h 2.61s
# ['z'] 0.2_100ENS_lp 9번째 반복 +54h 2.27s
# ['z'] 0.2_100ENS_lp 10번째 반복 +60h 3.27s
# ['z'] 0.2_100ENS_lp 11번째 반복 +66h 2.26s
# ['z'] 0.2_100ENS_lp 12번째 반복 +72h 2.93s
# ['z'] 0.2_100ENS_lp 13번째 반복 +78h 2.26s
# ['z'] 0.2_100ENS_lp 14번째 반복 +84h 2.30s
# ['z'] 0.2_100ENS_lp 15번째 반복 +90h 2.26s
# ['z'] 0.2_100ENS_lp 16번째 반복 +96h 2.28s
# ['z'] 0.2_100ENS_lp 17번째 반복 +102h 2.26s
# ['z'] 0.2_100ENS_lp 18번째 반복 +108h 2.62s
# ['z'] 0.2_100ENS_lp 19번째 반복 +114h 2.26s
# ['z'] 0.2_100ENS_lp 20번째 반복 +120h 2.42s
# ['z'] 0.2_100ENS_lp 21번째 반복 +126h 2.26s
# ['z'] 0.2_100ENS_lp 22번째 반복 +132h 2.33s
# ['z'] 0.2_100ENS_lp 23번째 반복 +138h 2.26s
# ['z'] 0.2_100ENS_lp 24번째 반복 +144h 2.28s
# ...

# %%
#%%
import torch
import onnxruntime as ort
import os
import numpy as np
import time
import itertools

# ===============================
# CONFIG
# ===============================
pangu_dir = r'/home1/jek/Pangu-Weather'

lat_indices = np.linspace(90, -90, 721)
lon_indices = np.linspace(0, 359.75, 1441)[:-1] 

def latlon_extent(lon_min, lon_max, lat_min, lat_max):    
    if lon_min < 0: lon_min += 360
    if lon_max < 0: lon_max += 360
    lat_start = np.argmin(np.abs(lat_indices - lat_max)) 
    lat_end = np.argmin(np.abs(lat_indices - lat_min))
    lon_start = np.argmin(np.abs(lon_indices - lon_min))
    lon_end = np.argmin(np.abs(lon_indices - lon_max))
    return lat_start, lat_end, lon_start, lon_end

lat_start, lat_end, lon_start, lon_end = latlon_extent(100, 160, 5, 45)

year = ['2022']
month = ['08']
day = ['27']
times = ['00']

# 실험 설정
perturb_time = 12       # 섭동을 가할 시점 (12시간)
q_perturb_ratio = -0.05   # 5% 증감
box1_center = {'lat': 28.25, 'lon': 151.0} # Upper (감소 시킬 곳)
box2_center = {'lat': 22.0, 'lon': 152.25} # Lower (증가 시킬 곳)
box_size = 3.0
upper_dict = {'z':0, 'q':1, 't':2, 'u':3, 'v':4}

# ===============================
# ONNX Session Load (6시간 모델만)
# ===============================
options = ort.SessionOptions()
options.enable_cpu_mem_arena= True
cuda_provider = {'arena_extend_strategy': 'kSameAsRequested', 'device_id': 1}
ort_session_6 = ort.InferenceSession(rf'{pangu_dir}/pangu_weather_6.onnx', sess_options=options, providers=[('CUDAExecutionProvider', cuda_provider)])

# ===============================
# Helper Functions
# ===============================
def get_mask(center_lat, center_lon, size_deg, lat_arr, lon_arr):
    lat_min, lat_max = center_lat - size_deg/2, center_lat + size_deg/2
    lon_min, lon_max = center_lon - size_deg/2, center_lon + size_deg/2
    if lon_min < 0: lon_min += 360
    if lon_max < 0: lon_max += 360
    lat_mask = (lat_arr <= lat_max) & (lat_arr >= lat_min)
    lon_mask = (lon_arr >= lon_min) & (lon_arr <= lon_max)
    return np.ix_(lat_mask, lon_mask)

# ===============================
# MAIN EXECUTUION
# ===============================
for y, m, d, tm in itertools.product(year, month, day, times):
    time_str = f'{y}/{m}/{d}/{tm}UTC'
    print(f"Processing {time_str} (Perturb at +{perturb_time}h)...")

    input_data_dir = rf'{pangu_dir}/input_data/{time_str}'
    
    # 0. 원본 데이터 로드
    input_upper_org = np.load(os.path.join(input_data_dir, 'upper.npy')).astype(np.float32)
    input_surface_org = np.load(os.path.join(input_data_dir, 'surface.npy')).astype(np.float32)

    # 1. 저장 경로 설정
    exp_name = f"Sens_Q_Mod_at_{perturb_time}h"
    output_root = rf'/data09/Pangu_TC_ENS/output_data/{time_str}/{exp_name}'
    os.makedirs(os.path.join(output_root, 'upper'), exist_ok=True)
    os.makedirs(os.path.join(output_root, 'surface'), exist_ok=True)
    
    # 0h는 원본 그대로 저장 (수정 없음)
    np.save(os.path.join(output_root, 'upper/0h'), input_upper_org[:,:,lat_start:lat_end+1, lon_start:lon_end+1])
    np.save(os.path.join(output_root, 'surface/0h'), input_surface_org[:,lat_start:lat_end+1, lon_start:lon_end+1])

    # 2. Forecasting Loop
    curr_upper = input_upper_org  # 초기 시작은 원본
    curr_surface = input_surface_org

    start_time = time.time()
    
    for i in range(28): # 168h Forecast
        lead_time = (i + 1) * 6
        
        # 모델 실행 (항상 직전 단계 결과 사용)
        output_u, output_s = ort_session_6.run(None, {
            'input': curr_upper, 
            'input_surface': curr_surface
        })
        
        # ==========================================
        # ★ 여기가 핵심: 12시간 시점이면 데이터 조작 ★
        # ==========================================
        if lead_time == perturb_time:
            print(f"!!! Applying Perturbation at +{lead_time}h !!!")
            
            q_idx = upper_dict['q']
            
            # Box 1: 수증기 감소
            idx_lat1, idx_lon1 = get_mask(box1_center['lat'], box1_center['lon'], box_size, lat_indices, lon_indices)
            output_u[q_idx][:, idx_lat1, idx_lon1] *= (1.0 - q_perturb_ratio)

            # Box 2: 수증기 증가
            idx_lat2, idx_lon2 = get_mask(box2_center['lat'], box2_center['lon'], box_size, lat_indices, lon_indices)
            output_u[q_idx][:, idx_lat2, idx_lon2] *= (1.0 + q_perturb_ratio)

        # 결과 갱신 (조작된 데이터가 있다면 그게 다음 루프의 입력이 됨)
        curr_upper, curr_surface = output_u, output_s

        # 저장
        np.save(os.path.join(output_root, f'upper/{lead_time}h'), curr_upper[:,:,lat_start:lat_end+1, lon_start:lon_end+1])
        np.save(os.path.join(output_root, f'surface/{lead_time}h'), curr_surface[:,lat_start:lat_end+1, lon_start:lon_end+1])

        print(f"[{exp_name}] +{lead_time}h Predicted.")

    print(f"Experiment Done. Total time: {time.time() - start_time:.1f}s")
# Out:
# Processing 2022/08/27/00UTC (Perturb at +12h)...
# [Sens_Q_Mod_at_12h] +6h Predicted.
# !!! Applying Perturbation at +12h !!!
# [Sens_Q_Mod_at_12h] +12h Predicted.
# [Sens_Q_Mod_at_12h] +18h Predicted.
# [Sens_Q_Mod_at_12h] +24h Predicted.
# [Sens_Q_Mod_at_12h] +30h Predicted.
# [Sens_Q_Mod_at_12h] +36h Predicted.
# [Sens_Q_Mod_at_12h] +42h Predicted.
# [Sens_Q_Mod_at_12h] +48h Predicted.
# [Sens_Q_Mod_at_12h] +54h Predicted.
# [Sens_Q_Mod_at_12h] +60h Predicted.
# [Sens_Q_Mod_at_12h] +66h Predicted.
# [Sens_Q_Mod_at_12h] +72h Predicted.
# [Sens_Q_Mod_at_12h] +78h Predicted.
# [Sens_Q_Mod_at_12h] +84h Predicted.
# [Sens_Q_Mod_at_12h] +90h Predicted.
# [Sens_Q_Mod_at_12h] +96h Predicted.
# [Sens_Q_Mod_at_12h] +102h Predicted.
# [Sens_Q_Mod_at_12h] +108h Predicted.
# [Sens_Q_Mod_at_12h] +114h Predicted.
# [Sens_Q_Mod_at_12h] +120h Predicted.
# [Sens_Q_Mod_at_12h] +126h Predicted.
# [Sens_Q_Mod_at_12h] +132h Predicted.
# [Sens_Q_Mod_at_12h] +138h Predicted.
# ...

# %%
#%%
import onnxruntime as ort
import os
import numpy as np
import time
import itertools

# ===============================
# 1. CONFIGURATION
# ===============================
pangu_dir = r'/home1/jek/Pangu-Weather'

# 실험 설정
perturb_time = 12       # 섭동을 가할 시점 (12시간)
q_perturb_ratio = 0.1  # 5% (양수로 설정하고 아래에서 더하고 뺍니다)

# Box 1: Upper Region (수증기 감소 시킬 곳)
box1_center = {'lat': 28.25, 'lon': 151.0} 
# Box 2: Lower Region (수증기 증가 시킬 곳)
box2_center = {'lat': 22.0, 'lon': 152.25} 
box_size = 3.0

lat_indices = np.linspace(90, -90, 721)
lon_indices = np.linspace(0, 359.75, 1441)[:-1] 

# 저장할 위경도 범위
def latlon_extent(lon_min, lon_max, lat_min, lat_max):    
    if lon_min < 0: lon_min += 360
    if lon_max < 0: lon_max += 360
    lat_start = np.argmin(np.abs(lat_indices - lat_max)) 
    lat_end = np.argmin(np.abs(lat_indices - lat_min))
    lon_start = np.argmin(np.abs(lon_indices - lon_min))
    lon_end = np.argmin(np.abs(lon_indices - lon_max))
    return lat_start, lat_end, lon_start, lon_end

lat_start, lat_end, lon_start, lon_end = latlon_extent(100, 160, 5, 45)

year = ['2022']
month = ['08']
day = ['27']
times = ['00']
upper_dict = {'z':0, 'q':1, 't':2, 'u':3, 'v':4}

# ===============================
# 2. MODEL LOADING (Only 6h)
# ===============================
options = ort.SessionOptions()
options.enable_cpu_mem_arena= True
cuda_provider = {'arena_extend_strategy': 'kSameAsRequested', 'device_id': 1}
ort_session_6 = ort.InferenceSession(rf'{pangu_dir}/pangu_weather_6.onnx', sess_options=options, providers=[('CUDAExecutionProvider', cuda_provider)])

# ===============================
# 3. HELPER FUNCTION
# ===============================
def get_mask(center_lat, center_lon, size_deg, lat_arr, lon_arr):
    lat_min, lat_max = center_lat - size_deg/2, center_lat + size_deg/2
    lon_min, lon_max = center_lon - size_deg/2, center_lon + size_deg/2
    if lon_min < 0: lon_min += 360
    if lon_max < 0: lon_max += 360
    lat_mask = (lat_arr <= lat_max) & (lat_arr >= lat_min)
    lon_mask = (lon_arr >= lon_min) & (lon_arr <= lon_max)
    return np.ix_(lat_mask, lon_mask)

# ===============================
# 4. MAIN EXPERIMENT LOOP
# ===============================
for y, m, d, tm in itertools.product(year, month, day, times):
    time_str = f'{y}/{m}/{d}/{tm}UTC'
    print(f"=== Initializing Experiment for {time_str} ===")

    input_data_dir = rf'{pangu_dir}/input_data/{time_str}'
    
    # [공통] 원본 데이터 로드 (Clean ERA5)
    # 두 실험 모두 이 데이터를 복사해서 시작하므로 시작점이 완벽하게 동일함.
    try:
        common_input_upper = np.load(os.path.join(input_data_dir, 'upper.npy')).astype(np.float32)
        common_input_surface = np.load(os.path.join(input_data_dir, 'surface.npy')).astype(np.float32)
    except FileNotFoundError:
        print(f"Error: 입력 데이터를 찾을 수 없습니다. {input_data_dir}")
        continue

    # =================================================================
    # 실험 정의: [실험명, 섭동 적용 여부]
    # 1. Control: 섭동 없음
    # 2. Experiment: 12시간에 섭동 적용
    # =================================================================
    experiments = [
        ("Control_Run", False), 
        (f"Sens_Q_Mod_at_{perturb_time}h", True)
    ]

    for exp_name, apply_perturb in experiments:
        print(f"\n>> Running Experiment: {exp_name}")
        
        # 저장 경로 설정
        output_root = rf'/data09/Pangu_TC_ENS/output_data/{time_str}/{exp_name}'
        os.makedirs(os.path.join(output_root, 'upper'), exist_ok=True)
        os.makedirs(os.path.join(output_root, 'surface'), exist_ok=True)

        # 0h 저장 (초기 상태)
        np.save(os.path.join(output_root, 'upper/0h'), common_input_upper[:,:,lat_start:lat_end+1, lon_start:lon_end+1])
        np.save(os.path.join(output_root, 'surface/0h'), common_input_surface[:,lat_start:lat_end+1, lon_start:lon_end+1])

        # 현재 상태 초기화 (반드시 copy() 사용)
        curr_upper = common_input_upper.copy()
        curr_surface = common_input_surface.copy()
        
        start_time = time.time()

        for i in range(28): # 168h Forecast
            lead_time = (i + 1) * 6
            
            # 모델 실행
            output_u, output_s = ort_session_6.run(None, {
                'input': curr_upper, 
                'input_surface': curr_surface
            })

            # ==========================================
            # ★ 섭동 적용 (Experiment 모드이면서 시간이 맞을 때) ★
            # ==========================================
            if apply_perturb and lead_time == perturb_time:
                print(f"   [Perturbation] Modifying Water Vapor(q) at +{lead_time}h")
                
                q_idx = upper_dict['q']
                
                # Box 1: 감소 (1.0 - 0.05 = 0.95배)
                idx_lat1, idx_lon1 = get_mask(box1_center['lat'], box1_center['lon'], box_size, lat_indices, lon_indices)
                output_u[q_idx][:, idx_lat1, idx_lon1] *= (1.0 - q_perturb_ratio)

                # Box 2: 증가 (1.0 + 0.05 = 1.05배)
                idx_lat2, idx_lon2 = get_mask(box2_center['lat'], box2_center['lon'], box_size, lat_indices, lon_indices)
                output_u[q_idx][:, idx_lat2, idx_lon2] *= (1.0 + q_perturb_ratio)

            # 결과 갱신
            curr_upper, curr_surface = output_u, output_s

            # 저장
            np.save(os.path.join(output_root, f'upper/{lead_time}h'), curr_upper[:,:,lat_start:lat_end+1, lon_start:lon_end+1])
            np.save(os.path.join(output_root, f'surface/{lead_time}h'), curr_surface[:,lat_start:lat_end+1, lon_start:lon_end+1])
            
            # 진행상황 출력 (4단계마다)
            if lead_time % 24 == 0:
                print(f"   Saved +{lead_time}h")

        print(f"   Done. Time: {time.time() - start_time:.1f}s")


# ===============================
# 5. VERIFICATION (자동 검증)
# ===============================
print("\n=== Verification ===")
ctrl_path = rf'/data09/Pangu_TC_ENS/output_data/{time_str}/Control_Run/upper'
exp_path = rf'/data09/Pangu_TC_ENS/output_data/{time_str}/Sens_Q_Mod_at_{perturb_time}h/upper'

# 6시간 비교 (섭동 전이므로 같아야 함)
u6_ctrl = np.load(os.path.join(ctrl_path, '6h.npy'))
u6_exp = np.load(os.path.join(exp_path, '6h.npy'))
diff_6h = np.max(np.abs(u6_ctrl - u6_exp))
print(f"Diff at 6h (Should be 0.0): {diff_6h:.8f}")

# 12시간 비교 (섭동 직후이므로 달라야 함)
u12_ctrl = np.load(os.path.join(ctrl_path, f'{perturb_time}h.npy'))
u12_exp = np.load(os.path.join(exp_path, f'{perturb_time}h.npy'))
diff_12h = np.max(np.abs(u12_ctrl - u12_exp))
print(f"Diff at {perturb_time}h (Should be > 0): {diff_12h:.8f}")

if diff_6h < 1e-5 and diff_12h > 1e-5:
    print("\n✅ SUCCESS: Experiment setup is correct!")
else:
    print("\n❌ WARNING: Something is wrong. Check 0h input data.")
# Out:
# === Initializing Experiment for 2022/08/27/00UTC ===
#
# >> Running Experiment: Control_Run
#    Saved +24h
#    Saved +48h
#    Saved +72h
#    Saved +96h
#    Saved +120h
#    Saved +144h
#    Saved +168h
#    Done. Time: 63.5s
#
# >> Running Experiment: Sens_Q_Mod_at_12h
#    [Perturbation] Modifying Water Vapor(q) at +12h
#    Saved +24h
#    Saved +48h
#    Saved +72h
#    Saved +96h
#    Saved +120h
#    Saved +144h
#    Saved +168h
#    Done. Time: 64.0s
#
# === Verification ===
# Diff at 6h (Should be 0.0): 0.00000000
# Diff at 12h (Should be > 0): 0.00177348
#
# ✅ SUCCESS: Experiment setup is correct!

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

lead_time = 96
upper = np.load(f'/data09/Pangu_TC_ENS/output_data/{time_str}/Control_Run/upper/{lead_time}h.npy')
masked_upper = np.load(f'/data09/Pangu_TC_ENS/output_data/{time_str}/Sens_Q_Mod_at_12h/upper/{lead_time}h.npy')
surf = np.load(f'/data09/Pangu_TC_ENS/output_data/{time_str}/Control_Run/surface/{lead_time}h.npy')
masked_surf = np.load(f'/data09/Pangu_TC_ENS/output_data/{time_str}/Sens_Q_Mod_at_12h/surface/{lead_time}h.npy')

plt.imshow(masked_upper[0,0])
plt.show()
plt.imshow(upper[0,0])
plt.show()
np.max(np.abs(masked_upper[0,0]-upper[0,0])), np.max(np.abs(surf[0]-masked_surf[0]))
# Out:
# (394.34323, 463.4922)
